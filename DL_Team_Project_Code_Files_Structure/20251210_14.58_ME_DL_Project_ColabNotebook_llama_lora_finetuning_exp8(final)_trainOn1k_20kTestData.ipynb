# %% [markdown]
# # Preliminaries and Imports

# %% [markdown]
# Notes:
# - In case of error "Using `bitsandbytes` 4-bit quantization requires the latest version of bitsandbytes: `pip install -U bitsandbytes": The update is already implemented in the notebook. "Restart the session" and "Run all" again because the update seems to require a restart

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# system and path set up
import os
import sys

# path
GOOGLE_DRIVE_PATH = os.path.join('/content', 'drive', 'My Drive', 'ColabNotebooks', 'DL','Deep Learning Project Full','DL Team Project', '20251126_22.47_DL_Team_Project_Code_Files_Structure')

# set working directory (for saving/ loading)
os.chdir(GOOGLE_DRIVE_PATH)

# set import path (for importing src/)
sys.path.insert(0, GOOGLE_DRIVE_PATH)

# verify
print("Current working directory:", os.getcwd())
print("Current import directory:", sys.path[0])
# Out:
# Current working directory: /content/drive/My Drive/ColabNotebooks/DL/Deep Learning Project Full/DL Team Project/20251126_22.47_DL_Team_Project_Code_Files_Structure
# Current import directory: /content/drive/My Drive/ColabNotebooks/DL/Deep Learning Project Full/DL Team Project/20251126_22.47_DL_Team_Project_Code_Files_Structure

# %%
# log into HF
# note: previously store your key as secret (key symbol on the left)
from google.colab import userdata
hf_token = userdata.get('HF_TOKEN')

from huggingface_hub import login
login(token=hf_token)

# Option: silence all HF logs
from transformers.utils.logging import set_verbosity_error
set_verbosity_error()

# %%
# install libraries (only once and then comment out)
# !pip install -q "transformers>=4.40.0" accelerate datasets peft bitsandbytes trl
# !pip install -q -U bitsandbytes transformers accelerate peft trl

# %%
# import standard libraries
import pandas as pd
import time
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import json
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, TrainingArguments
import torch
from peft import LoraConfig

# import utils
from src import utils

# import model
from src.model_llama_lora import CommonMethods, LlamaBaseModel, LlamaLoraModel

# create instance object of CommonMethods
cm = CommonMethods()

# %%
# set seed for reproduceibility (Note: does not work for OpenAI)
seed = 42

# %% [markdown]
# # Load and prepare data

# %%
# load pre-processed data
csv_path_train_data = f"{GOOGLE_DRIVE_PATH}/data/data_train.csv"
csv_path_val_data = f"{GOOGLE_DRIVE_PATH}/data/data_val.csv"
csv_path_test_data = f"{GOOGLE_DRIVE_PATH}/data/data_test.csv"

train_bal = pd.read_csv(csv_path_train_data)
val = pd.read_csv(csv_path_val_data)
test = pd.read_csv(csv_path_test_data)

# %%
# keep only needed columns (drop lang and label5)
train_bal = train_bal.drop(columns=["label5","lang"])
val = val.drop(columns=["label5","lang"])
test = test.drop(columns=["label5","lang"])

# %%
# downsample data
# Note: Fine-tuning on full data would take too long
train_bal = train_bal.sample(n=1000, random_state=seed)
val = val.sample(n=5000, random_state=seed)
test = test.sample(n=20000, random_state=seed)

# %% [markdown]
# # Run model/ Experiment

# %% [markdown]
# Specify model:
# - Choose model type
# - quant_config (= hyperparameters)
# - lora_config (= hyperparameters)
# - training_config (= hyperparameters)
# - Instruction (= hyperparameters)
#
# Specify data for evaluation:
# - val data: for tuning
# - test data: for final run

# %%
# choose model
model_name = "meta-llama/Llama-3.2-3B-Instruct" # "meta-llama/Meta-Llama-3-8B-Instruct"

# %%
# set quantification configuration
quant_config = BitsAndBytesConfig(
    load_in_4_bit=True,
    bnb_4bit_use_double_quant=False,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16)

# %%
peft_config = LoraConfig(
    r=8, # Default 8; size of low-rank update matrice; higher r --> larger trainable capacity                              # 1st prio hyperparameter
    lora_alpha=16, # Default 8;  scaling of loRA updates before adding to base model; higher alpha --> higher loRA effect   # 1st prio hyperparameter
    lora_dropout=0.05, # Default 0;  regularization withing LoRA
    bias="none", # Default None; base model bias not modified
    task_type="CAUSAL_LM", # Default "Causal_LM"; type is LLM
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj"]) # Default None; base model modules to which loRA is applied

# %%
# instruction
instruction = "Classify the following product review into one of: negative, neutral, positive."

# %%
# set x and y variables for evaluation
# Note: Does not affect train (uses always train data and val data) but only evaluation metrics
x = test["text"] # choose from: val["text"], test["text"]
y = test["label3"] # choose from: val["label3"], test["label3"]

# %%
# create instance of model
model_llama_lora = LlamaLoraModel(model_name, quant_config, peft_config, instruction)
# Out:
# model.safetensors.index.json:   0%|          | 0.00/20.9k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# trainable params: 4,587,520 || all params: 3,217,337,344 || trainable%: 0.1426
# tokenizer_config.json:   0%|          | 0.00/54.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]

# %%
# train model (measuring time)
t0 = time.perf_counter()

training_config = TrainingArguments(
    output_dir="outputs/llama3_lora_trainer",
    num_train_epochs=5, # default 3               # 1st prio hyperparameter
    per_device_train_batch_size=1, # default 8
    per_device_eval_batch_size=8, # default 8
    gradient_accumulation_steps=8,
    learning_rate=5e-5, # default 2e-4            # 1st prio hyperparameter
    logging_steps=10, # default 500
    eval_strategy="epoch", # default "no"
    save_strategy="epoch", # default "steps"
    load_best_model_at_end=True, # default False
    fp16=True, # default False
    report_to=[]) # defaulte None

model_llama_lora.train(
    x_train=train_bal["text"],
    y_train=cm.label3_num_to_txt(train_bal["label3"]),
    x_val=val["text"],
    y_val=cm.label3_num_to_txt(val["label3"]),
    training_config = training_config,
    text_token_limit=256)

t1 = time.perf_counter()
train_time_seconds = t1 - t0
train_time_per_sample = train_time_seconds / len(train_bal["label3"])
# Out:
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5000 [00:00<?, ? examples/s]
# {'loss': 6.8594, 'grad_norm': 15.936793327331543, 'learning_rate': 4.928e-05, 'epoch': 0.08}
# {'loss': 2.7598, 'grad_norm': 3.59028959274292, 'learning_rate': 4.8480000000000003e-05, 'epoch': 0.16}
# {'loss': 1.1723, 'grad_norm': 0.551435112953186, 'learning_rate': 4.7680000000000004e-05, 'epoch': 0.24}
# {'loss': 1.034, 'grad_norm': 0.43424978852272034, 'learning_rate': 4.688e-05, 'epoch': 0.32}
# {'loss': 1.0416, 'grad_norm': 0.3911057114601135, 'learning_rate': 4.608e-05, 'epoch': 0.4}
# {'loss': 0.7756, 'grad_norm': 0.4730430543422699, 'learning_rate': 4.528e-05, 'epoch': 0.48}
# {'loss': 0.73, 'grad_norm': 0.337384968996048, 'learning_rate': 4.448e-05, 'epoch': 0.56}
# {'loss': 0.7182, 'grad_norm': 0.30480819940567017, 'learning_rate': 4.368e-05, 'epoch': 0.64}
# {'loss': 0.8149, 'grad_norm': 0.3480333685874939, 'learning_rate': 4.288e-05, 'epoch': 0.72}
# {'loss': 0.6354, 'grad_norm': 0.24454089999198914, 'learning_rate': 4.2080000000000004e-05, 'epoch': 0.8}
# {'loss': 0.7045, 'grad_norm': 0.40039002895355225, 'learning_rate': 4.1280000000000005e-05, 'epoch': 0.88}
# {'loss': 0.6846, 'grad_norm': 0.272831529378891, 'learning_rate': 4.048e-05, 'epoch': 0.96}
# {'eval_loss': 0.6561797857284546, 'eval_runtime': 77.032, 'eval_samples_per_second': 64.908, 'eval_steps_per_second': 8.114, 'epoch': 1.0}
# {'loss': 0.75, 'grad_norm': 0.38876786828041077, 'learning_rate': 3.968e-05, 'epoch': 1.04}
# {'loss': 0.6644, 'grad_norm': 0.31592389941215515, 'learning_rate': 3.888e-05, 'epoch': 1.12}
# {'loss': 0.6095, 'grad_norm': 0.2782343327999115, 'learning_rate': 3.808e-05, 'epoch': 1.2}
# {'loss': 0.7269, 'grad_norm': 0.370659738779068, 'learning_rate': 3.728e-05, 'epoch': 1.28}
# {'loss': 0.615, 'grad_norm': 0.26230818033218384, 'learning_rate': 3.648e-05, 'epoch': 1.3599999999999999}
# {'loss': 0.6495, 'grad_norm': 0.38912034034729004, 'learning_rate': 3.5680000000000004e-05, 'epoch': 1.44}
# {'loss': 0.7952, 'grad_norm': 0.314205139875412, 'learning_rate': 3.4880000000000005e-05, 'epoch': 1.52}
# {'loss': 0.7137, 'grad_norm': 0.3335340917110443, 'learning_rate': 3.408e-05, 'epoch': 1.6}
# {'loss': 0.604, 'grad_norm': 0.27310696244239807, 'learning_rate': 3.328e-05, 'epoch': 1.6800000000000002}
# {'loss': 0.6502, 'grad_norm': 0.2945009768009186, 'learning_rate': 3.248e-05, 'epoch': 1.76}
# {'loss': 0.6688, 'grad_norm': 0.26047202944755554, 'learning_rate': 3.168e-05, 'epoch': 1.8399999999999999}
# {'loss': 0.6651, 'grad_norm': 0.29952767491340637, 'learning_rate': 3.088e-05, 'epoch': 1.92}
# {'loss': 0.6805, 'grad_norm': 0.2626144289970398, 'learning_rate': 3.0080000000000003e-05, 'epoch': 2.0}
# {'eval_loss': 0.6434295177459717, 'eval_runtime': 77.1205, 'eval_samples_per_second': 64.834, 'eval_steps_per_second': 8.104, 'epoch': 2.0}
# {'loss': 0.6635, 'grad_norm': 0.2809206247329712, 'learning_rate': 2.928e-05, 'epoch': 2.08}
# {'loss': 0.6156, 'grad_norm': 0.28537270426750183, 'learning_rate': 2.8480000000000002e-05, 'epoch': 2.16}
# {'loss': 0.6054, 'grad_norm': 0.2675229012966156, 'learning_rate': 2.768e-05, 'epoch': 2.24}
# {'loss': 0.5751, 'grad_norm': 0.31124812364578247, 'learning_rate': 2.688e-05, 'epoch': 2.32}
# {'loss': 0.7604, 'grad_norm': 0.31136554479599, 'learning_rate': 2.6079999999999998e-05, 'epoch': 2.4}
# {'loss': 0.8021, 'grad_norm': 0.42638474702835083, 'learning_rate': 2.5280000000000005e-05, 'epoch': 2.48}
# {'loss': 0.6795, 'grad_norm': 0.3620867133140564, 'learning_rate': 2.448e-05, 'epoch': 2.56}
# {'loss': 0.6585, 'grad_norm': 0.35099267959594727, 'learning_rate': 2.3680000000000004e-05, 'epoch': 2.64}
# {'loss': 0.6807, 'grad_norm': 0.34738266468048096, 'learning_rate': 2.288e-05, 'epoch': 2.7199999999999998}
# {'loss': 0.6482, 'grad_norm': 0.3465642035007477, 'learning_rate': 2.2080000000000002e-05, 'epoch': 2.8}
# {'loss': 0.6201, 'grad_norm': 0.2993046045303345, 'learning_rate': 2.128e-05, 'epoch': 2.88}
# {'loss': 0.6023, 'grad_norm': 0.37227630615234375, 'learning_rate': 2.048e-05, 'epoch': 2.96}
# {'eval_loss': 0.6394103765487671, 'eval_runtime': 77.2396, 'eval_samples_per_second': 64.734, 'eval_steps_per_second': 8.092, 'epoch': 3.0}
# {'loss': 0.7327, 'grad_norm': 0.3196587860584259, 'learning_rate': 1.968e-05, 'epoch': 3.04}
# {'loss': 0.7088, 'grad_norm': 0.3788161277770996, 'learning_rate': 1.888e-05, 'epoch': 3.12}
# {'loss': 0.7342, 'grad_norm': 0.37992674112319946, 'learning_rate': 1.808e-05, 'epoch': 3.2}
# {'loss': 0.6017, 'grad_norm': 0.3446827232837677, 'learning_rate': 1.728e-05, 'epoch': 3.2800000000000002}
# {'loss': 0.701, 'grad_norm': 0.338996559381485, 'learning_rate': 1.648e-05, 'epoch': 3.36}
# {'loss': 0.6111, 'grad_norm': 0.32250452041625977, 'learning_rate': 1.568e-05, 'epoch': 3.44}
# {'loss': 0.6686, 'grad_norm': 0.3894895911216736, 'learning_rate': 1.488e-05, 'epoch': 3.52}
# {'loss': 0.6124, 'grad_norm': 0.3445091247558594, 'learning_rate': 1.408e-05, 'epoch': 3.6}
# {'loss': 0.6717, 'grad_norm': 0.38585713505744934, 'learning_rate': 1.3280000000000002e-05, 'epoch': 3.68}
# {'loss': 0.7244, 'grad_norm': 0.3127853572368622, 'learning_rate': 1.248e-05, 'epoch': 3.76}
# {'loss': 0.6595, 'grad_norm': 0.34213536977767944, 'learning_rate': 1.168e-05, 'epoch': 3.84}
# {'loss': 0.5911, 'grad_norm': 0.394980788230896, 'learning_rate': 1.088e-05, 'epoch': 3.92}
# {'loss': 0.653, 'grad_norm': 0.3464833199977875, 'learning_rate': 1.008e-05, 'epoch': 4.0}
# {'eval_loss': 0.6374675035476685, 'eval_runtime': 77.2387, 'eval_samples_per_second': 64.734, 'eval_steps_per_second': 8.092, 'epoch': 4.0}
# {'loss': 0.7275, 'grad_norm': 0.42784595489501953, 'learning_rate': 9.28e-06, 'epoch': 4.08}
# {'loss': 0.5406, 'grad_norm': 0.3353572189807892, 'learning_rate': 8.48e-06, 'epoch': 4.16}
# {'loss': 0.7417, 'grad_norm': 0.39697933197021484, 'learning_rate': 7.68e-06, 'epoch': 4.24}
# {'loss': 0.6239, 'grad_norm': 0.32338830828666687, 'learning_rate': 6.88e-06, 'epoch': 4.32}
# {'loss': 0.6679, 'grad_norm': 0.3411354124546051, 'learning_rate': 6.08e-06, 'epoch': 4.4}
# {'loss': 0.6447, 'grad_norm': 0.34182336926460266, 'learning_rate': 5.28e-06, 'epoch': 4.48}
# {'loss': 0.6281, 'grad_norm': 0.412859171628952, 'learning_rate': 4.48e-06, 'epoch': 4.5600000000000005}
# {'loss': 0.6941, 'grad_norm': 0.49524644017219543, 'learning_rate': 3.68e-06, 'epoch': 4.64}
# {'loss': 0.7408, 'grad_norm': 0.4379242956638336, 'learning_rate': 2.88e-06, 'epoch': 4.72}
# {'loss': 0.6029, 'grad_norm': 0.3553641438484192, 'learning_rate': 2.08e-06, 'epoch': 4.8}
# {'loss': 0.5586, 'grad_norm': 0.31071576476097107, 'learning_rate': 1.28e-06, 'epoch': 4.88}
# {'loss': 0.7103, 'grad_norm': 0.4448640048503876, 'learning_rate': 4.8e-07, 'epoch': 4.96}
# {'eval_loss': 0.6368206739425659, 'eval_runtime': 76.9085, 'eval_samples_per_second': 65.012, 'eval_steps_per_second': 8.127, 'epoch': 5.0}
# {'train_runtime': 1654.8938, 'train_samples_per_second': 3.021, 'train_steps_per_second': 0.378, 'train_loss': 0.8239313232421875, 'epoch': 5.0}

# %%
# predict with model (measuring time)
t0 = time.perf_counter()

pred_txt = model_llama_lora.predict(
    x=x,
    text_token_limit=256,
    report_interval=100)

pred_num = cm.label3_txt_to_num(pred_txt)

t1 = time.perf_counter()
pred_time_seconds = t1 - t0
pred_time_per_sample = pred_time_seconds / len(pred_num)
# Out:
# Reviews processed: 100
# Reviews processed: 200
# Reviews processed: 300
# Reviews processed: 400
# Reviews processed: 500
# Reviews processed: 600
# Reviews processed: 700
# Reviews processed: 800
# Reviews processed: 900
# Reviews processed: 1000
# Reviews processed: 1100
# Reviews processed: 1200
# Reviews processed: 1300
# Reviews processed: 1400
# Reviews processed: 1500
# Reviews processed: 1600
# Reviews processed: 1700
# Reviews processed: 1800
# Reviews processed: 1900
# Reviews processed: 2000
# Reviews processed: 2100
# Reviews processed: 2200
# Reviews processed: 2300
# Reviews processed: 2400
# Reviews processed: 2500
# Reviews processed: 2600
# Reviews processed: 2700
# Reviews processed: 2800
# Reviews processed: 2900
# Reviews processed: 3000
# Reviews processed: 3100
# Reviews processed: 3200
# Reviews processed: 3300
# Reviews processed: 3400
# Reviews processed: 3500
# Reviews processed: 3600
# Reviews processed: 3700
# Reviews processed: 3800
# Reviews processed: 3900
# Reviews processed: 4000
# Reviews processed: 4100
# Reviews processed: 4200
# Reviews processed: 4300
# Reviews processed: 4400
# Reviews processed: 4500
# Reviews processed: 4600
# Reviews processed: 4700
# Reviews processed: 4800
# Reviews processed: 4900
# Reviews processed: 5000
# Reviews processed: 5100
# Reviews processed: 5200
# Reviews processed: 5300
# Reviews processed: 5400
# Reviews processed: 5500
# Reviews processed: 5600
# Reviews processed: 5700
# Reviews processed: 5800
# Reviews processed: 5900
# Reviews processed: 6000
# Reviews processed: 6100
# Reviews processed: 6200
# Reviews processed: 6300
# Reviews processed: 6400
# Reviews processed: 6500
# Reviews processed: 6600
# Reviews processed: 6700
# Reviews processed: 6800
# Reviews processed: 6900
# Reviews processed: 7000
# Reviews processed: 7100
# Reviews processed: 7200
# Reviews processed: 7300
# Reviews processed: 7400
# Reviews processed: 7500
# Reviews processed: 7600
# Reviews processed: 7700
# Reviews processed: 7800
# Reviews processed: 7900
# Reviews processed: 8000
# Reviews processed: 8100
# Reviews processed: 8200
# Reviews processed: 8300
# Reviews processed: 8400
# Reviews processed: 8500
# Reviews processed: 8600
# Reviews processed: 8700
# Reviews processed: 8800
# Reviews processed: 8900
# Reviews processed: 9000
# Reviews processed: 9100
# Reviews processed: 9200
# Reviews processed: 9300
# Reviews processed: 9400
# Reviews processed: 9500
# Reviews processed: 9600
# Reviews processed: 9700
# Reviews processed: 9800
# Reviews processed: 9900
# Reviews processed: 10000
# Reviews processed: 10100
# Reviews processed: 10200
# Reviews processed: 10300
# Reviews processed: 10400
# Reviews processed: 10500
# Reviews processed: 10600
# Reviews processed: 10700
# Reviews processed: 10800
# Reviews processed: 10900
# Reviews processed: 11000
# Reviews processed: 11100
# Reviews processed: 11200
# Reviews processed: 11300
# Reviews processed: 11400
# Reviews processed: 11500
# Reviews processed: 11600
# Reviews processed: 11700
# Reviews processed: 11800
# Reviews processed: 11900
# Reviews processed: 12000
# Reviews processed: 12100
# Reviews processed: 12200
# Reviews processed: 12300
# Reviews processed: 12400
# Reviews processed: 12500
# Reviews processed: 12600
# Reviews processed: 12700
# Reviews processed: 12800
# Reviews processed: 12900
# Reviews processed: 13000
# Reviews processed: 13100
# Reviews processed: 13200
# Reviews processed: 13300
# Reviews processed: 13400
# Reviews processed: 13500
# Reviews processed: 13600
# Reviews processed: 13700
# Reviews processed: 13800
# Reviews processed: 13900
# Reviews processed: 14000
# Reviews processed: 14100
# Reviews processed: 14200
# Reviews processed: 14300
# Reviews processed: 14400
# Reviews processed: 14500
# Reviews processed: 14600
# Reviews processed: 14700
# Reviews processed: 14800
# Reviews processed: 14900
# Reviews processed: 15000
# Reviews processed: 15100
# Reviews processed: 15200
# Reviews processed: 15300
# Reviews processed: 15400
# Reviews processed: 15500
# Reviews processed: 15600
# Reviews processed: 15700
# Reviews processed: 15800
# Reviews processed: 15900
# Reviews processed: 16000
# Reviews processed: 16100
# Reviews processed: 16200
# Reviews processed: 16300
# Reviews processed: 16400
# Reviews processed: 16500
# Reviews processed: 16600
# Reviews processed: 16700
# Reviews processed: 16800
# Reviews processed: 16900
# Reviews processed: 17000
# Reviews processed: 17100
# Reviews processed: 17200
# Reviews processed: 17300
# Reviews processed: 17400
# Reviews processed: 17500
# Reviews processed: 17600
# Reviews processed: 17700
# Reviews processed: 17800
# Reviews processed: 17900
# Reviews processed: 18000
# Reviews processed: 18100
# Reviews processed: 18200
# Reviews processed: 18300
# Reviews processed: 18400
# Reviews processed: 18500
# Reviews processed: 18600
# Reviews processed: 18700
# Reviews processed: 18800
# Reviews processed: 18900
# Reviews processed: 19000
# Reviews processed: 19100
# Reviews processed: 19200
# Reviews processed: 19300
# Reviews processed: 19400
# Reviews processed: 19500
# Reviews processed: 19600
# Reviews processed: 19700
# Reviews processed: 19800
# Reviews processed: 19900
# Reviews processed: 20000

# %%
# sanity check: accuracy
acc = sum(y == pred_num) / len(pred_num)
print(f"acc cntrl: {acc}")
# Out:
# acc cntrl: 0.85895

# %%
# create a run directory (analogous to KP)
hyperparams = {
    "learning_rate": training_config.learning_rate,
    "train_batch_size": training_config.per_device_train_batch_size,
    "epochs": training_config.num_train_epochs }

run_outdir = utils.make_run_dir(
    output_root="outputs",
    model_name=f"{model_name}_lora_finetuned",
    hyperparams=hyperparams)

print("run_outdir:", run_outdir)
# Out:
# run_outdir: outputs/meta-llama_Llama-3.2-3B-Instruct_lora_finetuned_lr5e-05_bs1_ep5_20251210_023517

# %%
# save model and trainig

# save model weights
model_llama_lora.trainer.save_model(run_outdir)

# save tokenizer
model_llama_lora.tokenizer.save_pretrained(run_outdir)

# save training log_history as csv
log_df = pd.DataFrame(model_llama_lora.log_history)
log_df.to_csv(os.path.join(run_outdir, "training_log_history.csv"), index=False)

# save train_result metrics as JSON
train_result = model_llama_lora.train_result
with open(os.path.join(run_outdir, "train_result.json"), "w") as f:
    # train_result is a TrainOutput; .metrics is usually what you care about
    json.dump(train_result.metrics, f, indent=2)

# %% [markdown]
# # Evaluate Results/ Experiment

# %%
# loss curves on training and validation data (incl. saving)
logs = pd.DataFrame(model_llama_lora.log_history)

train_loss = logs[["epoch", "loss"]].dropna()
eval_loss  = logs[["epoch", "eval_loss"]].dropna()

plt.figure(figsize=(10,6))
plt.plot(train_loss["epoch"], train_loss["loss"], '-o', markersize=6, label="train_loss")
plt.plot(eval_loss["epoch"], eval_loss["eval_loss"], '-o', markersize=6, label="eval_loss")

plt.xlabel("epoch")
plt.ylabel("loss")
plt.title("Training & Validation Loss per Epoch")
plt.legend()
plt.grid(True)

plt.savefig(os.path.join(run_outdir, "loss_curves_epoch.png"), bbox_inches="tight")
plt.show()

# %%
# classification metrics (incl. saving classification report as csv)
metrics = utils.compute_classification_metrics_from_arrays(y_true=y, y_pred=pred_num)
df_cfreport = pd.DataFrame(metrics["classification report"]).T
print(df_cfreport)
path = os.path.join(run_outdir, "classification_report.csv")
df_cfreport.to_csv(path)
# Out:
#               precision    recall  f1-score      support
# 0              0.888112  0.798563  0.840960   4453.00000
# 1              0.367610  0.749714  0.493326   1750.00000
# 2              0.990665  0.892295  0.938911  13797.00000
# accuracy       0.858950  0.858950  0.858950      0.85895
# macro avg      0.748796  0.813524  0.757732  20000.00000
# weighted avg   0.913315  0.858950  0.878113  20000.00000

# %%
# confusion matrix (incl. saving)
cm = confusion_matrix(y_true=y, y_pred=pred_num)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
plt.figure(figsize=(6, 6))
disp.plot(values_format='d')
plt.title(f"Confusion Matrix (Llama model)")
path = os.path.join(run_outdir, "confusion_matrix.png")
plt.savefig(path, bbox_inches='tight')
plt.show()

# %%
# evaluate time
print("Training time in seconds:", train_time_seconds)
print("Training time per sample:", train_time_per_sample)
print("Prediction time in seconds:", pred_time_seconds)
print("Prediction time per sample:", pred_time_per_sample)
# Out:
# Training time in seconds: 1670.239804662
# Training time per sample: 1.6702398046620002
# Prediction time in seconds: 3348.888261399
# Prediction time per sample: 0.16744441306995

# %%
# saving results in team_comparison_results
results_comparison = {
    "n_samples": len(x),
    "train_seconds": train_time_seconds,
    "pred_time_seconds": pred_time_seconds,
    "pred_time_per_sample": pred_time_per_sample,
    "metrics": metrics}

utils.save_results_csv(
    results=results_comparison,
    csv_path=os.path.join("outputs", "team_comparison_results.csv"),
    model_name=f"{model_name}_zeroshot",
    extra_info={"run_outdir": run_outdir})
# Out:
# Appended results to outputs/team_comparison_results.csv

# %%
# saving all results in dictionary
results_all = results_comparison
results_all["train_time_seconds"] = train_time_seconds,
results_all["train_time_per_sample"] = train_time_per_sample,
results_all["model"] = f"{model_name}_zeroshot",
results_all["instruction"] = instruction
path = os.path.join(run_outdir, "results_all.json")
with open(path, "w") as f:
    json.dump(results_all, f, indent=2)
