# %% [markdown]
# # Preliminaries and Imports

# %% [markdown]
# Notes:
# - In case of error "BitsAndBytes requires update": The update is already implemented in the notebook. "Restart the session" and "Run all" again because the update seems to require a restart

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# system and path set up
import os
import sys

# path
GOOGLE_DRIVE_PATH = os.path.join('/content', 'drive', 'My Drive', 'ColabNotebooks', 'DL','Deep Learning Project Full','DL Team Project', '20251126_22.47_DL_Team_Project_Code_Files_Structure')

# set working directory (for saving/ loading)
os.chdir(GOOGLE_DRIVE_PATH)

# set import path (for importing src/)
sys.path.insert(0, GOOGLE_DRIVE_PATH)

# verify
print("Current working directory:", os.getcwd())
print("Current import directory:", sys.path[0])
# Out:
# Current working directory: /content/drive/My Drive/ColabNotebooks/DL/Deep Learning Project Full/DL Team Project/20251126_22.47_DL_Team_Project_Code_Files_Structure
# Current import directory: /content/drive/My Drive/ColabNotebooks/DL/Deep Learning Project Full/DL Team Project/20251126_22.47_DL_Team_Project_Code_Files_Structure

# %%
# log into HF
# note: previously store your key as secret (key symbol on the left)
from google.colab import userdata
hf_token = userdata.get('HF_TOKEN')

from huggingface_hub import login
login(token=hf_token)

# Option: silence all HF logs
from transformers.utils.logging import set_verbosity_error
set_verbosity_error()

# %%
# install libraries (only once and then comment out)
# !pip install -q "transformers>=4.40.0" accelerate datasets peft bitsandbytes trl
# !pip install -q -U bitsandbytes transformers accelerate peft trl

# %%
# import standard libraries
import pandas as pd
import time
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import json
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, TrainingArguments
import torch
from peft import LoraConfig

# import utils
from src import utils

# import model
from src.model_llama_lora import CommonMethods, LlamaBaseModel, LlamaLoraModel

# create instance object of CommonMethods
cm = CommonMethods()

# %%
# set seed for reproduceibility (Note: does not work for OpenAI)
seed = 42

# %% [markdown]
# # Load and prepare data

# %%
# load pre-processed data
csv_path_train_data = f"{GOOGLE_DRIVE_PATH}/data/data_train.csv"
csv_path_val_data = f"{GOOGLE_DRIVE_PATH}/data/data_val.csv"
csv_path_test_data = f"{GOOGLE_DRIVE_PATH}/data/data_test.csv"

train_bal = pd.read_csv(csv_path_train_data)
val = pd.read_csv(csv_path_val_data)
test = pd.read_csv(csv_path_test_data)

# %%
# keep only needed columns (drop lang and label5)
train_bal = train_bal.drop(columns=["label5","lang"])
val = val.drop(columns=["label5","lang"])
test = test.drop(columns=["label5","lang"])

# %%
# downsample data
# Note: Fine-tuning on full data would take too long
train_bal = train_bal.sample(n=5000, random_state=seed)
val = val.sample(n=5000, random_state=seed)
test = test.sample(n=20000, random_state=seed)

# %% [markdown]
# # Run model/ Experiment

# %% [markdown]
# Specify model:
# - Choose model type
# - quant_config (= hyperparameters)
# - lora_config (= hyperparameters)
# - training_config (= hyperparameters)
# - Instruction (= hyperparameters)
#
# Specify data for evaluation:
# - val data: for tuning
# - test data: for final run

# %%
# choose model
model_name = "meta-llama/Llama-3.2-3B-Instruct" # "meta-llama/Meta-Llama-3-8B-Instruct"

# %%
# set quantification configuration
quant_config = BitsAndBytesConfig(
    load_in_4_bit=True,
    bnb_4bit_use_double_quant=False,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16)

# %%
peft_config = LoraConfig(
    r=8, # Default 8; size of low-rank update matrice; higher r --> larger trainable capacity                              # 1st prio hyperparameter
    lora_alpha=8, # Default 8;  scaling of loRA updates before adding to base model; higher alpha --> higher loRA effect   # 1st prio hyperparameter
    lora_dropout=0, # Default 0;  regularization withing LoRA
    bias="none", # Default None; base model bias not modified
    task_type="CAUSAL_LM", # Default "Causal_LM"; type is LLM
    target_modules=None) # Default None; base model modules to which loRA is applied

# %%
# instruction
instruction = "Classify the following product review into one of: negative, neutral, positive."

# %%
# set x and y variables for evaluation
# Note: Does not affect train (uses always train data and val data) but only evaluation metrics
x = val["text"] # choose from: val["text"], test["text"]
y = val["label3"] # choose from: val["label3"], test["label3"]

# %%
# create instance of model
model_llama_lora = LlamaLoraModel(model_name, quant_config, peft_config, instruction)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# trainable params: 2,293,760 || all params: 3,215,043,584 || trainable%: 0.0713

# %%
# train model (measuring time)
t0 = time.perf_counter()

training_config = TrainingArguments(
    output_dir="outputs/llama3_lora_trainer",
    num_train_epochs=5, # default 3               # 1st prio hyperparameter
    per_device_train_batch_size=8, # default 8
    per_device_eval_batch_size=8, # default 8
    gradient_accumulation_steps=1,
    learning_rate=5e-5, # default 5e-5            # 1st prio hyperparameter
    logging_steps=10, # default 500
    eval_strategy="epoch", # default "no"
    save_strategy="epoch", # default "steps"
    load_best_model_at_end=False, # default False
    fp16=False, # default False
    report_to=[]) # defaulte None

model_llama_lora.train(
    x_train=train_bal["text"],
    y_train=cm.label3_num_to_txt(train_bal["label3"]),
    x_val=val["text"],
    y_val=cm.label3_num_to_txt(val["label3"]),
    training_config = training_config,
    text_token_limit=256)

t1 = time.perf_counter()
train_time_seconds = t1 - t0
train_time_per_sample = train_time_seconds / len(train_bal["label3"])
# Out:
# Map:   0%|          | 0/5000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5000 [00:00<?, ? examples/s]
# {'loss': 7.1831, 'grad_norm': 8.787425994873047, 'learning_rate': 4.976e-05, 'epoch': 0.016}
# {'loss': 5.8727, 'grad_norm': 12.43466854095459, 'learning_rate': 4.9493333333333336e-05, 'epoch': 0.032}
# {'loss': 3.7386, 'grad_norm': 9.814266204833984, 'learning_rate': 4.9226666666666674e-05, 'epoch': 0.048}
# {'loss': 1.6588, 'grad_norm': 2.0175797939300537, 'learning_rate': 4.896e-05, 'epoch': 0.064}
# {'loss': 1.0113, 'grad_norm': 0.3721306324005127, 'learning_rate': 4.869333333333334e-05, 'epoch': 0.08}
# {'loss': 1.0367, 'grad_norm': 0.35515615344047546, 'learning_rate': 4.842666666666667e-05, 'epoch': 0.096}
# {'loss': 0.8936, 'grad_norm': 0.33428755402565, 'learning_rate': 4.816e-05, 'epoch': 0.112}
# {'loss': 0.911, 'grad_norm': 0.29538494348526, 'learning_rate': 4.789333333333334e-05, 'epoch': 0.128}
# {'loss': 0.8682, 'grad_norm': 0.28005847334861755, 'learning_rate': 4.762666666666667e-05, 'epoch': 0.144}
# {'loss': 0.8228, 'grad_norm': 0.30125942826271057, 'learning_rate': 4.736000000000001e-05, 'epoch': 0.16}
# {'loss': 0.7952, 'grad_norm': 0.2936726212501526, 'learning_rate': 4.709333333333333e-05, 'epoch': 0.176}
# {'loss': 0.8836, 'grad_norm': 0.3870841860771179, 'learning_rate': 4.682666666666667e-05, 'epoch': 0.192}
# {'loss': 0.7451, 'grad_norm': 0.3290863037109375, 'learning_rate': 4.656e-05, 'epoch': 0.208}
# {'loss': 0.7299, 'grad_norm': 0.2375943660736084, 'learning_rate': 4.629333333333333e-05, 'epoch': 0.224}
# {'loss': 0.6745, 'grad_norm': 0.2241896539926529, 'learning_rate': 4.602666666666667e-05, 'epoch': 0.24}
# {'loss': 0.7354, 'grad_norm': 0.1845131367444992, 'learning_rate': 4.576e-05, 'epoch': 0.256}
# {'loss': 0.6539, 'grad_norm': 0.3096049726009369, 'learning_rate': 4.549333333333334e-05, 'epoch': 0.272}
# {'loss': 0.7561, 'grad_norm': 0.1931149661540985, 'learning_rate': 4.5226666666666665e-05, 'epoch': 0.288}
# {'loss': 0.703, 'grad_norm': 0.18231472373008728, 'learning_rate': 4.496e-05, 'epoch': 0.304}
# {'loss': 0.6952, 'grad_norm': 0.20660458505153656, 'learning_rate': 4.4693333333333335e-05, 'epoch': 0.32}
# {'loss': 0.6343, 'grad_norm': 0.17471584677696228, 'learning_rate': 4.4426666666666666e-05, 'epoch': 0.336}
# {'loss': 0.7258, 'grad_norm': 0.21506159007549286, 'learning_rate': 4.4160000000000004e-05, 'epoch': 0.352}
# {'loss': 0.8072, 'grad_norm': 0.27297788858413696, 'learning_rate': 4.3893333333333335e-05, 'epoch': 0.368}
# {'loss': 0.7081, 'grad_norm': 0.23186403512954712, 'learning_rate': 4.3626666666666674e-05, 'epoch': 0.384}
# {'loss': 0.628, 'grad_norm': 0.28268930315971375, 'learning_rate': 4.336e-05, 'epoch': 0.4}
# {'loss': 0.6982, 'grad_norm': 0.2079349309206009, 'learning_rate': 4.3093333333333336e-05, 'epoch': 0.416}
# {'loss': 0.6639, 'grad_norm': 0.2615966796875, 'learning_rate': 4.282666666666667e-05, 'epoch': 0.432}
# {'loss': 0.6285, 'grad_norm': 0.2229573279619217, 'learning_rate': 4.256e-05, 'epoch': 0.448}
# {'loss': 0.6434, 'grad_norm': 0.22564665973186493, 'learning_rate': 4.229333333333334e-05, 'epoch': 0.464}
# {'loss': 0.6466, 'grad_norm': 0.1829300820827484, 'learning_rate': 4.202666666666667e-05, 'epoch': 0.48}
# {'loss': 0.7412, 'grad_norm': 0.29278963804244995, 'learning_rate': 4.176000000000001e-05, 'epoch': 0.496}
# {'loss': 0.7935, 'grad_norm': 0.24369098246097565, 'learning_rate': 4.149333333333333e-05, 'epoch': 0.512}
# {'loss': 0.677, 'grad_norm': 0.20526105165481567, 'learning_rate': 4.122666666666667e-05, 'epoch': 0.528}
# {'loss': 0.6721, 'grad_norm': 0.2094501256942749, 'learning_rate': 4.096e-05, 'epoch': 0.544}
# {'loss': 0.8549, 'grad_norm': 0.2368311733007431, 'learning_rate': 4.069333333333333e-05, 'epoch': 0.56}
# {'loss': 0.6748, 'grad_norm': 0.23109769821166992, 'learning_rate': 4.042666666666667e-05, 'epoch': 0.576}
# {'loss': 0.7042, 'grad_norm': 0.1955091506242752, 'learning_rate': 4.016e-05, 'epoch': 0.592}
# {'loss': 0.5173, 'grad_norm': 0.1857827752828598, 'learning_rate': 3.989333333333333e-05, 'epoch': 0.608}
# {'loss': 0.7608, 'grad_norm': 0.21626578271389008, 'learning_rate': 3.9626666666666664e-05, 'epoch': 0.624}
# {'loss': 0.779, 'grad_norm': 0.4079822897911072, 'learning_rate': 3.936e-05, 'epoch': 0.64}
# {'loss': 0.6054, 'grad_norm': 0.22245801985263824, 'learning_rate': 3.9093333333333334e-05, 'epoch': 0.656}
# {'loss': 0.6341, 'grad_norm': 0.25070735812187195, 'learning_rate': 3.8826666666666665e-05, 'epoch': 0.672}
# {'loss': 0.7715, 'grad_norm': 0.2542841136455536, 'learning_rate': 3.8560000000000004e-05, 'epoch': 0.688}
# {'loss': 0.6325, 'grad_norm': 0.2271621972322464, 'learning_rate': 3.8293333333333335e-05, 'epoch': 0.704}
# {'loss': 0.6523, 'grad_norm': 0.25798043608665466, 'learning_rate': 3.8026666666666666e-05, 'epoch': 0.72}
# {'loss': 0.6681, 'grad_norm': 0.2689685523509979, 'learning_rate': 3.776e-05, 'epoch': 0.736}
# {'loss': 0.6746, 'grad_norm': 0.20948974788188934, 'learning_rate': 3.7493333333333336e-05, 'epoch': 0.752}
# {'loss': 0.729, 'grad_norm': 0.2227267175912857, 'learning_rate': 3.7226666666666674e-05, 'epoch': 0.768}
# {'loss': 0.6662, 'grad_norm': 0.19146065413951874, 'learning_rate': 3.696e-05, 'epoch': 0.784}
# {'loss': 0.7225, 'grad_norm': 0.20594792068004608, 'learning_rate': 3.669333333333334e-05, 'epoch': 0.8}
# {'loss': 0.62, 'grad_norm': 0.16595330834388733, 'learning_rate': 3.642666666666667e-05, 'epoch': 0.816}
# {'loss': 0.6228, 'grad_norm': 0.2494630217552185, 'learning_rate': 3.616e-05, 'epoch': 0.832}
# {'loss': 0.7191, 'grad_norm': 0.21749773621559143, 'learning_rate': 3.589333333333334e-05, 'epoch': 0.848}
# {'loss': 0.7568, 'grad_norm': 0.2326107621192932, 'learning_rate': 3.562666666666667e-05, 'epoch': 0.864}
# {'loss': 0.6127, 'grad_norm': 0.2745961546897888, 'learning_rate': 3.536000000000001e-05, 'epoch': 0.88}
# {'loss': 0.7741, 'grad_norm': 0.24283769726753235, 'learning_rate': 3.509333333333333e-05, 'epoch': 0.896}
# {'loss': 0.6508, 'grad_norm': 0.27261045575141907, 'learning_rate': 3.482666666666667e-05, 'epoch': 0.912}
# {'loss': 0.6466, 'grad_norm': 0.2023668885231018, 'learning_rate': 3.456e-05, 'epoch': 0.928}
# {'loss': 0.597, 'grad_norm': 0.24023011326789856, 'learning_rate': 3.429333333333333e-05, 'epoch': 0.944}
# {'loss': 0.62, 'grad_norm': 0.23186585307121277, 'learning_rate': 3.402666666666667e-05, 'epoch': 0.96}
# {'loss': 0.6489, 'grad_norm': 0.24659216403961182, 'learning_rate': 3.376e-05, 'epoch': 0.976}
# {'loss': 0.7225, 'grad_norm': 0.2931024134159088, 'learning_rate': 3.349333333333334e-05, 'epoch': 0.992}
# {'eval_loss': 0.6418963670730591, 'eval_runtime': 238.354, 'eval_samples_per_second': 20.977, 'eval_steps_per_second': 2.622, 'epoch': 1.0}
# {'loss': 0.7783, 'grad_norm': 0.27293816208839417, 'learning_rate': 3.3226666666666665e-05, 'epoch': 1.008}
# {'loss': 0.6389, 'grad_norm': 0.1910407543182373, 'learning_rate': 3.296e-05, 'epoch': 1.024}
# {'loss': 0.6998, 'grad_norm': 0.21177951991558075, 'learning_rate': 3.2693333333333334e-05, 'epoch': 1.04}
# {'loss': 0.6615, 'grad_norm': 0.20200221240520477, 'learning_rate': 3.2426666666666666e-05, 'epoch': 1.056}
# {'loss': 0.6844, 'grad_norm': 0.22416390478610992, 'learning_rate': 3.2160000000000004e-05, 'epoch': 1.072}
# {'loss': 0.7146, 'grad_norm': 0.27227041125297546, 'learning_rate': 3.1893333333333335e-05, 'epoch': 1.088}
# {'loss': 0.641, 'grad_norm': 0.2949507236480713, 'learning_rate': 3.1626666666666667e-05, 'epoch': 1.104}
# {'loss': 0.6675, 'grad_norm': 0.23471900820732117, 'learning_rate': 3.136e-05, 'epoch': 1.12}
# {'loss': 0.7372, 'grad_norm': 0.2655414342880249, 'learning_rate': 3.1093333333333336e-05, 'epoch': 1.1360000000000001}
# {'loss': 0.7081, 'grad_norm': 0.34175431728363037, 'learning_rate': 3.082666666666667e-05, 'epoch': 1.152}
# {'loss': 0.645, 'grad_norm': 0.27573758363723755, 'learning_rate': 3.056e-05, 'epoch': 1.168}
# {'loss': 0.658, 'grad_norm': 0.21206580102443695, 'learning_rate': 3.0293333333333334e-05, 'epoch': 1.184}
# {'loss': 0.676, 'grad_norm': 0.2853478491306305, 'learning_rate': 3.0026666666666668e-05, 'epoch': 1.2}
# {'loss': 0.6779, 'grad_norm': 0.25171399116516113, 'learning_rate': 2.976e-05, 'epoch': 1.216}
# {'loss': 0.6144, 'grad_norm': 0.2366708517074585, 'learning_rate': 2.9493333333333334e-05, 'epoch': 1.232}
# {'loss': 0.6499, 'grad_norm': 0.27522531151771545, 'learning_rate': 2.922666666666667e-05, 'epoch': 1.248}
# {'loss': 0.6765, 'grad_norm': 0.22180022299289703, 'learning_rate': 2.8960000000000004e-05, 'epoch': 1.264}
# {'loss': 0.5789, 'grad_norm': 0.2764124572277069, 'learning_rate': 2.8693333333333332e-05, 'epoch': 1.28}
# {'loss': 0.621, 'grad_norm': 0.23668061196804047, 'learning_rate': 2.8426666666666667e-05, 'epoch': 1.296}
# {'loss': 0.6416, 'grad_norm': 0.2661909759044647, 'learning_rate': 2.816e-05, 'epoch': 1.312}
# {'loss': 0.5423, 'grad_norm': 0.20706892013549805, 'learning_rate': 2.7893333333333333e-05, 'epoch': 1.328}
# {'loss': 0.687, 'grad_norm': 0.20381233096122742, 'learning_rate': 2.7626666666666668e-05, 'epoch': 1.3439999999999999}
# {'loss': 0.7366, 'grad_norm': 0.2922925651073456, 'learning_rate': 2.7360000000000002e-05, 'epoch': 1.3599999999999999}
# {'loss': 0.6683, 'grad_norm': 0.23894457519054413, 'learning_rate': 2.7093333333333337e-05, 'epoch': 1.376}
# {'loss': 0.7003, 'grad_norm': 0.28802376985549927, 'learning_rate': 2.6826666666666665e-05, 'epoch': 1.392}
# {'loss': 0.6809, 'grad_norm': 0.27518972754478455, 'learning_rate': 2.6560000000000003e-05, 'epoch': 1.408}
# {'loss': 0.7023, 'grad_norm': 0.24180206656455994, 'learning_rate': 2.6293333333333338e-05, 'epoch': 1.424}
# {'loss': 0.6954, 'grad_norm': 0.29104873538017273, 'learning_rate': 2.6026666666666666e-05, 'epoch': 1.44}
# {'loss': 0.6122, 'grad_norm': 0.25256580114364624, 'learning_rate': 2.576e-05, 'epoch': 1.456}
# {'loss': 0.7027, 'grad_norm': 0.2533634603023529, 'learning_rate': 2.5493333333333335e-05, 'epoch': 1.472}
# {'loss': 0.5853, 'grad_norm': 0.2629668712615967, 'learning_rate': 2.5226666666666663e-05, 'epoch': 1.488}
# {'loss': 0.6653, 'grad_norm': 0.3126869201660156, 'learning_rate': 2.496e-05, 'epoch': 1.504}
# {'loss': 0.7537, 'grad_norm': 0.2916260063648224, 'learning_rate': 2.4693333333333336e-05, 'epoch': 1.52}
# {'loss': 0.6674, 'grad_norm': 0.2628990113735199, 'learning_rate': 2.4426666666666668e-05, 'epoch': 1.536}
# {'loss': 0.6519, 'grad_norm': 0.22796332836151123, 'learning_rate': 2.4160000000000002e-05, 'epoch': 1.552}
# {'loss': 0.6338, 'grad_norm': 0.23446540534496307, 'learning_rate': 2.3893333333333334e-05, 'epoch': 1.568}
# {'loss': 0.6249, 'grad_norm': 0.24385733902454376, 'learning_rate': 2.362666666666667e-05, 'epoch': 1.584}
# {'loss': 0.7021, 'grad_norm': 0.3027934730052948, 'learning_rate': 2.336e-05, 'epoch': 1.6}
# {'loss': 0.601, 'grad_norm': 0.2568199932575226, 'learning_rate': 2.3093333333333335e-05, 'epoch': 1.616}
# {'loss': 0.6748, 'grad_norm': 0.34368711709976196, 'learning_rate': 2.282666666666667e-05, 'epoch': 1.6320000000000001}
# {'loss': 0.6024, 'grad_norm': 0.21945467591285706, 'learning_rate': 2.256e-05, 'epoch': 1.6480000000000001}
# {'loss': 0.6472, 'grad_norm': 0.31276100873947144, 'learning_rate': 2.2293333333333336e-05, 'epoch': 1.6640000000000001}
# {'loss': 0.6599, 'grad_norm': 0.26661574840545654, 'learning_rate': 2.2026666666666667e-05, 'epoch': 1.6800000000000002}
# {'loss': 0.77, 'grad_norm': 0.22354230284690857, 'learning_rate': 2.176e-05, 'epoch': 1.696}
# {'loss': 0.6072, 'grad_norm': 0.27453771233558655, 'learning_rate': 2.1493333333333333e-05, 'epoch': 1.712}
# {'loss': 0.6712, 'grad_norm': 0.34585070610046387, 'learning_rate': 2.1226666666666668e-05, 'epoch': 1.728}
# {'loss': 0.5998, 'grad_norm': 0.26579031348228455, 'learning_rate': 2.0960000000000003e-05, 'epoch': 1.744}
# {'loss': 0.639, 'grad_norm': 0.25216373801231384, 'learning_rate': 2.0693333333333334e-05, 'epoch': 1.76}
# {'loss': 0.6847, 'grad_norm': 0.33328214287757874, 'learning_rate': 2.042666666666667e-05, 'epoch': 1.776}
# {'loss': 0.6088, 'grad_norm': 0.260721892118454, 'learning_rate': 2.016e-05, 'epoch': 1.792}
# {'loss': 0.7501, 'grad_norm': 0.3411712646484375, 'learning_rate': 1.9893333333333335e-05, 'epoch': 1.808}
# {'loss': 0.6034, 'grad_norm': 0.23075662553310394, 'learning_rate': 1.962666666666667e-05, 'epoch': 1.8239999999999998}
# {'loss': 0.6907, 'grad_norm': 0.25510913133621216, 'learning_rate': 1.936e-05, 'epoch': 1.8399999999999999}
# {'loss': 0.658, 'grad_norm': 0.2493716925382614, 'learning_rate': 1.9093333333333336e-05, 'epoch': 1.8559999999999999}
# {'loss': 0.6852, 'grad_norm': 0.2649810016155243, 'learning_rate': 1.8826666666666667e-05, 'epoch': 1.8719999999999999}
# {'loss': 0.5974, 'grad_norm': 0.21162088215351105, 'learning_rate': 1.856e-05, 'epoch': 1.888}
# {'loss': 0.6713, 'grad_norm': 0.24481454491615295, 'learning_rate': 1.8293333333333333e-05, 'epoch': 1.904}
# {'loss': 0.5776, 'grad_norm': 0.2812366485595703, 'learning_rate': 1.8026666666666668e-05, 'epoch': 1.92}
# {'loss': 0.5894, 'grad_norm': 0.27634990215301514, 'learning_rate': 1.7760000000000003e-05, 'epoch': 1.936}
# {'loss': 0.7606, 'grad_norm': 0.3352680504322052, 'learning_rate': 1.7493333333333334e-05, 'epoch': 1.952}
# {'loss': 0.5651, 'grad_norm': 0.24383185803890228, 'learning_rate': 1.722666666666667e-05, 'epoch': 1.968}
# {'loss': 0.6706, 'grad_norm': 0.27767375111579895, 'learning_rate': 1.696e-05, 'epoch': 1.984}
# {'loss': 0.6952, 'grad_norm': 0.299600213766098, 'learning_rate': 1.669333333333333e-05, 'epoch': 2.0}
# {'eval_loss': 0.6349788308143616, 'eval_runtime': 238.1544, 'eval_samples_per_second': 20.995, 'eval_steps_per_second': 2.624, 'epoch': 2.0}
# {'loss': 0.6952, 'grad_norm': 0.3677462935447693, 'learning_rate': 1.6426666666666666e-05, 'epoch': 2.016}
# {'loss': 0.6482, 'grad_norm': 0.2965392470359802, 'learning_rate': 1.616e-05, 'epoch': 2.032}
# {'loss': 0.6791, 'grad_norm': 0.2580912709236145, 'learning_rate': 1.5893333333333336e-05, 'epoch': 2.048}
# {'loss': 0.6906, 'grad_norm': 0.2817522883415222, 'learning_rate': 1.5626666666666667e-05, 'epoch': 2.064}
# {'loss': 0.7036, 'grad_norm': 0.2424858659505844, 'learning_rate': 1.536e-05, 'epoch': 2.08}
# {'loss': 0.6711, 'grad_norm': 0.28333064913749695, 'learning_rate': 1.5093333333333335e-05, 'epoch': 2.096}
# {'loss': 0.7303, 'grad_norm': 0.26334524154663086, 'learning_rate': 1.4826666666666666e-05, 'epoch': 2.112}
# {'loss': 0.6006, 'grad_norm': 0.27510330080986023, 'learning_rate': 1.4560000000000001e-05, 'epoch': 2.128}
# {'loss': 0.5877, 'grad_norm': 0.24230389297008514, 'learning_rate': 1.4293333333333334e-05, 'epoch': 2.144}
# {'loss': 0.676, 'grad_norm': 0.2634976804256439, 'learning_rate': 1.4026666666666669e-05, 'epoch': 2.16}
# {'loss': 0.5601, 'grad_norm': 0.24615980684757233, 'learning_rate': 1.376e-05, 'epoch': 2.176}
# {'loss': 0.6368, 'grad_norm': 0.2610357403755188, 'learning_rate': 1.3493333333333333e-05, 'epoch': 2.192}
# {'loss': 0.6612, 'grad_norm': 0.2339770495891571, 'learning_rate': 1.3226666666666668e-05, 'epoch': 2.208}
# {'loss': 0.6639, 'grad_norm': 0.32228395342826843, 'learning_rate': 1.296e-05, 'epoch': 2.224}
# {'loss': 0.722, 'grad_norm': 0.2874007225036621, 'learning_rate': 1.2693333333333334e-05, 'epoch': 2.24}
# {'loss': 0.707, 'grad_norm': 0.2272302508354187, 'learning_rate': 1.2426666666666667e-05, 'epoch': 2.2560000000000002}
# {'loss': 0.6809, 'grad_norm': 0.271024614572525, 'learning_rate': 1.216e-05, 'epoch': 2.2720000000000002}
# {'loss': 0.6834, 'grad_norm': 0.3297746777534485, 'learning_rate': 1.1893333333333334e-05, 'epoch': 2.288}
# {'loss': 0.6687, 'grad_norm': 0.2906566560268402, 'learning_rate': 1.1626666666666668e-05, 'epoch': 2.304}
# {'loss': 0.6464, 'grad_norm': 0.27728521823883057, 'learning_rate': 1.1360000000000001e-05, 'epoch': 2.32}
# {'loss': 0.6995, 'grad_norm': 0.29926422238349915, 'learning_rate': 1.1093333333333333e-05, 'epoch': 2.336}
# {'loss': 0.7945, 'grad_norm': 0.27293065190315247, 'learning_rate': 1.0826666666666667e-05, 'epoch': 2.352}
# {'loss': 0.5844, 'grad_norm': 0.29584231972694397, 'learning_rate': 1.056e-05, 'epoch': 2.368}
# {'loss': 0.6601, 'grad_norm': 0.42830193042755127, 'learning_rate': 1.0293333333333334e-05, 'epoch': 2.384}
# {'loss': 0.6091, 'grad_norm': 0.22234416007995605, 'learning_rate': 1.0026666666666668e-05, 'epoch': 2.4}
# {'loss': 0.6489, 'grad_norm': 0.245616152882576, 'learning_rate': 9.760000000000001e-06, 'epoch': 2.416}
# {'loss': 0.604, 'grad_norm': 0.26112252473831177, 'learning_rate': 9.493333333333333e-06, 'epoch': 2.432}
# {'loss': 0.6933, 'grad_norm': 0.29764091968536377, 'learning_rate': 9.226666666666668e-06, 'epoch': 2.448}
# {'loss': 0.7935, 'grad_norm': 0.25276872515678406, 'learning_rate': 8.96e-06, 'epoch': 2.464}
# {'loss': 0.7023, 'grad_norm': 0.327089786529541, 'learning_rate': 8.693333333333334e-06, 'epoch': 2.48}
# {'loss': 0.6976, 'grad_norm': 0.29904353618621826, 'learning_rate': 8.426666666666667e-06, 'epoch': 2.496}
# {'loss': 0.5902, 'grad_norm': 0.2809382677078247, 'learning_rate': 8.160000000000001e-06, 'epoch': 2.512}
# {'loss': 0.6202, 'grad_norm': 0.2679344713687897, 'learning_rate': 7.893333333333333e-06, 'epoch': 2.528}
# {'loss': 0.6543, 'grad_norm': 0.29026299715042114, 'learning_rate': 7.626666666666667e-06, 'epoch': 2.544}
# {'loss': 0.6267, 'grad_norm': 0.2830071449279785, 'learning_rate': 7.36e-06, 'epoch': 2.56}
# {'loss': 0.6898, 'grad_norm': 0.3563166856765747, 'learning_rate': 7.093333333333334e-06, 'epoch': 2.576}
# {'loss': 0.6785, 'grad_norm': 0.30294331908226013, 'learning_rate': 6.826666666666668e-06, 'epoch': 2.592}
# {'loss': 0.6767, 'grad_norm': 0.30023467540740967, 'learning_rate': 6.560000000000001e-06, 'epoch': 2.608}
# {'loss': 0.5219, 'grad_norm': 0.2513493001461029, 'learning_rate': 6.293333333333333e-06, 'epoch': 2.624}
# {'loss': 0.6106, 'grad_norm': 0.28023314476013184, 'learning_rate': 6.026666666666667e-06, 'epoch': 2.64}
# {'loss': 0.5645, 'grad_norm': 0.29160475730895996, 'learning_rate': 5.76e-06, 'epoch': 2.656}
# {'loss': 0.7126, 'grad_norm': 0.3045080602169037, 'learning_rate': 5.493333333333334e-06, 'epoch': 2.672}
# {'loss': 0.6237, 'grad_norm': 0.3175354599952698, 'learning_rate': 5.226666666666667e-06, 'epoch': 2.6879999999999997}
# {'loss': 0.6126, 'grad_norm': 0.2468211054801941, 'learning_rate': 4.96e-06, 'epoch': 2.7039999999999997}
# {'loss': 0.5842, 'grad_norm': 0.2816852629184723, 'learning_rate': 4.693333333333334e-06, 'epoch': 2.7199999999999998}
# {'loss': 0.5478, 'grad_norm': 0.2826518714427948, 'learning_rate': 4.426666666666667e-06, 'epoch': 2.7359999999999998}
# {'loss': 0.6852, 'grad_norm': 0.23458828032016754, 'learning_rate': 4.16e-06, 'epoch': 2.752}
# {'loss': 0.6582, 'grad_norm': 0.3136470317840576, 'learning_rate': 3.893333333333334e-06, 'epoch': 2.768}
# {'loss': 0.5695, 'grad_norm': 0.21240372955799103, 'learning_rate': 3.626666666666667e-06, 'epoch': 2.784}
# {'loss': 0.6214, 'grad_norm': 0.2827523648738861, 'learning_rate': 3.36e-06, 'epoch': 2.8}
# {'loss': 0.6356, 'grad_norm': 0.33426928520202637, 'learning_rate': 3.0933333333333335e-06, 'epoch': 2.816}
# {'loss': 0.5596, 'grad_norm': 0.23626787960529327, 'learning_rate': 2.8266666666666666e-06, 'epoch': 2.832}
# {'loss': 0.6313, 'grad_norm': 0.3694062829017639, 'learning_rate': 2.56e-06, 'epoch': 2.848}
# {'loss': 0.7178, 'grad_norm': 0.3595282733440399, 'learning_rate': 2.2933333333333335e-06, 'epoch': 2.864}
# {'loss': 0.5542, 'grad_norm': 0.21798790991306305, 'learning_rate': 2.0266666666666666e-06, 'epoch': 2.88}
# {'loss': 0.7328, 'grad_norm': 0.20848867297172546, 'learning_rate': 1.76e-06, 'epoch': 2.896}
# {'loss': 0.7713, 'grad_norm': 0.2831086218357086, 'learning_rate': 1.4933333333333334e-06, 'epoch': 2.912}
# {'loss': 0.6696, 'grad_norm': 0.30930769443511963, 'learning_rate': 1.2266666666666669e-06, 'epoch': 2.928}
# {'loss': 0.645, 'grad_norm': 0.35624465346336365, 'learning_rate': 9.6e-07, 'epoch': 2.944}
# {'loss': 0.6732, 'grad_norm': 0.25190621614456177, 'learning_rate': 6.933333333333333e-07, 'epoch': 2.96}
# {'loss': 0.6974, 'grad_norm': 0.29483747482299805, 'learning_rate': 4.2666666666666673e-07, 'epoch': 2.976}
# {'loss': 0.6022, 'grad_norm': 0.2725353240966797, 'learning_rate': 1.6e-07, 'epoch': 2.992}
# {'eval_loss': 0.6335442662239075, 'eval_runtime': 238.6219, 'eval_samples_per_second': 20.954, 'eval_steps_per_second': 2.619, 'epoch': 3.0}
# {'train_runtime': 2333.971, 'train_samples_per_second': 6.427, 'train_steps_per_second': 0.803, 'train_loss': 0.7607883422851562, 'epoch': 3.0}

# %%
# predict with model (measuring time)
t0 = time.perf_counter()

pred_txt = model_llama_lora.predict(
    x=x,
    text_token_limit=256,
    report_interval=100)

pred_num = cm.label3_txt_to_num(pred_txt)

t1 = time.perf_counter()
pred_time_seconds = t1 - t0
pred_time_per_sample = pred_time_seconds / len(pred_num)
# Out:
# Reviews processed: 100
# Reviews processed: 200
# Reviews processed: 300
# Reviews processed: 400
# Reviews processed: 500
# Reviews processed: 600
# Reviews processed: 700
# Reviews processed: 800
# Reviews processed: 900
# Reviews processed: 1000
# Reviews processed: 1100
# Reviews processed: 1200
# Reviews processed: 1300
# Reviews processed: 1400
# Reviews processed: 1500
# Reviews processed: 1600
# Reviews processed: 1700
# Reviews processed: 1800
# Reviews processed: 1900
# Reviews processed: 2000
# Reviews processed: 2100
# Reviews processed: 2200
# Reviews processed: 2300
# Reviews processed: 2400
# Reviews processed: 2500
# Reviews processed: 2600
# Reviews processed: 2700
# Reviews processed: 2800
# Reviews processed: 2900
# Reviews processed: 3000
# Reviews processed: 3100
# Reviews processed: 3200
# Reviews processed: 3300
# Reviews processed: 3400
# Reviews processed: 3500
# Reviews processed: 3600
# Reviews processed: 3700
# Reviews processed: 3800
# Reviews processed: 3900
# Reviews processed: 4000
# Reviews processed: 4100
# Reviews processed: 4200
# Reviews processed: 4300
# Reviews processed: 4400
# Reviews processed: 4500
# Reviews processed: 4600
# Reviews processed: 4700
# Reviews processed: 4800
# Reviews processed: 4900
# Reviews processed: 5000

# %%
# sanity check: accuracy
acc = sum(y == pred_num) / len(pred_num)
print(f"acc cntrl: {acc}")
# Out:
# acc cntrl: 0.875

# %%
# create a run directory (analogous to KP)
hyperparams = {
    "learning_rate": training_config.learning_rate,
    "train_batch_size": training_config.per_device_train_batch_size,
    "epochs": training_config.num_train_epochs }

run_outdir = utils.make_run_dir(
    output_root="outputs",
    model_name=f"{model_name}_lora_finetuned",
    hyperparams=hyperparams)

print("run_outdir:", run_outdir)
# Out:
# run_outdir: outputs/meta-llama_Llama-3.2-3B-Instruct_lora_finetuned_lr5e-05_bs8_ep3_20251205_122846

# %%
# save model and trainig

# save model weights
model_llama_lora.trainer.save_model(run_outdir)

# save tokenizer
model_llama_lora.tokenizer.save_pretrained(run_outdir)

# save training log_history as csv
log_df = pd.DataFrame(model_llama_lora.log_history)
log_df.to_csv(os.path.join(run_outdir, "training_log_history.csv"), index=False)

# save train_result metrics as JSON
train_result = model_llama_lora.train_result
with open(os.path.join(run_outdir, "train_result.json"), "w") as f:
    # train_result is a TrainOutput; .metrics is usually what you care about
    json.dump(train_result.metrics, f, indent=2)

# %% [markdown]
# # Evaluate Results/ Experiment

# %%
# loss curves on training and validation data (incl. saving)
logs = pd.DataFrame(model_llama_lora.log_history)

train_loss = logs[["epoch", "loss"]].dropna()
eval_loss  = logs[["epoch", "eval_loss"]].dropna()

plt.figure(figsize=(10,6))
plt.plot(train_loss["epoch"], train_loss["loss"], '-o', markersize=6, label="train_loss")
plt.plot(eval_loss["epoch"], eval_loss["eval_loss"], '-o', markersize=6, label="eval_loss")

plt.xlabel("epoch")
plt.ylabel("loss")
plt.title("Training & Validation Loss per Epoch")
plt.legend()
plt.grid(True)

plt.savefig(os.path.join(run_outdir, "loss_curves_epoch.png"), bbox_inches="tight")
plt.show()

# %%
# classification metrics (incl. saving classification report as csv)
metrics = utils.compute_classification_metrics_from_arrays(y_true=y, y_pred=pred_num)
df_cfreport = pd.DataFrame(metrics["classification report"]).T
print(df_cfreport)
path = os.path.join(run_outdir, "classification_report.csv")
df_cfreport.to_csv(path)
# Out:
#               precision    recall  f1-score   support
# 0              0.896289  0.829956  0.861848  1135.000
# 1              0.377863  0.720874  0.495826   412.000
# 2              0.991464  0.908196  0.948005  3453.000
# accuracy       0.875000  0.875000  0.875000     0.875
# macro avg      0.755205  0.819675  0.768560  5000.000
# weighted avg   0.919298  0.875000  0.891188  5000.000

# %%
# confusion matrix (incl. saving)
cm = confusion_matrix(y_true=y, y_pred=pred_num)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
plt.figure(figsize=(6, 6))
disp.plot(values_format='d')
plt.title(f"Confusion Matrix (Llama model)")
path = os.path.join(run_outdir, "confusion_matrix.png")
plt.savefig(path, bbox_inches='tight')
plt.show()

# %%
# evaluate time
print("Training time in seconds:", train_time_seconds)
print("Training time per sample:", train_time_per_sample)
print("Prediction time in seconds:", pred_time_seconds)
print("Prediction time per sample:", pred_time_per_sample)
# Out:
# Training time in seconds: 2349.3766315230005
# Training time per sample: 0.4698753263046001
# Prediction time in seconds: 744.2566189229983
# Prediction time per sample: 0.14885132378459967

# %%
# saving results in team_comparison_results
results_comparison = {
    "n_samples": len(x),
    "train_seconds": train_time_seconds,
    "pred_time_seconds": pred_time_seconds,
    "pred_time_per_sample": pred_time_per_sample,
    "metrics": metrics}

utils.save_results_csv(
    results=results_comparison,
    csv_path=os.path.join("outputs", "team_comparison_results.csv"),
    model_name=f"{model_name}_zeroshot",
    extra_info={"run_outdir": run_outdir})
# Out:
# Appended results to outputs/team_comparison_results.csv

# %%
# saving all results in dictionary
results_all = results_comparison
results_all["train_time_seconds"] = train_time_seconds,
results_all["train_time_per_sample"] = train_time_per_sample,
results_all["model"] = f"{model_name}_zeroshot",
results_all["instruction"] = instruction
path = os.path.join(run_outdir, "results_all.json")
with open(path, "w") as f:
    json.dump(results_all, f, indent=2)
