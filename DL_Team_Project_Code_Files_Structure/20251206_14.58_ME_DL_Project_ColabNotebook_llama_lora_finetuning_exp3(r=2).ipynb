# %% [markdown]
# # Preliminaries and Imports

# %% [markdown]
# Notes:
# - In case of error "BitsAndBytes requires update": The update is already implemented in the notebook. "Restart the session" and "Run all" again because the update seems to require a restart

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# system and path set up
import os
import sys

# path
GOOGLE_DRIVE_PATH = os.path.join('/content', 'drive', 'My Drive', 'ColabNotebooks', 'DL','Deep Learning Project Full','DL Team Project', '20251126_22.47_DL_Team_Project_Code_Files_Structure')

# set working directory (for saving/ loading)
os.chdir(GOOGLE_DRIVE_PATH)

# set import path (for importing src/)
sys.path.insert(0, GOOGLE_DRIVE_PATH)

# verify
print("Current working directory:", os.getcwd())
print("Current import directory:", sys.path[0])
# Out:
# Current working directory: /content/drive/My Drive/ColabNotebooks/DL/Deep Learning Project Full/DL Team Project/20251126_22.47_DL_Team_Project_Code_Files_Structure
# Current import directory: /content/drive/My Drive/ColabNotebooks/DL/Deep Learning Project Full/DL Team Project/20251126_22.47_DL_Team_Project_Code_Files_Structure

# %%
# log into HF
# note: previously store your key as secret (key symbol on the left)
from google.colab import userdata
hf_token = userdata.get('HF_TOKEN')

from huggingface_hub import login
login(token=hf_token)

# Option: silence all HF logs
from transformers.utils.logging import set_verbosity_error
set_verbosity_error()

# %%
# install libraries (only once and then comment out)
# !pip install -q "transformers>=4.40.0" accelerate datasets peft bitsandbytes trl
# !pip install -q -U bitsandbytes transformers accelerate peft trl

# %%
# import standard libraries
import pandas as pd
import time
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import json
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, TrainingArguments
import torch
from peft import LoraConfig

# import utils
from src import utils

# import model
from src.model_llama_lora import CommonMethods, LlamaBaseModel, LlamaLoraModel

# create instance object of CommonMethods
cm = CommonMethods()

# %%
# set seed for reproduceibility (Note: does not work for OpenAI)
seed = 42

# %% [markdown]
# # Load and prepare data

# %%
# load pre-processed data
csv_path_train_data = f"{GOOGLE_DRIVE_PATH}/data/data_train.csv"
csv_path_val_data = f"{GOOGLE_DRIVE_PATH}/data/data_val.csv"
csv_path_test_data = f"{GOOGLE_DRIVE_PATH}/data/data_test.csv"

train_bal = pd.read_csv(csv_path_train_data)
val = pd.read_csv(csv_path_val_data)
test = pd.read_csv(csv_path_test_data)

# %%
# keep only needed columns (drop lang and label5)
train_bal = train_bal.drop(columns=["label5","lang"])
val = val.drop(columns=["label5","lang"])
test = test.drop(columns=["label5","lang"])

# %%
# downsample data
# Note: Fine-tuning on full data would take too long
train_bal = train_bal.sample(n=5000, random_state=seed)
val = val.sample(n=5000, random_state=seed)
test = test.sample(n=20000, random_state=seed)

# %% [markdown]
# # Run model/ Experiment

# %% [markdown]
# Specify model:
# - Choose model type
# - quant_config (= hyperparameters)
# - lora_config (= hyperparameters)
# - training_config (= hyperparameters)
# - Instruction (= hyperparameters)
#
# Specify data for evaluation:
# - val data: for tuning
# - test data: for final run

# %%
# choose model
model_name = "meta-llama/Llama-3.2-3B-Instruct" # "meta-llama/Meta-Llama-3-8B-Instruct"

# %%
# set quantification configuration
quant_config = BitsAndBytesConfig(
    load_in_4_bit=True,
    bnb_4bit_use_double_quant=False,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16)

# %%
peft_config = LoraConfig(
    r=2, # Default 8; size of low-rank update matrice; higher r --> larger trainable capacity                              # 1st prio hyperparameter
    lora_alpha=8, # Default 8;  scaling of loRA updates before adding to base model; higher alpha --> higher loRA effect   # 1st prio hyperparameter
    lora_dropout=0, # Default 0;  regularization withing LoRA
    bias="none", # Default None; base model bias not modified
    task_type="CAUSAL_LM", # Default "Causal_LM"; type is LLM
    target_modules=None) # Default None; base model modules to which loRA is applied

# %%
# instruction
instruction = "Classify the following product review into one of: negative, neutral, positive."

# %%
# set x and y variables for evaluation
# Note: Does not affect train (uses always train data and val data) but only evaluation metrics
x = val["text"] # choose from: val["text"], test["text"]
y = val["label3"] # choose from: val["label3"], test["label3"]

# %%
# create instance of model
model_llama_lora = LlamaLoraModel(model_name, quant_config, peft_config, instruction)
# Out:
# model.safetensors.index.json:   0%|          | 0.00/20.9k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# trainable params: 573,440 || all params: 3,213,323,264 || trainable%: 0.0178
# tokenizer_config.json:   0%|          | 0.00/54.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]

# %%
# train model (measuring time)
t0 = time.perf_counter()

training_config = TrainingArguments(
    output_dir="outputs/llama3_lora_trainer",
    num_train_epochs=5, # default 3               # 1st prio hyperparameter
    per_device_train_batch_size=8, # default 8
    per_device_eval_batch_size=8, # default 8
    gradient_accumulation_steps=1,
    learning_rate=5e-5, # default 5e-5            # 1st prio hyperparameter
    logging_steps=10, # default 500
    eval_strategy="epoch", # default "no"
    save_strategy="epoch", # default "steps"
    load_best_model_at_end=False, # default False
    fp16=False, # default False
    report_to=[]) # defaulte None

model_llama_lora.train(
    x_train=train_bal["text"],
    y_train=cm.label3_num_to_txt(train_bal["label3"]),
    x_val=val["text"],
    y_val=cm.label3_num_to_txt(val["label3"]),
    training_config = training_config,
    text_token_limit=256)

t1 = time.perf_counter()
train_time_seconds = t1 - t0
train_time_per_sample = train_time_seconds / len(train_bal["label3"])
# Out:
# Map:   0%|          | 0/5000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5000 [00:00<?, ? examples/s]
# {'loss': 6.9588, 'grad_norm': 16.965431213378906, 'learning_rate': 4.9856000000000005e-05, 'epoch': 0.016}
# {'loss': 5.3399, 'grad_norm': 25.162511825561523, 'learning_rate': 4.969600000000001e-05, 'epoch': 0.032}
# {'loss': 3.0499, 'grad_norm': 16.961992263793945, 'learning_rate': 4.9536e-05, 'epoch': 0.048}
# {'loss': 1.4224, 'grad_norm': 2.7917816638946533, 'learning_rate': 4.9376e-05, 'epoch': 0.064}
# {'loss': 0.9891, 'grad_norm': 0.7295870184898376, 'learning_rate': 4.9216e-05, 'epoch': 0.08}
# {'loss': 1.0124, 'grad_norm': 0.6362000107765198, 'learning_rate': 4.9056e-05, 'epoch': 0.096}
# {'loss': 0.8561, 'grad_norm': 0.6044701337814331, 'learning_rate': 4.8896e-05, 'epoch': 0.112}
# {'loss': 0.8641, 'grad_norm': 0.6007744073867798, 'learning_rate': 4.8736e-05, 'epoch': 0.128}
# {'loss': 0.8103, 'grad_norm': 0.5627800822257996, 'learning_rate': 4.8576000000000004e-05, 'epoch': 0.144}
# {'loss': 0.7534, 'grad_norm': 0.8938375115394592, 'learning_rate': 4.8416e-05, 'epoch': 0.16}
# {'loss': 0.712, 'grad_norm': 0.6203697919845581, 'learning_rate': 4.8256e-05, 'epoch': 0.176}
# {'loss': 0.7119, 'grad_norm': 0.6670798659324646, 'learning_rate': 3.6096e-05, 'epoch': 1.392}
# {'loss': 0.6929, 'grad_norm': 0.6205133199691772, 'learning_rate': 3.5936e-05, 'epoch': 1.408}
# {'loss': 0.7146, 'grad_norm': 0.6053314805030823, 'learning_rate': 3.5776000000000004e-05, 'epoch': 1.424}
# {'loss': 0.7112, 'grad_norm': 0.6947365403175354, 'learning_rate': 3.5616e-05, 'epoch': 1.44}
# {'loss': 0.6247, 'grad_norm': 0.6085030436515808, 'learning_rate': 3.5456e-05, 'epoch': 1.456}
# {'loss': 0.7183, 'grad_norm': 0.5781111717224121, 'learning_rate': 3.5296e-05, 'epoch': 1.472}
# {'loss': 0.5967, 'grad_norm': 0.6670681238174438, 'learning_rate': 3.5136000000000004e-05, 'epoch': 1.488}
# {'loss': 0.6802, 'grad_norm': 0.7073060274124146, 'learning_rate': 3.4976000000000005e-05, 'epoch': 1.504}
# {'loss': 0.7706, 'grad_norm': 0.6132379174232483, 'learning_rate': 3.481600000000001e-05, 'epoch': 1.52}
# {'loss': 0.6819, 'grad_norm': 0.6522836089134216, 'learning_rate': 3.4656e-05, 'epoch': 1.536}
# {'loss': 0.6669, 'grad_norm': 0.5246537923812866, 'learning_rate': 3.4496e-05, 'epoch': 1.552}
# {'loss': 0.6493, 'grad_norm': 0.5614792704582214, 'learning_rate': 3.4336000000000005e-05, 'epoch': 1.568}
# {'loss': 0.639, 'grad_norm': 0.5554265975952148, 'learning_rate': 3.4176e-05, 'epoch': 1.584}
# {'loss': 0.7168, 'grad_norm': 0.7270873188972473, 'learning_rate': 3.4016e-05, 'epoch': 1.6}
# {'loss': 0.6122, 'grad_norm': 0.5685102939605713, 'learning_rate': 3.3856e-05, 'epoch': 1.616}
# {'loss': 0.6889, 'grad_norm': 0.7199272513389587, 'learning_rate': 3.3696e-05, 'epoch': 1.6320000000000001}
# {'loss': 0.6162, 'grad_norm': 0.48144710063934326, 'learning_rate': 3.3536e-05, 'epoch': 1.6480000000000001}
# {'loss': 0.6604, 'grad_norm': 0.6945096850395203, 'learning_rate': 3.3376e-05, 'epoch': 1.6640000000000001}
# {'loss': 0.6746, 'grad_norm': 0.6570962071418762, 'learning_rate': 3.3216e-05, 'epoch': 1.6800000000000002}
# {'loss': 0.785, 'grad_norm': 0.5301647782325745, 'learning_rate': 3.3056e-05, 'epoch': 1.696}
# {'loss': 0.622, 'grad_norm': 0.6639410257339478, 'learning_rate': 3.2896e-05, 'epoch': 1.712}
# {'loss': 0.6853, 'grad_norm': 0.7687994241714478, 'learning_rate': 3.2736e-05, 'epoch': 1.728}
# {'loss': 0.6133, 'grad_norm': 0.5499003529548645, 'learning_rate': 3.2576e-05, 'epoch': 1.744}
# {'loss': 0.6528, 'grad_norm': 0.5907993912696838, 'learning_rate': 3.2416e-05, 'epoch': 1.76}
# {'loss': 0.6989, 'grad_norm': 0.7558696866035461, 'learning_rate': 3.2256000000000004e-05, 'epoch': 1.776}
# {'loss': 0.6219, 'grad_norm': 0.6270163655281067, 'learning_rate': 3.2096000000000006e-05, 'epoch': 1.792}
# {'loss': 0.7679, 'grad_norm': 0.7715774774551392, 'learning_rate': 3.1936e-05, 'epoch': 1.808}
# {'loss': 0.6154, 'grad_norm': 0.5518029928207397, 'learning_rate': 3.1776e-05, 'epoch': 1.8239999999999998}
# {'loss': 0.7073, 'grad_norm': 0.5748929977416992, 'learning_rate': 3.1616000000000004e-05, 'epoch': 1.8399999999999999}
# {'loss': 0.6772, 'grad_norm': 0.5761876106262207, 'learning_rate': 3.1456000000000005e-05, 'epoch': 1.8559999999999999}
# {'loss': 0.7003, 'grad_norm': 0.6143711805343628, 'learning_rate': 3.1296e-05, 'epoch': 1.8719999999999999}
# {'loss': 0.6105, 'grad_norm': 0.5478923916816711, 'learning_rate': 3.1136e-05, 'epoch': 1.888}
# {'loss': 0.6852, 'grad_norm': 0.6233522891998291, 'learning_rate': 3.0975999999999996e-05, 'epoch': 1.904}
# {'loss': 0.5945, 'grad_norm': 0.6279942989349365, 'learning_rate': 3.0816e-05, 'epoch': 1.92}
# {'loss': 0.6038, 'grad_norm': 0.6848171353340149, 'learning_rate': 3.0656e-05, 'epoch': 1.936}
# {'loss': 0.7791, 'grad_norm': 0.7973659038543701, 'learning_rate': 3.0496e-05, 'epoch': 1.952}
# {'loss': 0.5781, 'grad_norm': 0.5339386463165283, 'learning_rate': 3.0336000000000002e-05, 'epoch': 1.968}
# {'loss': 0.6849, 'grad_norm': 0.7048583626747131, 'learning_rate': 3.0175999999999997e-05, 'epoch': 1.984}
# {'loss': 0.7127, 'grad_norm': 0.686185359954834, 'learning_rate': 3.0016e-05, 'epoch': 2.0}
# {'eval_loss': 0.6495372653007507, 'eval_runtime': 262.4923, 'eval_samples_per_second': 19.048, 'eval_steps_per_second': 2.381, 'epoch': 2.0}
# {'loss': 0.71, 'grad_norm': 0.7180131077766418, 'learning_rate': 2.9856e-05, 'epoch': 2.016}
# {'loss': 0.6611, 'grad_norm': 0.6766043901443481, 'learning_rate': 2.9696e-05, 'epoch': 2.032}
# {'loss': 0.697, 'grad_norm': 0.598447322845459, 'learning_rate': 2.9536000000000003e-05, 'epoch': 2.048}
# {'loss': 0.7058, 'grad_norm': 0.6510168313980103, 'learning_rate': 2.9376000000000005e-05, 'epoch': 2.064}
# {'loss': 0.7193, 'grad_norm': 0.5567392110824585, 'learning_rate': 2.9216e-05, 'epoch': 2.08}
# {'loss': 0.6868, 'grad_norm': 0.6321878433227539, 'learning_rate': 2.9056e-05, 'epoch': 2.096}
# {'loss': 0.7453, 'grad_norm': 0.5963432788848877, 'learning_rate': 2.8896000000000003e-05, 'epoch': 2.112}
# {'loss': 0.6144, 'grad_norm': 0.6186968684196472, 'learning_rate': 2.8736e-05, 'epoch': 2.128}
# {'loss': 0.5991, 'grad_norm': 0.5608662366867065, 'learning_rate': 2.8576000000000002e-05, 'epoch': 2.144}
# {'loss': 0.713, 'grad_norm': 0.7288023233413696, 'learning_rate': 2.0256e-05, 'epoch': 2.976}
# {'loss': 0.6122, 'grad_norm': 0.6120901703834534, 'learning_rate': 2.0096000000000002e-05, 'epoch': 2.992}
# {'eval_loss': 0.6482329964637756, 'eval_runtime': 262.4077, 'eval_samples_per_second': 19.054, 'eval_steps_per_second': 2.382, 'epoch': 3.0}
# {'loss': 0.7271, 'grad_norm': 0.5875492095947266, 'learning_rate': 1.9936e-05, 'epoch': 3.008}
# {'loss': 0.6594, 'grad_norm': 0.7118687033653259, 'learning_rate': 1.9776000000000002e-05, 'epoch': 3.024}
# {'loss': 0.6993, 'grad_norm': 0.8006024956703186, 'learning_rate': 1.9616e-05, 'epoch': 3.04}
# {'loss': 0.6074, 'grad_norm': 0.5837196111679077, 'learning_rate': 1.9456e-05, 'epoch': 3.056}
# {'loss': 0.7346, 'grad_norm': 0.6387975811958313, 'learning_rate': 1.9296e-05, 'epoch': 3.072}
# {'loss': 0.7202, 'grad_norm': 0.7073818445205688, 'learning_rate': 1.9136e-05, 'epoch': 3.088}
# {'loss': 0.6249, 'grad_norm': 0.5622135400772095, 'learning_rate': 1.8976000000000003e-05, 'epoch': 3.104}
# {'loss': 0.707, 'grad_norm': 0.7105121612548828, 'learning_rate': 1.8816e-05, 'epoch': 3.12}
# {'loss': 0.584, 'grad_norm': 0.6969535946846008, 'learning_rate': 1.8656000000000002e-05, 'epoch': 3.136}
# {'loss': 0.6181, 'grad_norm': 0.5991590023040771, 'learning_rate': 1.8496000000000004e-05, 'epoch': 3.152}
# {'loss': 0.6408, 'grad_norm': 0.6872228980064392, 'learning_rate': 1.8336000000000002e-05, 'epoch': 3.168}
# {'loss': 0.7321, 'grad_norm': 0.7466618418693542, 'learning_rate': 1.8176e-05, 'epoch': 3.184}
# {'loss': 0.6772, 'grad_norm': 0.9065269827842712, 'learning_rate': 1.8015999999999998e-05, 'epoch': 3.2}
# {'loss': 0.6828, 'grad_norm': 0.6989399790763855, 'learning_rate': 1.7856e-05, 'epoch': 3.216}
# {'loss': 0.7243, 'grad_norm': 0.6759354472160339, 'learning_rate': 1.7696e-05, 'epoch': 3.232}
# {'loss': 0.7825, 'grad_norm': 0.7331607937812805, 'learning_rate': 1.7536e-05, 'epoch': 3.248}
# {'loss': 0.7209, 'grad_norm': 0.8905534744262695, 'learning_rate': 1.7376e-05, 'epoch': 3.2640000000000002}
# {'loss': 0.6693, 'grad_norm': 0.8549261689186096, 'learning_rate': 1.7216000000000003e-05, 'epoch': 3.2800000000000002}
# {'loss': 0.7081, 'grad_norm': 0.7532680630683899, 'learning_rate': 1.7056e-05, 'epoch': 3.296}
# {'loss': 0.7712, 'grad_norm': 0.8242312073707581, 'learning_rate': 1.6896000000000002e-05, 'epoch': 3.312}
# {'loss': 0.6339, 'grad_norm': 0.5420533418655396, 'learning_rate': 1.6736e-05, 'epoch': 3.328}
# {'loss': 0.5972, 'grad_norm': 0.7369375228881836, 'learning_rate': 1.6576e-05, 'epoch': 3.344}
# {'loss': 0.7746, 'grad_norm': 0.7524803280830383, 'learning_rate': 1.6416e-05, 'epoch': 3.36}
# {'loss': 0.6507, 'grad_norm': 0.8215664625167847, 'learning_rate': 1.6256e-05, 'epoch': 3.376}
# {'loss': 0.6037, 'grad_norm': 0.6229498386383057, 'learning_rate': 1.6096e-05, 'epoch': 3.392}
# {'loss': 0.7138, 'grad_norm': 0.637704074382782, 'learning_rate': 1.5936e-05, 'epoch': 3.408}
# {'loss': 0.6281, 'grad_norm': 0.6540842652320862, 'learning_rate': 1.5776000000000003e-05, 'epoch': 3.424}
# {'loss': 0.7743, 'grad_norm': 0.7744565606117249, 'learning_rate': 1.5616e-05, 'epoch': 3.44}
# {'loss': 0.7203, 'grad_norm': 0.9026868939399719, 'learning_rate': 1.5456000000000002e-05, 'epoch': 3.456}
# {'loss': 0.656, 'grad_norm': 0.7721564173698425, 'learning_rate': 1.5296e-05, 'epoch': 3.472}
# {'loss': 0.6448, 'grad_norm': 0.904476523399353, 'learning_rate': 1.5136e-05, 'epoch': 3.488}
# {'loss': 0.6179, 'grad_norm': 0.5578061938285828, 'learning_rate': 1.4976000000000002e-05, 'epoch': 3.504}
# {'loss': 0.5754, 'grad_norm': 0.6209195256233215, 'learning_rate': 1.4816e-05, 'epoch': 3.52}
# {'loss': 0.6152, 'grad_norm': 0.6225125789642334, 'learning_rate': 1.4656e-05, 'epoch': 3.536}
# {'loss': 0.677, 'grad_norm': 0.6706283092498779, 'learning_rate': 1.4496000000000001e-05, 'epoch': 3.552}
# {'loss': 0.6527, 'grad_norm': 0.8289740085601807, 'learning_rate': 1.4336e-05, 'epoch': 3.568}
# {'loss': 0.6025, 'grad_norm': 0.6327376365661621, 'learning_rate': 1.4176000000000001e-05, 'epoch': 3.584}
# {'loss': 0.6369, 'grad_norm': 0.7786813974380493, 'learning_rate': 1.4016000000000001e-05, 'epoch': 3.6}
# {'loss': 0.5688, 'grad_norm': 0.5744998455047607, 'learning_rate': 1.3855999999999999e-05, 'epoch': 3.616}
# {'loss': 0.673, 'grad_norm': 0.6632472276687622, 'learning_rate': 1.3696e-05, 'epoch': 3.632}
# {'loss': 0.7041, 'grad_norm': 0.6886602640151978, 'learning_rate': 1.3536000000000002e-05, 'epoch': 3.648}
# {'loss': 0.7437, 'grad_norm': 0.8930050134658813, 'learning_rate': 1.3376e-05, 'epoch': 3.664}
# {'loss': 0.6771, 'grad_norm': 0.7337360978126526, 'learning_rate': 1.3216e-05, 'epoch': 3.68}
# {'loss': 0.7515, 'grad_norm': 0.7870826721191406, 'learning_rate': 1.3056000000000002e-05, 'epoch': 3.6959999999999997}
# {'loss': 0.6615, 'grad_norm': 0.6342841386795044, 'learning_rate': 1.2896e-05, 'epoch': 3.7119999999999997}
# {'loss': 0.625, 'grad_norm': 0.7209784984588623, 'learning_rate': 1.2736000000000001e-05, 'epoch': 3.7279999999999998}
# {'loss': 0.6354, 'grad_norm': 0.7373837828636169, 'learning_rate': 1.2576000000000001e-05, 'epoch': 3.7439999999999998}
# {'loss': 0.7036, 'grad_norm': 0.6666671633720398, 'learning_rate': 1.2416000000000001e-05, 'epoch': 3.76}
# {'loss': 0.761, 'grad_norm': 0.6377732753753662, 'learning_rate': 1.2256000000000001e-05, 'epoch': 3.776}
# {'loss': 0.6097, 'grad_norm': 0.5637678503990173, 'learning_rate': 1.2096e-05, 'epoch': 3.792}
# {'loss': 0.6288, 'grad_norm': 0.8655831813812256, 'learning_rate': 1.1936e-05, 'epoch': 3.808}
# {'loss': 0.7353, 'grad_norm': 0.6481218934059143, 'learning_rate': 1.1776e-05, 'epoch': 3.824}
# {'loss': 0.6414, 'grad_norm': 0.8122480511665344, 'learning_rate': 1.1616e-05, 'epoch': 3.84}
# {'loss': 0.6101, 'grad_norm': 0.696553647518158, 'learning_rate': 1.1456e-05, 'epoch': 3.856}
# {'loss': 0.6982, 'grad_norm': 0.609566330909729, 'learning_rate': 1.1296000000000002e-05, 'epoch': 3.872}
# {'loss': 0.5082, 'grad_norm': 0.6891301870346069, 'learning_rate': 1.1136e-05, 'epoch': 3.888}
# {'loss': 0.71, 'grad_norm': 0.6833752393722534, 'learning_rate': 1.0976e-05, 'epoch': 3.904}
# {'loss': 0.6598, 'grad_norm': 0.6505820751190186, 'learning_rate': 1.0816000000000001e-05, 'epoch': 3.92}
# {'loss': 0.6079, 'grad_norm': 0.7641065716743469, 'learning_rate': 1.0656000000000001e-05, 'epoch': 3.936}
# {'loss': 0.5947, 'grad_norm': 0.6031646132469177, 'learning_rate': 1.0496e-05, 'epoch': 3.952}
# {'loss': 0.6648, 'grad_norm': 0.6408610343933105, 'learning_rate': 1.0336e-05, 'epoch': 3.968}
# {'loss': 0.698, 'grad_norm': 0.7066664695739746, 'learning_rate': 1.0176e-05, 'epoch': 3.984}
# {'loss': 0.6143, 'grad_norm': 0.6527886986732483, 'learning_rate': 1.0016e-05, 'epoch': 4.0}
# {'eval_loss': 0.6472551822662354, 'eval_runtime': 262.5382, 'eval_samples_per_second': 19.045, 'eval_steps_per_second': 2.381, 'epoch': 4.0}
# {'loss': 0.5872, 'grad_norm': 0.6554326415061951, 'learning_rate': 9.856e-06, 'epoch': 4.016}
# {'loss': 0.6226, 'grad_norm': 0.7691023945808411, 'learning_rate': 9.696000000000002e-06, 'epoch': 4.032}
# {'loss': 0.6919, 'grad_norm': 0.7448287606239319, 'learning_rate': 9.536e-06, 'epoch': 4.048}
# {'loss': 0.6469, 'grad_norm': 0.7719784379005432, 'learning_rate': 9.376e-06, 'epoch': 4.064}
# {'loss': 0.6406, 'grad_norm': 0.8061578869819641, 'learning_rate': 9.216000000000001e-06, 'epoch': 4.08}
# {'loss': 0.6941, 'grad_norm': 0.8644959330558777, 'learning_rate': 9.056000000000001e-06, 'epoch': 4.096}
# {'loss': 0.7108, 'grad_norm': 0.62507164478302, 'learning_rate': 8.896000000000001e-06, 'epoch': 4.112}
# {'loss': 0.6552, 'grad_norm': 0.8213291764259338, 'learning_rate': 8.735999999999999e-06, 'epoch': 4.128}
# {'loss': 0.6821, 'grad_norm': 0.7502630949020386, 'learning_rate': 4.1599999999999997e-07, 'epoch': 4.96}
# {'loss': 0.6672, 'grad_norm': 0.8398473262786865, 'learning_rate': 2.56e-07, 'epoch': 4.976}
# {'loss': 0.6782, 'grad_norm': 0.7877139449119568, 'learning_rate': 9.600000000000001e-08, 'epoch': 4.992}
# {'eval_loss': 0.647717297077179, 'eval_runtime': 262.4007, 'eval_samples_per_second': 19.055, 'eval_steps_per_second': 2.382, 'epoch': 5.0}
# {'train_runtime': 4145.6761, 'train_samples_per_second': 6.03, 'train_steps_per_second': 0.754, 'train_loss': 0.7225777849578857, 'epoch': 5.0}

# %%
# predict with model (measuring time)
t0 = time.perf_counter()

pred_txt = model_llama_lora.predict(
    x=x,
    text_token_limit=256,
    report_interval=100)

pred_num = cm.label3_txt_to_num(pred_txt)

t1 = time.perf_counter()
pred_time_seconds = t1 - t0
pred_time_per_sample = pred_time_seconds / len(pred_num)
# Out:
# Reviews processed: 100
# Reviews processed: 200
# Reviews processed: 300
# Reviews processed: 400
# Reviews processed: 500
# Reviews processed: 600
# Reviews processed: 700
# Reviews processed: 800
# Reviews processed: 900
# Reviews processed: 1000
# Reviews processed: 1100
# Reviews processed: 1200
# Reviews processed: 1300
# Reviews processed: 1400
# Reviews processed: 1500
# Reviews processed: 1600
# Reviews processed: 1700
# Reviews processed: 1800
# Reviews processed: 1900
# Reviews processed: 2000
# Reviews processed: 2100
# Reviews processed: 2200
# Reviews processed: 2300
# Reviews processed: 2400
# Reviews processed: 2500
# Reviews processed: 2600
# Reviews processed: 2700
# Reviews processed: 2800
# Reviews processed: 2900
# Reviews processed: 3000
# Reviews processed: 3100
# Reviews processed: 3200
# Reviews processed: 3300
# Reviews processed: 3400
# Reviews processed: 3500
# Reviews processed: 3600
# Reviews processed: 3700
# Reviews processed: 3800
# Reviews processed: 3900
# Reviews processed: 4000
# Reviews processed: 4100
# Reviews processed: 4200
# Reviews processed: 4300
# Reviews processed: 4400
# Reviews processed: 4500
# Reviews processed: 4600
# Reviews processed: 4700
# Reviews processed: 4800
# Reviews processed: 4900
# Reviews processed: 5000

# %%
# sanity check: accuracy
acc = sum(y == pred_num) / len(pred_num)
print(f"acc cntrl: {acc}")
# Out:
# acc cntrl: 0.8744

# %%
# create a run directory (analogous to KP)
hyperparams = {
    "learning_rate": training_config.learning_rate,
    "train_batch_size": training_config.per_device_train_batch_size,
    "epochs": training_config.num_train_epochs }

run_outdir = utils.make_run_dir(
    output_root="outputs",
    model_name=f"{model_name}_lora_finetuned",
    hyperparams=hyperparams)

print("run_outdir:", run_outdir)
# Out:
# run_outdir: outputs/meta-llama_Llama-3.2-3B-Instruct_lora_finetuned_lr5e-05_bs8_ep5_20251206_100147

# %%
# save model and trainig

# save model weights
model_llama_lora.trainer.save_model(run_outdir)

# save tokenizer
model_llama_lora.tokenizer.save_pretrained(run_outdir)

# save training log_history as csv
log_df = pd.DataFrame(model_llama_lora.log_history)
log_df.to_csv(os.path.join(run_outdir, "training_log_history.csv"), index=False)

# save train_result metrics as JSON
train_result = model_llama_lora.train_result
with open(os.path.join(run_outdir, "train_result.json"), "w") as f:
    # train_result is a TrainOutput; .metrics is usually what you care about
    json.dump(train_result.metrics, f, indent=2)

# %% [markdown]
# # Evaluate Results/ Experiment

# %%
# loss curves on training and validation data (incl. saving)
logs = pd.DataFrame(model_llama_lora.log_history)

train_loss = logs[["epoch", "loss"]].dropna()
eval_loss  = logs[["epoch", "eval_loss"]].dropna()

plt.figure(figsize=(10,6))
plt.plot(train_loss["epoch"], train_loss["loss"], '-o', markersize=6, label="train_loss")
plt.plot(eval_loss["epoch"], eval_loss["eval_loss"], '-o', markersize=6, label="eval_loss")

plt.xlabel("epoch")
plt.ylabel("loss")
plt.title("Training & Validation Loss per Epoch")
plt.legend()
plt.grid(True)

plt.savefig(os.path.join(run_outdir, "loss_curves_epoch.png"), bbox_inches="tight")
plt.show()

# %%
# classification metrics (incl. saving classification report as csv)
metrics = utils.compute_classification_metrics_from_arrays(y_true=y, y_pred=pred_num)
df_cfreport = pd.DataFrame(metrics["classification report"]).T
print(df_cfreport)
path = os.path.join(run_outdir, "classification_report.csv")
df_cfreport.to_csv(path)
# Out:
#               precision    recall  f1-score    support
# 0              0.909533  0.823789  0.864540  1135.0000
# 1              0.378378  0.747573  0.502447   412.0000
# 2              0.990817  0.906169  0.946604  3453.0000
# accuracy       0.874400  0.874400  0.874400     0.8744
# macro avg      0.759576  0.825843  0.771197  5000.0000
# weighted avg   0.921901  0.874400  0.891377  5000.0000

# %%
# confusion matrix (incl. saving)
cm = confusion_matrix(y_true=y, y_pred=pred_num)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
plt.figure(figsize=(6, 6))
disp.plot(values_format='d')
plt.title(f"Confusion Matrix (Llama model)")
path = os.path.join(run_outdir, "confusion_matrix.png")
plt.savefig(path, bbox_inches='tight')
plt.show()

# %%
# evaluate time
print("Training time in seconds:", train_time_seconds)
print("Training time per sample:", train_time_per_sample)
print("Prediction time in seconds:", pred_time_seconds)
print("Prediction time per sample:", pred_time_per_sample)
# Out:
# Training time in seconds: 4161.599730573999
# Training time per sample: 0.8323199461147999
# Prediction time in seconds: 711.7443796490006
# Prediction time per sample: 0.1423488759298001

# %%
# saving results in team_comparison_results
results_comparison = {
    "n_samples": len(x),
    "train_seconds": train_time_seconds,
    "pred_time_seconds": pred_time_seconds,
    "pred_time_per_sample": pred_time_per_sample,
    "metrics": metrics}

utils.save_results_csv(
    results=results_comparison,
    csv_path=os.path.join("outputs", "team_comparison_results.csv"),
    model_name=f"{model_name}_zeroshot",
    extra_info={"run_outdir": run_outdir})
# Out:
# Appended results to outputs/team_comparison_results.csv

# %%
# saving all results in dictionary
results_all = results_comparison
results_all["train_time_seconds"] = train_time_seconds,
results_all["train_time_per_sample"] = train_time_per_sample,
results_all["model"] = f"{model_name}_zeroshot",
results_all["instruction"] = instruction
path = os.path.join(run_outdir, "results_all.json")
with open(path, "w") as f:
    json.dump(results_all, f, indent=2)
