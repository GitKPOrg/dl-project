# %% [markdown]
# # Preliminaries and Imports

# %% [markdown]
# Notes:
# - In case of error "BitsAndBytes requires update": The update is already implemented in the notebook. "Restart the session" and "Run all" again because the update seems to require a restart

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# system and path set up
import os
import sys

# path
GOOGLE_DRIVE_PATH = os.path.join('/content', 'drive', 'My Drive', 'ColabNotebooks', 'DL','Deep Learning Project Full','DL Team Project', '20251126_22.47_DL_Team_Project_Code_Files_Structure')

# set working directory (for saving/ loading)
os.chdir(GOOGLE_DRIVE_PATH)

# set import path (for importing src/)
sys.path.insert(0, GOOGLE_DRIVE_PATH)

# verify
print("Current working directory:", os.getcwd())
print("Current import directory:", sys.path[0])
# Out:
# Current working directory: /content/drive/My Drive/ColabNotebooks/DL/Deep Learning Project Full/DL Team Project/20251126_22.47_DL_Team_Project_Code_Files_Structure
# Current import directory: /content/drive/My Drive/ColabNotebooks/DL/Deep Learning Project Full/DL Team Project/20251126_22.47_DL_Team_Project_Code_Files_Structure

# %%
# log into HF
# note: previously store your key as secret (key symbol on the left)
from google.colab import userdata
hf_token = userdata.get('HF_TOKEN')

from huggingface_hub import login
login(token=hf_token)

# Option: silence all HF logs
from transformers.utils.logging import set_verbosity_error
set_verbosity_error()

# %%
# install libraries (only once and then comment out)
# !pip install -q "transformers>=4.40.0" accelerate datasets peft bitsandbytes trl
# !pip install -q -U bitsandbytes transformers accelerate peft trl

# %%
# import standard libraries
import pandas as pd
import time
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import json
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, TrainingArguments
import torch
from peft import LoraConfig

# import utils
from src import utils

# import model
from src.model_llama_lora import CommonMethods, LlamaBaseModel, LlamaLoraModel

# create instance object of CommonMethods
cm = CommonMethods()

# %%
# set seed for reproduceibility (Note: does not work for OpenAI)
seed = 42

# %% [markdown]
# # Load and prepare data

# %%
# load pre-processed data
csv_path_train_data = f"{GOOGLE_DRIVE_PATH}/data/data_train.csv"
csv_path_val_data = f"{GOOGLE_DRIVE_PATH}/data/data_val.csv"
csv_path_test_data = f"{GOOGLE_DRIVE_PATH}/data/data_test.csv"

train_bal = pd.read_csv(csv_path_train_data)
val = pd.read_csv(csv_path_val_data)
test = pd.read_csv(csv_path_test_data)

# %%
# keep only needed columns (drop lang and label5)
train_bal = train_bal.drop(columns=["label5","lang"])
val = val.drop(columns=["label5","lang"])
test = test.drop(columns=["label5","lang"])

# %%
# downsample data
# Note: Fine-tuning on full data would take too long
train_bal = train_bal.sample(n=5000, random_state=seed)
val = val.sample(n=5000, random_state=seed)
test = test.sample(n=20000, random_state=seed)

# %% [markdown]
# # Run model/ Experiment

# %% [markdown]
# Specify model:
# - Choose model type
# - quant_config (= hyperparameters)
# - lora_config (= hyperparameters)
# - training_config (= hyperparameters)
# - Instruction (= hyperparameters)
#
# Specify data for evaluation:
# - val data: for tuning
# - test data: for final run

# %%
# choose model
model_name = "meta-llama/Llama-3.2-3B-Instruct" # "meta-llama/Meta-Llama-3-8B-Instruct"

# %%
# set quantification configuration
quant_config = BitsAndBytesConfig(
    load_in_4_bit=True,
    bnb_4bit_use_double_quant=False,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16)

# %%
peft_config = LoraConfig(
    r=64, # Default 8; size of low-rank update matrice; higher r --> larger trainable capacity                              # 1st prio hyperparameter
    lora_alpha=8, # Default 8;  scaling of loRA updates before adding to base model; higher alpha --> higher loRA effect   # 1st prio hyperparameter
    lora_dropout=0, # Default 0;  regularization withing LoRA
    bias="none", # Default None; base model bias not modified
    task_type="CAUSAL_LM", # Default "Causal_LM"; type is LLM
    target_modules=None) # Default None; base model modules to which loRA is applied

# %%
# instruction
instruction = "Classify the following product review into one of: negative, neutral, positive."

# %%
# set x and y variables for evaluation
# Note: Does not affect train (uses always train data and val data) but only evaluation metrics
x = val["text"] # choose from: val["text"], test["text"]
y = val["label3"] # choose from: val["label3"], test["label3"]

# %%
# create instance of model
model_llama_lora = LlamaLoraModel(model_name, quant_config, peft_config, instruction)
# Out:
# model.safetensors.index.json:   0%|          | 0.00/20.9k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# trainable params: 18,350,080 || all params: 3,231,099,904 || trainable%: 0.5679
# tokenizer_config.json:   0%|          | 0.00/54.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]

# %%
# train model (measuring time)
t0 = time.perf_counter()

training_config = TrainingArguments(
    output_dir="outputs/llama3_lora_trainer",
    num_train_epochs=5, # default 3               # 1st prio hyperparameter
    per_device_train_batch_size=8, # default 8
    per_device_eval_batch_size=8, # default 8
    gradient_accumulation_steps=1,
    learning_rate=5e-5, # default 5e-5            # 1st prio hyperparameter
    logging_steps=10, # default 500
    eval_strategy="epoch", # default "no"
    save_strategy="epoch", # default "steps"
    load_best_model_at_end=False, # default False
    fp16=False, # default False
    report_to=[]) # defaulte None

model_llama_lora.train(
    x_train=train_bal["text"],
    y_train=cm.label3_num_to_txt(train_bal["label3"]),
    x_val=val["text"],
    y_val=cm.label3_num_to_txt(val["label3"]),
    training_config = training_config,
    text_token_limit=256)

t1 = time.perf_counter()
train_time_seconds = t1 - t0
train_time_per_sample = train_time_seconds / len(train_bal["label3"])
# Out:
# Map:   0%|          | 0/5000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5000 [00:00<?, ? examples/s]
# {'loss': 6.9537, 'grad_norm': 3.224433660507202, 'learning_rate': 4.9856000000000005e-05, 'epoch': 0.016}
# {'loss': 5.2937, 'grad_norm': 4.301661491394043, 'learning_rate': 4.969600000000001e-05, 'epoch': 0.032}
# {'loss': 2.9892, 'grad_norm': 3.02166485786438, 'learning_rate': 4.9536e-05, 'epoch': 0.048}
# {'loss': 1.3918, 'grad_norm': 0.42323365807533264, 'learning_rate': 4.9376e-05, 'epoch': 0.064}
# {'loss': 0.9956, 'grad_norm': 0.13313737511634827, 'learning_rate': 4.9216e-05, 'epoch': 0.08}
# {'loss': 1.0525, 'grad_norm': 0.1322130262851715, 'learning_rate': 4.9056e-05, 'epoch': 0.096}
# {'loss': 0.9305, 'grad_norm': 0.12383385747671127, 'learning_rate': 4.8896e-05, 'epoch': 0.112}
# {'loss': 0.9657, 'grad_norm': 0.11247128993272781, 'learning_rate': 4.8736e-05, 'epoch': 0.128}
# {'loss': 0.939, 'grad_norm': 0.10165542364120483, 'learning_rate': 4.8576000000000004e-05, 'epoch': 0.144}
# {'loss': 0.9086, 'grad_norm': 0.10564525425434113, 'learning_rate': 4.8416e-05, 'epoch': 0.16}
# {'loss': 0.8962, 'grad_norm': 0.10662434995174408, 'learning_rate': 4.8256e-05, 'epoch': 0.176}
# {'loss': 0.7424, 'grad_norm': 0.10439743846654892, 'learning_rate': 4.0096e-05, 'epoch': 0.992}
# {'eval_loss': 0.6580482125282288, 'eval_runtime': 250.375, 'eval_samples_per_second': 19.97, 'eval_steps_per_second': 2.496, 'epoch': 1.0}
# {'loss': 0.7987, 'grad_norm': 0.0967368558049202, 'learning_rate': 3.9936e-05, 'epoch': 1.008}
# {'loss': 0.6552, 'grad_norm': 0.07659206539392471, 'learning_rate': 3.9776e-05, 'epoch': 1.024}
# {'loss': 0.7171, 'grad_norm': 0.07784648984670639, 'learning_rate': 3.9616e-05, 'epoch': 1.04}
# {'loss': 0.6795, 'grad_norm': 0.07103656977415085, 'learning_rate': 3.9456e-05, 'epoch': 1.056}
# {'loss': 0.7028, 'grad_norm': 0.08346094191074371, 'learning_rate': 3.9296e-05, 'epoch': 1.072}
# {'loss': 0.7324, 'grad_norm': 0.09926719218492508, 'learning_rate': 3.9136e-05, 'epoch': 1.088}
# {'loss': 0.6603, 'grad_norm': 0.11182857304811478, 'learning_rate': 3.8976e-05, 'epoch': 1.104}
# {'loss': 0.6854, 'grad_norm': 0.07786697149276733, 'learning_rate': 3.8816e-05, 'epoch': 1.12}
# {'loss': 0.7556, 'grad_norm': 0.09936664998531342, 'learning_rate': 3.8656000000000004e-05, 'epoch': 1.1360000000000001}
# {'loss': 0.7242, 'grad_norm': 0.12040099501609802, 'learning_rate': 3.8496000000000005e-05, 'epoch': 1.152}
# {'loss': 0.662, 'grad_norm': 0.09464984387159348, 'learning_rate': 3.8336e-05, 'epoch': 1.168}
# {'loss': 0.6729, 'grad_norm': 0.075164295732975, 'learning_rate': 3.8176e-05, 'epoch': 1.184}
# {'loss': 0.6959, 'grad_norm': 0.1055816188454628, 'learning_rate': 3.8016e-05, 'epoch': 1.2}
# {'loss': 0.6958, 'grad_norm': 0.09119376540184021, 'learning_rate': 3.7856000000000005e-05, 'epoch': 1.216}
# {'loss': 0.6306, 'grad_norm': 0.08938717842102051, 'learning_rate': 3.7696000000000006e-05, 'epoch': 1.232}
# {'loss': 0.6664, 'grad_norm': 0.097426638007164, 'learning_rate': 3.7536e-05, 'epoch': 1.248}
# {'loss': 0.695, 'grad_norm': 0.0840686485171318, 'learning_rate': 3.7376e-05, 'epoch': 1.264}
# {'loss': 0.5991, 'grad_norm': 0.08974418044090271, 'learning_rate': 3.7216000000000004e-05, 'epoch': 1.28}
# {'loss': 0.6375, 'grad_norm': 0.08784547448158264, 'learning_rate': 3.7056e-05, 'epoch': 1.296}
# {'loss': 0.6583, 'grad_norm': 0.09220463037490845, 'learning_rate': 3.6896e-05, 'epoch': 1.312}
# {'loss': 0.5563, 'grad_norm': 0.07315849512815475, 'learning_rate': 3.6736e-05, 'epoch': 1.328}
# {'loss': 0.7039, 'grad_norm': 0.07434438169002533, 'learning_rate': 3.6576e-05, 'epoch': 1.3439999999999999}
# {'loss': 0.7583, 'grad_norm': 0.10090124607086182, 'learning_rate': 3.6416e-05, 'epoch': 1.3599999999999999}
# {'loss': 0.6852, 'grad_norm': 0.08510158956050873, 'learning_rate': 3.6256e-05, 'epoch': 1.376}
# {'loss': 0.7159, 'grad_norm': 0.10866548866033554, 'learning_rate': 3.6096e-05, 'epoch': 1.392}
# {'loss': 0.6987, 'grad_norm': 0.09731926023960114, 'learning_rate': 3.5936e-05, 'epoch': 1.408}
# {'loss': 0.7193, 'grad_norm': 0.08617325127124786, 'learning_rate': 3.5776000000000004e-05, 'epoch': 1.424}
# {'loss': 0.7134, 'grad_norm': 0.11527544260025024, 'learning_rate': 3.5616e-05, 'epoch': 1.44}
# {'loss': 0.6283, 'grad_norm': 0.09025758504867554, 'learning_rate': 3.5456e-05, 'epoch': 1.456}
# {'loss': 0.7227, 'grad_norm': 0.09008151292800903, 'learning_rate': 3.5296e-05, 'epoch': 1.472}
# {'loss': 0.6003, 'grad_norm': 0.10012655705213547, 'learning_rate': 3.5136000000000004e-05, 'epoch': 1.488}
# {'loss': 0.6837, 'grad_norm': 0.11393045634031296, 'learning_rate': 3.4976000000000005e-05, 'epoch': 1.504}
# {'loss': 0.7745, 'grad_norm': 0.09903833270072937, 'learning_rate': 3.481600000000001e-05, 'epoch': 1.52}
# {'loss': 0.6859, 'grad_norm': 0.09802951663732529, 'learning_rate': 3.4656e-05, 'epoch': 1.536}
# {'loss': 0.6699, 'grad_norm': 0.08060295879840851, 'learning_rate': 3.4496e-05, 'epoch': 1.552}
# {'loss': 0.6525, 'grad_norm': 0.08547282218933105, 'learning_rate': 3.4336000000000005e-05, 'epoch': 1.568}
# {'loss': 0.6422, 'grad_norm': 0.08651562035083771, 'learning_rate': 3.4176e-05, 'epoch': 1.584}
# {'loss': 0.7205, 'grad_norm': 0.11640044301748276, 'learning_rate': 3.4016e-05, 'epoch': 1.6}
# {'loss': 0.6154, 'grad_norm': 0.08983476459980011, 'learning_rate': 3.3856e-05, 'epoch': 1.616}
# {'loss': 0.6942, 'grad_norm': 0.11988875269889832, 'learning_rate': 3.3696e-05, 'epoch': 1.6320000000000001}
# {'loss': 0.6191, 'grad_norm': 0.07796572893857956, 'learning_rate': 3.3536e-05, 'epoch': 1.6480000000000001}
# {'loss': 0.6629, 'grad_norm': 0.12034505605697632, 'learning_rate': 3.3376e-05, 'epoch': 1.6640000000000001}
# {'loss': 0.6772, 'grad_norm': 0.11363840848207474, 'learning_rate': 3.3216e-05, 'epoch': 1.6800000000000002}
# {'loss': 0.7905, 'grad_norm': 0.08275547623634338, 'learning_rate': 3.3056e-05, 'epoch': 1.696}
# {'loss': 0.6238, 'grad_norm': 0.10184989124536514, 'learning_rate': 3.2896e-05, 'epoch': 1.712}
# {'loss': 0.6887, 'grad_norm': 0.12497398257255554, 'learning_rate': 3.2736e-05, 'epoch': 1.728}
# {'loss': 0.6147, 'grad_norm': 0.0896177664399147, 'learning_rate': 3.2576e-05, 'epoch': 1.744}
# {'loss': 0.6559, 'grad_norm': 0.0866120383143425, 'learning_rate': 3.2416e-05, 'epoch': 1.76}
# {'loss': 0.7017, 'grad_norm': 0.12363950163125992, 'learning_rate': 3.2256000000000004e-05, 'epoch': 1.776}
# {'loss': 0.6248, 'grad_norm': 0.0962003692984581, 'learning_rate': 3.2096000000000006e-05, 'epoch': 1.792}
# {'loss': 0.7721, 'grad_norm': 0.12953466176986694, 'learning_rate': 3.1936e-05, 'epoch': 1.808}
# {'loss': 0.6189, 'grad_norm': 0.08669058233499527, 'learning_rate': 3.1776e-05, 'epoch': 1.8239999999999998}
# {'loss': 0.7097, 'grad_norm': 0.0913999080657959, 'learning_rate': 3.1616000000000004e-05, 'epoch': 1.8399999999999999}
# {'loss': 0.6807, 'grad_norm': 0.09058745205402374, 'learning_rate': 3.1456000000000005e-05, 'epoch': 1.8559999999999999}
# {'loss': 0.7032, 'grad_norm': 0.10039455443620682, 'learning_rate': 3.1296e-05, 'epoch': 1.8719999999999999}
# {'loss': 0.6134, 'grad_norm': 0.08770226687192917, 'learning_rate': 3.1136e-05, 'epoch': 1.888}
# {'loss': 0.6863, 'grad_norm': 0.09657710790634155, 'learning_rate': 3.0975999999999996e-05, 'epoch': 1.904}
# {'loss': 0.597, 'grad_norm': 0.1004098653793335, 'learning_rate': 3.0816e-05, 'epoch': 1.92}
# {'loss': 0.606, 'grad_norm': 0.1030457392334938, 'learning_rate': 3.0656e-05, 'epoch': 1.936}
# {'loss': 0.7809, 'grad_norm': 0.12623070180416107, 'learning_rate': 3.0496e-05, 'epoch': 1.952}
# {'loss': 0.5805, 'grad_norm': 0.09257396310567856, 'learning_rate': 3.0336000000000002e-05, 'epoch': 1.968}
# {'loss': 0.6872, 'grad_norm': 0.11297383904457092, 'learning_rate': 3.0175999999999997e-05, 'epoch': 1.984}
# {'loss': 0.7152, 'grad_norm': 0.10647685825824738, 'learning_rate': 3.0016e-05, 'epoch': 2.0}
# {'eval_loss': 0.6514655351638794, 'eval_runtime': 250.2945, 'eval_samples_per_second': 19.976, 'eval_steps_per_second': 2.497, 'epoch': 2.0}
# {'loss': 0.7149, 'grad_norm': 0.12253707647323608, 'learning_rate': 2.9856e-05, 'epoch': 2.016}
# {'loss': 0.6656, 'grad_norm': 0.11625991016626358, 'learning_rate': 2.9696e-05, 'epoch': 2.032}
# {'loss': 0.6991, 'grad_norm': 0.0934722051024437, 'learning_rate': 2.9536000000000003e-05, 'epoch': 2.048}
# {'loss': 0.7078, 'grad_norm': 0.09975080192089081, 'learning_rate': 2.9376000000000005e-05, 'epoch': 2.064}
# {'loss': 0.7226, 'grad_norm': 0.08409454673528671, 'learning_rate': 2.9216e-05, 'epoch': 2.08}
# {'loss': 0.6904, 'grad_norm': 0.10381896048784256, 'learning_rate': 2.9056e-05, 'epoch': 2.096}
# {'loss': 0.7497, 'grad_norm': 0.09472788125276566, 'learning_rate': 2.8896000000000003e-05, 'epoch': 2.112}
# {'loss': 0.618, 'grad_norm': 0.10125097632408142, 'learning_rate': 2.8736e-05, 'epoch': 2.128}
# {'loss': 0.6024, 'grad_norm': 0.08840087056159973, 'learning_rate': 2.8576000000000002e-05, 'epoch': 2.144}
# {'loss': 0.6429, 'grad_norm': 0.10852650552988052, 'learning_rate': 2.4416e-05, 'epoch': 2.56}
# {'loss': 0.7107, 'grad_norm': 0.12269113957881927, 'learning_rate': 2.4256e-05, 'epoch': 2.576}
# {'loss': 0.6948, 'grad_norm': 0.09557219594717026, 'learning_rate': 2.4096e-05, 'epoch': 2.592}
# {'loss': 0.6963, 'grad_norm': 0.11736376583576202, 'learning_rate': 2.3936e-05, 'epoch': 2.608}
# {'loss': 0.5372, 'grad_norm': 0.09410231560468674, 'learning_rate': 2.3776e-05, 'epoch': 2.624}
# {'loss': 0.6303, 'grad_norm': 0.10500090569257736, 'learning_rate': 2.3616000000000002e-05, 'epoch': 2.64}
# {'loss': 0.5801, 'grad_norm': 0.10643710196018219, 'learning_rate': 2.3456e-05, 'epoch': 2.656}
# {'loss': 0.7296, 'grad_norm': 0.1201336458325386, 'learning_rate': 2.3296000000000002e-05, 'epoch': 2.672}
# {'loss': 0.6407, 'grad_norm': 0.1542869210243225, 'learning_rate': 2.3136000000000003e-05, 'epoch': 2.6879999999999997}
# {'loss': 0.6284, 'grad_norm': 0.09162268042564392, 'learning_rate': 2.2976e-05, 'epoch': 2.7039999999999997}
# {'loss': 0.6025, 'grad_norm': 0.10720536857843399, 'learning_rate': 2.2816e-05, 'epoch': 2.7199999999999998}
# {'loss': 0.5637, 'grad_norm': 0.1057085320353508, 'learning_rate': 2.2656e-05, 'epoch': 2.7359999999999998}
# {'loss': 0.7023, 'grad_norm': 0.09679388999938965, 'learning_rate': 2.2496e-05, 'epoch': 2.752}
# {'loss': 0.6758, 'grad_norm': 0.11483108252286911, 'learning_rate': 2.2336e-05, 'epoch': 2.768}
# {'loss': 0.5836, 'grad_norm': 0.0821131244301796, 'learning_rate': 2.2176000000000002e-05, 'epoch': 2.784}
# {'loss': 0.6347, 'grad_norm': 0.11240948736667633, 'learning_rate': 2.2016e-05, 'epoch': 2.8}
# {'loss': 0.6517, 'grad_norm': 0.11826415359973907, 'learning_rate': 2.1856000000000002e-05, 'epoch': 2.816}
# {'loss': 0.573, 'grad_norm': 0.0876375138759613, 'learning_rate': 2.1696e-05, 'epoch': 2.832}
# {'loss': 0.6454, 'grad_norm': 0.14877745509147644, 'learning_rate': 2.1536000000000002e-05, 'epoch': 2.848}
# {'loss': 0.7343, 'grad_norm': 0.15355023741722107, 'learning_rate': 2.1376e-05, 'epoch': 2.864}
# {'loss': 0.5708, 'grad_norm': 0.08148059248924255, 'learning_rate': 2.1215999999999998e-05, 'epoch': 2.88}
# {'loss': 0.7505, 'grad_norm': 0.0849808007478714, 'learning_rate': 2.1056e-05, 'epoch': 2.896}
# {'loss': 0.7936, 'grad_norm': 0.11209388822317123, 'learning_rate': 2.0896e-05, 'epoch': 2.912}
# {'loss': 0.6907, 'grad_norm': 0.1354931890964508, 'learning_rate': 2.0736e-05, 'epoch': 2.928}
# {'loss': 0.6599, 'grad_norm': 0.11868508160114288, 'learning_rate': 2.0576e-05, 'epoch': 2.944}
# {'loss': 0.6909, 'grad_norm': 0.0972282886505127, 'learning_rate': 2.0416000000000002e-05, 'epoch': 2.96}
# {'loss': 0.7152, 'grad_norm': 0.1134285107254982, 'learning_rate': 2.0256e-05, 'epoch': 2.976}
# {'loss': 0.6155, 'grad_norm': 0.09845629334449768, 'learning_rate': 2.0096000000000002e-05, 'epoch': 2.992}
# {'eval_loss': 0.6491573452949524, 'eval_runtime': 250.228, 'eval_samples_per_second': 19.982, 'eval_steps_per_second': 2.498, 'epoch': 3.0}
# {'loss': 0.7297, 'grad_norm': 0.08868535608053207, 'learning_rate': 1.9936e-05, 'epoch': 3.008}
# {'loss': 0.6622, 'grad_norm': 0.11186005920171738, 'learning_rate': 1.9776000000000002e-05, 'epoch': 3.024}
# {'loss': 0.7008, 'grad_norm': 0.13099519908428192, 'learning_rate': 1.9616e-05, 'epoch': 3.04}
# {'loss': 0.6102, 'grad_norm': 0.09193135797977448, 'learning_rate': 1.9456e-05, 'epoch': 3.056}
# {'loss': 0.7391, 'grad_norm': 0.09787535667419434, 'learning_rate': 1.9296e-05, 'epoch': 3.072}
# {'loss': 0.7243, 'grad_norm': 0.10832113027572632, 'learning_rate': 1.9136e-05, 'epoch': 3.088}
# {'loss': 0.6279, 'grad_norm': 0.08557095378637314, 'learning_rate': 1.8976000000000003e-05, 'epoch': 3.104}
# {'loss': 0.71, 'grad_norm': 0.11471021920442581, 'learning_rate': 1.8816e-05, 'epoch': 3.12}
# {'loss': 0.5866, 'grad_norm': 0.11615889519453049, 'learning_rate': 1.8656000000000002e-05, 'epoch': 3.136}
# {'loss': 0.6194, 'grad_norm': 0.09562424570322037, 'learning_rate': 1.8496000000000004e-05, 'epoch': 3.152}
# {'loss': 0.6435, 'grad_norm': 0.10415858030319214, 'learning_rate': 1.8336000000000002e-05, 'epoch': 3.168}
# {'loss': 0.7349, 'grad_norm': 0.13802224397659302, 'learning_rate': 1.8176e-05, 'epoch': 3.184}
# {'loss': 0.6799, 'grad_norm': 0.1448008120059967, 'learning_rate': 1.8015999999999998e-05, 'epoch': 3.2}
# {'loss': 0.6849, 'grad_norm': 0.10996994376182556, 'learning_rate': 1.7856e-05, 'epoch': 3.216}
# {'loss': 0.7263, 'grad_norm': 0.11116822808980942, 'learning_rate': 1.7696e-05, 'epoch': 3.232}
# {'loss': 0.7853, 'grad_norm': 0.11664687842130661, 'learning_rate': 1.7536e-05, 'epoch': 3.248}
# {'loss': 0.7254, 'grad_norm': 0.1483655422925949, 'learning_rate': 1.7376e-05, 'epoch': 3.2640000000000002}
# {'loss': 0.6721, 'grad_norm': 0.13374187052249908, 'learning_rate': 1.7216000000000003e-05, 'epoch': 3.2800000000000002}
# {'loss': 0.7107, 'grad_norm': 0.11713151633739471, 'learning_rate': 1.7056e-05, 'epoch': 3.296}
# {'loss': 0.7731, 'grad_norm': 0.120170459151268, 'learning_rate': 1.6896000000000002e-05, 'epoch': 3.312}
# {'loss': 0.6369, 'grad_norm': 0.08186729997396469, 'learning_rate': 1.6736e-05, 'epoch': 3.328}
# {'loss': 0.6, 'grad_norm': 0.11342060565948486, 'learning_rate': 1.6576e-05, 'epoch': 3.344}
# {'loss': 0.7764, 'grad_norm': 0.12008015066385269, 'learning_rate': 1.6416e-05, 'epoch': 3.36}
# {'loss': 0.653, 'grad_norm': 0.13710187375545502, 'learning_rate': 1.6256e-05, 'epoch': 3.376}
# {'loss': 0.6069, 'grad_norm': 0.10125309973955154, 'learning_rate': 1.6096e-05, 'epoch': 3.392}
# {'loss': 0.7173, 'grad_norm': 0.10030221194028854, 'learning_rate': 1.5936e-05, 'epoch': 3.408}
# {'loss': 0.631, 'grad_norm': 0.10003792494535446, 'learning_rate': 1.5776000000000003e-05, 'epoch': 3.424}
# {'loss': 0.7777, 'grad_norm': 0.12710252404212952, 'learning_rate': 1.5616e-05, 'epoch': 3.44}
# {'loss': 0.7224, 'grad_norm': 0.14336048066616058, 'learning_rate': 1.5456000000000002e-05, 'epoch': 3.456}
# {'loss': 0.6582, 'grad_norm': 0.12525884807109833, 'learning_rate': 1.5296e-05, 'epoch': 3.472}
# {'loss': 0.6484, 'grad_norm': 0.14193855226039886, 'learning_rate': 1.5136e-05, 'epoch': 3.488}
# {'loss': 0.6202, 'grad_norm': 0.08653735369443893, 'learning_rate': 1.4976000000000002e-05, 'epoch': 3.504}
# {'loss': 0.5779, 'grad_norm': 0.10301689803600311, 'learning_rate': 1.4816e-05, 'epoch': 3.52}
# {'loss': 0.6179, 'grad_norm': 0.10086875408887863, 'learning_rate': 1.4656e-05, 'epoch': 3.536}
# {'loss': 0.6792, 'grad_norm': 0.10609890520572662, 'learning_rate': 1.4496000000000001e-05, 'epoch': 3.552}
# {'loss': 0.6555, 'grad_norm': 0.12962372601032257, 'learning_rate': 1.4336e-05, 'epoch': 3.568}
# {'loss': 0.6056, 'grad_norm': 0.10823681205511093, 'learning_rate': 1.4176000000000001e-05, 'epoch': 3.584}
# {'loss': 0.6384, 'grad_norm': 0.11292925477027893, 'learning_rate': 1.4016000000000001e-05, 'epoch': 3.6}
# {'loss': 0.5713, 'grad_norm': 0.0897679254412651, 'learning_rate': 1.3855999999999999e-05, 'epoch': 3.616}
# {'loss': 0.6763, 'grad_norm': 0.10217349231243134, 'learning_rate': 1.3696e-05, 'epoch': 3.632}
# {'loss': 0.7079, 'grad_norm': 0.10737556219100952, 'learning_rate': 1.3536000000000002e-05, 'epoch': 3.648}
# {'loss': 0.7468, 'grad_norm': 0.13820911943912506, 'learning_rate': 1.3376e-05, 'epoch': 3.664}
# {'loss': 0.6797, 'grad_norm': 0.11947287619113922, 'learning_rate': 1.3216e-05, 'epoch': 3.68}
# {'loss': 0.754, 'grad_norm': 0.12928035855293274, 'learning_rate': 1.3056000000000002e-05, 'epoch': 3.6959999999999997}
# {'loss': 0.6635, 'grad_norm': 0.09826356172561646, 'learning_rate': 1.2896e-05, 'epoch': 3.7119999999999997}
# {'loss': 0.6275, 'grad_norm': 0.11477015912532806, 'learning_rate': 1.2736000000000001e-05, 'epoch': 3.7279999999999998}
# {'loss': 0.638, 'grad_norm': 0.11509626358747482, 'learning_rate': 1.2576000000000001e-05, 'epoch': 3.7439999999999998}
# {'loss': 0.7066, 'grad_norm': 0.10860980302095413, 'learning_rate': 1.2416000000000001e-05, 'epoch': 3.76}
# {'loss': 0.7642, 'grad_norm': 0.09832876175642014, 'learning_rate': 1.2256000000000001e-05, 'epoch': 3.776}
# {'loss': 0.6117, 'grad_norm': 0.092088982462883, 'learning_rate': 1.2096e-05, 'epoch': 3.792}
# {'loss': 0.6316, 'grad_norm': 0.1381341964006424, 'learning_rate': 1.1936e-05, 'epoch': 3.808}
# {'loss': 0.7367, 'grad_norm': 0.10996236652135849, 'learning_rate': 1.1776e-05, 'epoch': 3.824}
# {'loss': 0.6436, 'grad_norm': 0.12259964644908905, 'learning_rate': 1.1616e-05, 'epoch': 3.84}
# {'loss': 0.6127, 'grad_norm': 0.1130448505282402, 'learning_rate': 1.1456e-05, 'epoch': 3.856}
# {'loss': 0.7014, 'grad_norm': 0.09540560096502304, 'learning_rate': 1.1296000000000002e-05, 'epoch': 3.872}
# {'loss': 0.5106, 'grad_norm': 0.10414592921733856, 'learning_rate': 1.1136e-05, 'epoch': 3.888}
# {'loss': 0.7118, 'grad_norm': 0.11592500656843185, 'learning_rate': 1.0976e-05, 'epoch': 3.904}
# {'loss': 0.6628, 'grad_norm': 0.1059294193983078, 'learning_rate': 1.0816000000000001e-05, 'epoch': 3.92}
# {'loss': 0.6108, 'grad_norm': 0.11973001807928085, 'learning_rate': 1.0656000000000001e-05, 'epoch': 3.936}
# {'loss': 0.5971, 'grad_norm': 0.09080561995506287, 'learning_rate': 1.0496e-05, 'epoch': 3.952}
# {'loss': 0.6688, 'grad_norm': 0.10181239992380142, 'learning_rate': 1.0336e-05, 'epoch': 3.968}
# {'loss': 0.7009, 'grad_norm': 0.10798873752355576, 'learning_rate': 1.0176e-05, 'epoch': 3.984}
# {'loss': 0.6164, 'grad_norm': 0.10236602276563644, 'learning_rate': 1.0016e-05, 'epoch': 4.0}
# {'eval_loss': 0.6480387449264526, 'eval_runtime': 250.2446, 'eval_samples_per_second': 19.98, 'eval_steps_per_second': 2.498, 'epoch': 4.0}
# {'loss': 0.5906, 'grad_norm': 0.10432320088148117, 'learning_rate': 9.856e-06, 'epoch': 4.016}
# {'loss': 0.6266, 'grad_norm': 0.1201452761888504, 'learning_rate': 9.696000000000002e-06, 'epoch': 4.032}
# {'loss': 0.6943, 'grad_norm': 0.11883571743965149, 'learning_rate': 9.536e-06, 'epoch': 4.048}
# {'loss': 0.6496, 'grad_norm': 0.11523862183094025, 'learning_rate': 9.376e-06, 'epoch': 4.064}
# {'loss': 0.6436, 'grad_norm': 0.127136692404747, 'learning_rate': 9.216000000000001e-06, 'epoch': 4.08}
# {'loss': 0.6963, 'grad_norm': 0.13733841478824615, 'learning_rate': 9.056000000000001e-06, 'epoch': 4.096}
# {'loss': 0.7146, 'grad_norm': 0.09534510225057602, 'learning_rate': 8.896000000000001e-06, 'epoch': 4.112}
# {'loss': 0.6582, 'grad_norm': 0.1348605751991272, 'learning_rate': 8.735999999999999e-06, 'epoch': 4.128}
# {'loss': 0.612, 'grad_norm': 0.10202208161354065, 'learning_rate': 4.576000000000001e-06, 'epoch': 4.5440000000000005}
# {'loss': 0.8341, 'grad_norm': 0.11984584480524063, 'learning_rate': 4.416e-06, 'epoch': 4.5600000000000005}
# {'loss': 0.5985, 'grad_norm': 0.12979453802108765, 'learning_rate': 4.256e-06, 'epoch': 4.576}
# {'loss': 0.6683, 'grad_norm': 0.11303731054067612, 'learning_rate': 4.096e-06, 'epoch': 4.592}
# {'loss': 0.7036, 'grad_norm': 0.10644767433404922, 'learning_rate': 3.936e-06, 'epoch': 4.608}
# {'loss': 0.635, 'grad_norm': 0.09122885763645172, 'learning_rate': 3.7760000000000004e-06, 'epoch': 4.624}
# {'loss': 0.5983, 'grad_norm': 0.1132538765668869, 'learning_rate': 3.6159999999999998e-06, 'epoch': 4.64}
# {'loss': 0.6705, 'grad_norm': 0.11032011359930038, 'learning_rate': 3.456e-06, 'epoch': 4.656}
# {'loss': 0.6403, 'grad_norm': 0.1384597271680832, 'learning_rate': 3.2960000000000003e-06, 'epoch': 4.672}
# {'loss': 0.6198, 'grad_norm': 0.11131753027439117, 'learning_rate': 3.136e-06, 'epoch': 4.688}
# {'loss': 0.6768, 'grad_norm': 0.1213872954249382, 'learning_rate': 2.9760000000000004e-06, 'epoch': 4.704}
# {'loss': 0.6371, 'grad_norm': 0.10712393373250961, 'learning_rate': 2.8160000000000002e-06, 'epoch': 4.72}
# {'loss': 0.6819, 'grad_norm': 0.09620709717273712, 'learning_rate': 2.656e-06, 'epoch': 4.736}
# {'loss': 0.7615, 'grad_norm': 0.13909724354743958, 'learning_rate': 2.496e-06, 'epoch': 4.752}
# {'loss': 0.7281, 'grad_norm': 0.14361871778964996, 'learning_rate': 2.336e-06, 'epoch': 4.768}
# {'loss': 0.7636, 'grad_norm': 0.10792598128318787, 'learning_rate': 2.1760000000000004e-06, 'epoch': 4.784}
# {'loss': 0.6018, 'grad_norm': 0.10307896137237549, 'learning_rate': 2.0160000000000003e-06, 'epoch': 4.8}
# {'loss': 0.5712, 'grad_norm': 0.10398738086223602, 'learning_rate': 1.856e-06, 'epoch': 4.816}
# {'loss': 0.5581, 'grad_norm': 0.11958228796720505, 'learning_rate': 1.696e-06, 'epoch': 4.832}
# {'loss': 0.5954, 'grad_norm': 0.11326614767313004, 'learning_rate': 1.5360000000000002e-06, 'epoch': 4.848}
# {'loss': 0.656, 'grad_norm': 0.12467449903488159, 'learning_rate': 1.376e-06, 'epoch': 4.864}
# {'loss': 0.7665, 'grad_norm': 0.1361444592475891, 'learning_rate': 1.216e-06, 'epoch': 4.88}
# {'loss': 0.724, 'grad_norm': 0.09932225197553635, 'learning_rate': 1.0560000000000001e-06, 'epoch': 4.896}
# {'loss': 0.6883, 'grad_norm': 0.12035266309976578, 'learning_rate': 8.96e-07, 'epoch': 4.912}
# {'loss': 0.647, 'grad_norm': 0.16999302804470062, 'learning_rate': 7.36e-07, 'epoch': 4.928}
# {'loss': 0.7004, 'grad_norm': 0.1364591419696808, 'learning_rate': 5.760000000000001e-07, 'epoch': 4.944}
# {'loss': 0.6836, 'grad_norm': 0.12295850366353989, 'learning_rate': 4.1599999999999997e-07, 'epoch': 4.96}
# {'loss': 0.6696, 'grad_norm': 0.13200947642326355, 'learning_rate': 2.56e-07, 'epoch': 4.976}
# {'loss': 0.6799, 'grad_norm': 0.12078969925642014, 'learning_rate': 9.600000000000001e-08, 'epoch': 4.992}
# {'eval_loss': 0.6481621265411377, 'eval_runtime': 250.1493, 'eval_samples_per_second': 19.988, 'eval_steps_per_second': 2.499, 'epoch': 5.0}
# {'train_runtime': 4045.3904, 'train_samples_per_second': 6.18, 'train_steps_per_second': 0.772, 'train_loss': 0.7312305339813232, 'epoch': 5.0}

# %%
# predict with model (measuring time)
t0 = time.perf_counter()

pred_txt = model_llama_lora.predict(
    x=x,
    text_token_limit=256,
    report_interval=100)

pred_num = cm.label3_txt_to_num(pred_txt)

t1 = time.perf_counter()
pred_time_seconds = t1 - t0
pred_time_per_sample = pred_time_seconds / len(pred_num)
# Out:
# Reviews processed: 100
# Reviews processed: 200
# Reviews processed: 300
# Reviews processed: 400
# Reviews processed: 500
# Reviews processed: 600
# Reviews processed: 700
# Reviews processed: 800
# Reviews processed: 900
# Reviews processed: 1000
# Reviews processed: 1100
# Reviews processed: 1200
# Reviews processed: 1300
# Reviews processed: 1400
# Reviews processed: 1500
# Reviews processed: 1600
# Reviews processed: 1700
# Reviews processed: 1800
# Reviews processed: 1900
# Reviews processed: 2000
# Reviews processed: 2100
# Reviews processed: 2200
# Reviews processed: 2300
# Reviews processed: 2400
# Reviews processed: 2500
# Reviews processed: 2600
# Reviews processed: 2700
# Reviews processed: 2800
# Reviews processed: 2900
# Reviews processed: 3000
# Reviews processed: 3100
# Reviews processed: 3200
# Reviews processed: 3300
# Reviews processed: 3400
# Reviews processed: 3500
# Reviews processed: 3600
# Reviews processed: 3700
# Reviews processed: 3800
# Reviews processed: 3900
# Reviews processed: 4000
# Reviews processed: 4100
# Reviews processed: 4200
# Reviews processed: 4300
# Reviews processed: 4400
# Reviews processed: 4500
# Reviews processed: 4600
# Reviews processed: 4700
# Reviews processed: 4800
# Reviews processed: 4900
# Reviews processed: 5000

# %%
# sanity check: accuracy
acc = sum(y == pred_num) / len(pred_num)
print(f"acc cntrl: {acc}")
# Out:
# acc cntrl: 0.8718

# %%
# create a run directory (analogous to KP)
hyperparams = {
    "learning_rate": training_config.learning_rate,
    "train_batch_size": training_config.per_device_train_batch_size,
    "epochs": training_config.num_train_epochs }

run_outdir = utils.make_run_dir(
    output_root="outputs",
    model_name=f"{model_name}_lora_finetuned",
    hyperparams=hyperparams)

print("run_outdir:", run_outdir)
# Out:
# run_outdir: outputs/meta-llama_Llama-3.2-3B-Instruct_lora_finetuned_lr5e-05_bs8_ep5_20251206_113734

# %%
# save model and trainig

# save model weights
model_llama_lora.trainer.save_model(run_outdir)

# save tokenizer
model_llama_lora.tokenizer.save_pretrained(run_outdir)

# save training log_history as csv
log_df = pd.DataFrame(model_llama_lora.log_history)
log_df.to_csv(os.path.join(run_outdir, "training_log_history.csv"), index=False)

# save train_result metrics as JSON
train_result = model_llama_lora.train_result
with open(os.path.join(run_outdir, "train_result.json"), "w") as f:
    # train_result is a TrainOutput; .metrics is usually what you care about
    json.dump(train_result.metrics, f, indent=2)

# %% [markdown]
# # Evaluate Results/ Experiment

# %%
# loss curves on training and validation data (incl. saving)
logs = pd.DataFrame(model_llama_lora.log_history)

train_loss = logs[["epoch", "loss"]].dropna()
eval_loss  = logs[["epoch", "eval_loss"]].dropna()

plt.figure(figsize=(10,6))
plt.plot(train_loss["epoch"], train_loss["loss"], '-o', markersize=6, label="train_loss")
plt.plot(eval_loss["epoch"], eval_loss["eval_loss"], '-o', markersize=6, label="eval_loss")

plt.xlabel("epoch")
plt.ylabel("loss")
plt.title("Training & Validation Loss per Epoch")
plt.legend()
plt.grid(True)

plt.savefig(os.path.join(run_outdir, "loss_curves_epoch.png"), bbox_inches="tight")
plt.show()

# %%
# classification metrics (incl. saving classification report as csv)
metrics = utils.compute_classification_metrics_from_arrays(y_true=y, y_pred=pred_num)
df_cfreport = pd.DataFrame(metrics["classification report"]).T
print(df_cfreport)
path = os.path.join(run_outdir, "classification_report.csv")
df_cfreport.to_csv(path)
# Out:
#               precision    recall  f1-score    support
# 0              0.907045  0.816740  0.859527  1135.0000
# 1              0.369697  0.740291  0.493129   412.0000
# 2              0.991754  0.905589  0.946715  3453.0000
# accuracy       0.871800  0.871800  0.871800     0.8718
# macro avg      0.756165  0.820874  0.766457  5000.0000
# weighted avg   0.921267  0.871800  0.889548  5000.0000

# %%
# confusion matrix (incl. saving)
cm = confusion_matrix(y_true=y, y_pred=pred_num)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
plt.figure(figsize=(6, 6))
disp.plot(values_format='d')
plt.title(f"Confusion Matrix (Llama model)")
path = os.path.join(run_outdir, "confusion_matrix.png")
plt.savefig(path, bbox_inches='tight')
plt.show()

# %%
# evaluate time
print("Training time in seconds:", train_time_seconds)
print("Training time per sample:", train_time_per_sample)
print("Prediction time in seconds:", pred_time_seconds)
print("Prediction time per sample:", pred_time_per_sample)
# Out:
# Training time in seconds: 4062.267639334
# Training time per sample: 0.8124535278667999
# Prediction time in seconds: 732.5919087450002
# Prediction time per sample: 0.14651838174900003

# %%
# saving results in team_comparison_results
results_comparison = {
    "n_samples": len(x),
    "train_seconds": train_time_seconds,
    "pred_time_seconds": pred_time_seconds,
    "pred_time_per_sample": pred_time_per_sample,
    "metrics": metrics}

utils.save_results_csv(
    results=results_comparison,
    csv_path=os.path.join("outputs", "team_comparison_results.csv"),
    model_name=f"{model_name}_zeroshot",
    extra_info={"run_outdir": run_outdir})
# Out:
# Appended results to outputs/team_comparison_results.csv

# %%
# saving all results in dictionary
results_all = results_comparison
results_all["train_time_seconds"] = train_time_seconds,
results_all["train_time_per_sample"] = train_time_per_sample,
results_all["model"] = f"{model_name}_zeroshot",
results_all["instruction"] = instruction
path = os.path.join(run_outdir, "results_all.json")
with open(path, "w") as f:
    json.dump(results_all, f, indent=2)
