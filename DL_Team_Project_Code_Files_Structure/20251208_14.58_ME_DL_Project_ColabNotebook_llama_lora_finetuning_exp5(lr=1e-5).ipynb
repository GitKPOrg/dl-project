# %% [markdown]
# # Preliminaries and Imports

# %% [markdown]
# Notes:
# - In case of error "BitsAndBytes requires update": The update is already implemented in the notebook. "Restart the session" and "Run all" again because the update seems to require a restart

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# system and path set up
import os
import sys

# path
GOOGLE_DRIVE_PATH = os.path.join('/content', 'drive', 'My Drive', 'ColabNotebooks', 'DL','Deep Learning Project Full','DL Team Project', '20251126_22.47_DL_Team_Project_Code_Files_Structure')

# set working directory (for saving/ loading)
os.chdir(GOOGLE_DRIVE_PATH)

# set import path (for importing src/)
sys.path.insert(0, GOOGLE_DRIVE_PATH)

# verify
print("Current working directory:", os.getcwd())
print("Current import directory:", sys.path[0])
# Out:
# Current working directory: /content/drive/My Drive/ColabNotebooks/DL/Deep Learning Project Full/DL Team Project/20251126_22.47_DL_Team_Project_Code_Files_Structure
# Current import directory: /content/drive/My Drive/ColabNotebooks/DL/Deep Learning Project Full/DL Team Project/20251126_22.47_DL_Team_Project_Code_Files_Structure

# %%
# log into HF
# note: previously store your key as secret (key symbol on the left)
from google.colab import userdata
hf_token = userdata.get('HF_TOKEN')

from huggingface_hub import login
login(token=hf_token)

# Option: silence all HF logs
from transformers.utils.logging import set_verbosity_error
set_verbosity_error()

# %%
# install libraries (only once and then comment out)
# !pip install -q "transformers>=4.40.0" accelerate datasets peft bitsandbytes trl
# !pip install -q -U bitsandbytes transformers accelerate peft trl

# %%
# import standard libraries
import pandas as pd
import time
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import json
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, TrainingArguments
import torch
from peft import LoraConfig

# import utils
from src import utils

# import model
from src.model_llama_lora import CommonMethods, LlamaBaseModel, LlamaLoraModel

# create instance object of CommonMethods
cm = CommonMethods()

# %%
# set seed for reproduceibility (Note: does not work for OpenAI)
seed = 42

# %% [markdown]
# # Load and prepare data

# %%
# load pre-processed data
csv_path_train_data = f"{GOOGLE_DRIVE_PATH}/data/data_train.csv"
csv_path_val_data = f"{GOOGLE_DRIVE_PATH}/data/data_val.csv"
csv_path_test_data = f"{GOOGLE_DRIVE_PATH}/data/data_test.csv"

train_bal = pd.read_csv(csv_path_train_data)
val = pd.read_csv(csv_path_val_data)
test = pd.read_csv(csv_path_test_data)

# %%
# keep only needed columns (drop lang and label5)
train_bal = train_bal.drop(columns=["label5","lang"])
val = val.drop(columns=["label5","lang"])
test = test.drop(columns=["label5","lang"])

# %%
# downsample data
# Note: Fine-tuning on full data would take too long
train_bal = train_bal.sample(n=5000, random_state=seed)
val = val.sample(n=5000, random_state=seed)
test = test.sample(n=20000, random_state=seed)

# %% [markdown]
# # Run model/ Experiment

# %% [markdown]
# Specify model:
# - Choose model type
# - quant_config (= hyperparameters)
# - lora_config (= hyperparameters)
# - training_config (= hyperparameters)
# - Instruction (= hyperparameters)
#
# Specify data for evaluation:
# - val data: for tuning
# - test data: for final run

# %%
# choose model
model_name = "meta-llama/Llama-3.2-3B-Instruct" # "meta-llama/Meta-Llama-3-8B-Instruct"

# %%
# set quantification configuration
quant_config = BitsAndBytesConfig(
    load_in_4_bit=True,
    bnb_4bit_use_double_quant=False,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16)

# %%
peft_config = LoraConfig(
    r=8, # Default 8; size of low-rank update matrice; higher r --> larger trainable capacity                              # 1st prio hyperparameter
    lora_alpha=8, # Default 8;  scaling of loRA updates before adding to base model; higher alpha --> higher loRA effect   # 1st prio hyperparameter
    lora_dropout=0, # Default 0;  regularization withing LoRA
    bias="none", # Default None; base model bias not modified
    task_type="CAUSAL_LM", # Default "Causal_LM"; type is LLM
    target_modules=None) # Default None; base model modules to which loRA is applied

# %%
# instruction
instruction = "Classify the following product review into one of: negative, neutral, positive."

# %%
# set x and y variables for evaluation
# Note: Does not affect train (uses always train data and val data) but only evaluation metrics
x = val["text"] # choose from: val["text"], test["text"]
y = val["label3"] # choose from: val["label3"], test["label3"]

# %%
# create instance of model
model_llama_lora = LlamaLoraModel(model_name, quant_config, peft_config, instruction)
# Out:
# model.safetensors.index.json:   0%|          | 0.00/20.9k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# trainable params: 2,293,760 || all params: 3,215,043,584 || trainable%: 0.0713
# tokenizer_config.json:   0%|          | 0.00/54.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]

# %%
# train model (measuring time)
t0 = time.perf_counter()

training_config = TrainingArguments(
    output_dir="outputs/llama3_lora_trainer",
    num_train_epochs=5, # default 3               # 1st prio hyperparameter
    per_device_train_batch_size=8, # default 8
    per_device_eval_batch_size=8, # default 8
    gradient_accumulation_steps=1,
    learning_rate=1e-5, # default 5e-5            # 1st prio hyperparameter
    logging_steps=10, # default 500
    eval_strategy="epoch", # default "no"
    save_strategy="epoch", # default "steps"
    load_best_model_at_end=False, # default False
    fp16=False, # default False
    report_to=[]) # defaulte None

model_llama_lora.train(
    x_train=train_bal["text"],
    y_train=cm.label3_num_to_txt(train_bal["label3"]),
    x_val=val["text"],
    y_val=cm.label3_num_to_txt(val["label3"]),
    training_config = training_config,
    text_token_limit=256)

t1 = time.perf_counter()
train_time_seconds = t1 - t0
train_time_per_sample = train_time_seconds / len(train_bal["label3"])
# Out:
# Map:   0%|          | 0/5000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5000 [00:00<?, ? examples/s]
# {'loss': 7.3023, 'grad_norm': 5.3074493408203125, 'learning_rate': 9.9712e-06, 'epoch': 0.016}
# {'loss': 7.1137, 'grad_norm': 5.791355609893799, 'learning_rate': 9.939200000000001e-06, 'epoch': 0.032}
# {'loss': 6.9331, 'grad_norm': 7.5637407302856445, 'learning_rate': 9.9072e-06, 'epoch': 0.048}
# {'loss': 6.6037, 'grad_norm': 10.352376937866211, 'learning_rate': 9.8752e-06, 'epoch': 0.064}
# {'loss': 6.3947, 'grad_norm': 11.133734703063965, 'learning_rate': 9.843200000000001e-06, 'epoch': 0.08}
# {'loss': 5.8955, 'grad_norm': 10.568305015563965, 'learning_rate': 9.8112e-06, 'epoch': 0.096}
# {'loss': 5.491, 'grad_norm': 13.315244674682617, 'learning_rate': 9.779200000000001e-06, 'epoch': 0.112}
# {'loss': 4.9175, 'grad_norm': 12.762934684753418, 'learning_rate': 9.7472e-06, 'epoch': 0.128}
# {'loss': 4.2484, 'grad_norm': 10.893680572509766, 'learning_rate': 9.715200000000001e-06, 'epoch': 0.144}
# {'loss': 3.6014, 'grad_norm': 10.680419921875, 'learning_rate': 9.6832e-06, 'epoch': 0.16}
# {'loss': 2.9117, 'grad_norm': 10.693073272705078, 'learning_rate': 9.6512e-06, 'epoch': 0.176}
# {'eval_loss': 0.6974552273750305, 'eval_runtime': 249.195, 'eval_samples_per_second': 20.065, 'eval_steps_per_second': 2.508, 'epoch': 1.0}
# {'loss': 0.8449, 'grad_norm': 0.23562122881412506, 'learning_rate': 7.9872e-06, 'epoch': 1.008}
# {'loss': 0.6943, 'grad_norm': 0.1815657764673233, 'learning_rate': 7.955200000000001e-06, 'epoch': 1.024}
# {'loss': 0.7571, 'grad_norm': 0.18621592223644257, 'learning_rate': 7.9232e-06, 'epoch': 1.04}
# {'loss': 0.7153, 'grad_norm': 0.19105440378189087, 'learning_rate': 7.891200000000002e-06, 'epoch': 1.056}
# {'loss': 0.7392, 'grad_norm': 0.20287595689296722, 'learning_rate': 7.859200000000001e-06, 'epoch': 1.072}
# {'loss': 0.7726, 'grad_norm': 0.24559970200061798, 'learning_rate': 7.8272e-06, 'epoch': 1.088}
# {'loss': 0.6975, 'grad_norm': 0.2665916979312897, 'learning_rate': 7.795200000000001e-06, 'epoch': 1.104}
# {'loss': 0.7195, 'grad_norm': 0.23008592426776886, 'learning_rate': 7.7632e-06, 'epoch': 1.12}
# {'loss': 0.789, 'grad_norm': 0.2140110731124878, 'learning_rate': 7.731200000000001e-06, 'epoch': 1.1360000000000001}
# {'loss': 0.7624, 'grad_norm': 0.2890211045742035, 'learning_rate': 7.6992e-06, 'epoch': 1.152}
# {'loss': 0.6952, 'grad_norm': 0.20809270441532135, 'learning_rate': 7.6672e-06, 'epoch': 1.168}
# {'loss': 0.7085, 'grad_norm': 0.19943228363990784, 'learning_rate': 7.635200000000001e-06, 'epoch': 1.184}
# {'loss': 0.73, 'grad_norm': 0.23743316531181335, 'learning_rate': 7.6032e-06, 'epoch': 1.2}
# {'loss': 0.7288, 'grad_norm': 0.21371111273765564, 'learning_rate': 7.5712000000000005e-06, 'epoch': 1.216}
# {'loss': 0.6592, 'grad_norm': 0.21714234352111816, 'learning_rate': 7.539200000000001e-06, 'epoch': 1.232}
# {'loss': 0.6983, 'grad_norm': 0.24830879271030426, 'learning_rate': 7.507200000000001e-06, 'epoch': 1.248}
# {'loss': 0.7202, 'grad_norm': 0.21452918648719788, 'learning_rate': 7.4752e-06, 'epoch': 1.264}
# {'loss': 0.6237, 'grad_norm': 0.20934873819351196, 'learning_rate': 7.4432e-06, 'epoch': 1.28}
# {'loss': 0.6616, 'grad_norm': 0.26547375321388245, 'learning_rate': 7.4112e-06, 'epoch': 1.296}
# {'loss': 0.6849, 'grad_norm': 0.2137664407491684, 'learning_rate': 7.3792000000000004e-06, 'epoch': 1.312}
# {'loss': 0.5808, 'grad_norm': 0.18575310707092285, 'learning_rate': 7.347200000000001e-06, 'epoch': 1.328}
# {'loss': 0.7271, 'grad_norm': 0.1861630082130432, 'learning_rate': 7.3152e-06, 'epoch': 1.3439999999999999}
# {'loss': 0.7808, 'grad_norm': 0.27589938044548035, 'learning_rate': 7.2832e-06, 'epoch': 1.3599999999999999}
# {'loss': 0.7112, 'grad_norm': 0.19905021786689758, 'learning_rate': 7.2512e-06, 'epoch': 1.376}
# {'loss': 0.7266, 'grad_norm': 0.29371747374534607, 'learning_rate': 4.0512e-06, 'epoch': 2.976}
# {'loss': 0.6273, 'grad_norm': 0.284774512052536, 'learning_rate': 4.0192e-06, 'epoch': 2.992}
# {'eval_loss': 0.6583977341651917, 'eval_runtime': 249.1995, 'eval_samples_per_second': 20.064, 'eval_steps_per_second': 2.508, 'epoch': 3.0}
# {'loss': 0.7425, 'grad_norm': 0.2518341839313507, 'learning_rate': 3.9872000000000006e-06, 'epoch': 3.008}
# {'loss': 0.6745, 'grad_norm': 0.29117003083229065, 'learning_rate': 3.9552e-06, 'epoch': 3.024}
# {'loss': 0.7111, 'grad_norm': 0.3369513154029846, 'learning_rate': 3.9232e-06, 'epoch': 3.04}
# {'loss': 0.6238, 'grad_norm': 0.2802051901817322, 'learning_rate': 3.8912e-06, 'epoch': 3.056}
# {'loss': 0.757, 'grad_norm': 0.24897527694702148, 'learning_rate': 3.8592e-06, 'epoch': 3.072}
# {'loss': 0.7357, 'grad_norm': 0.2822508215904236, 'learning_rate': 3.8272e-06, 'epoch': 3.088}
# {'loss': 0.6411, 'grad_norm': 0.28806763887405396, 'learning_rate': 3.7952000000000005e-06, 'epoch': 3.104}
# {'loss': 0.7208, 'grad_norm': 0.32833895087242126, 'learning_rate': 3.7632000000000002e-06, 'epoch': 3.12}
# {'loss': 0.5968, 'grad_norm': 0.29460543394088745, 'learning_rate': 3.7312000000000004e-06, 'epoch': 3.136}
# {'loss': 0.6314, 'grad_norm': 0.3324485719203949, 'learning_rate': 3.6992000000000005e-06, 'epoch': 3.152}
# {'loss': 0.6568, 'grad_norm': 0.2753155529499054, 'learning_rate': 3.6672000000000002e-06, 'epoch': 3.168}
# {'loss': 0.7497, 'grad_norm': 0.34203681349754333, 'learning_rate': 3.6352000000000004e-06, 'epoch': 3.184}
# {'loss': 0.6926, 'grad_norm': 0.3691379129886627, 'learning_rate': 3.6032e-06, 'epoch': 3.2}
# {'loss': 0.6961, 'grad_norm': 0.3099026679992676, 'learning_rate': 3.5712000000000002e-06, 'epoch': 3.216}
# {'loss': 0.7447, 'grad_norm': 0.3147414028644562, 'learning_rate': 3.5392000000000004e-06, 'epoch': 3.232}
# {'loss': 0.8003, 'grad_norm': 0.3740878701210022, 'learning_rate': 3.5072e-06, 'epoch': 3.248}
# {'loss': 0.7409, 'grad_norm': 0.4099811315536499, 'learning_rate': 3.4752e-06, 'epoch': 3.2640000000000002}
# {'loss': 0.6861, 'grad_norm': 0.37774720788002014, 'learning_rate': 3.4432000000000003e-06, 'epoch': 3.2800000000000002}
# {'loss': 0.7259, 'grad_norm': 0.33684682846069336, 'learning_rate': 3.4112e-06, 'epoch': 3.296}
# {'loss': 0.7862, 'grad_norm': 0.3402084410190582, 'learning_rate': 3.3792e-06, 'epoch': 3.312}
# {'loss': 0.6484, 'grad_norm': 0.2576722502708435, 'learning_rate': 3.3472000000000003e-06, 'epoch': 3.328}
# {'loss': 0.6107, 'grad_norm': 0.3034953474998474, 'learning_rate': 3.3152e-06, 'epoch': 3.344}
# {'loss': 0.7908, 'grad_norm': 0.31462788581848145, 'learning_rate': 3.2832e-06, 'epoch': 3.36}
# {'loss': 0.6641, 'grad_norm': 0.2924870550632477, 'learning_rate': 3.2512000000000003e-06, 'epoch': 3.376}
# {'loss': 0.6182, 'grad_norm': 0.2651987373828888, 'learning_rate': 3.2192e-06, 'epoch': 3.392}
# {'loss': 0.7277, 'grad_norm': 0.3126976191997528, 'learning_rate': 3.1872e-06, 'epoch': 3.408}
# {'loss': 0.6395, 'grad_norm': 0.2730304002761841, 'learning_rate': 3.1552000000000003e-06, 'epoch': 3.424}
# {'loss': 0.7879, 'grad_norm': 0.38101691007614136, 'learning_rate': 3.1232e-06, 'epoch': 3.44}
# {'loss': 0.7342, 'grad_norm': 0.3716447949409485, 'learning_rate': 3.0912e-06, 'epoch': 3.456}
# {'loss': 0.669, 'grad_norm': 0.32492727041244507, 'learning_rate': 3.0592000000000007e-06, 'epoch': 3.472}
# {'loss': 0.662, 'grad_norm': 0.4630308747291565, 'learning_rate': 3.0272e-06, 'epoch': 3.488}
# {'loss': 0.6306, 'grad_norm': 0.2545999586582184, 'learning_rate': 2.9952e-06, 'epoch': 3.504}
# {'loss': 0.5897, 'grad_norm': 0.3059483766555786, 'learning_rate': 2.9632e-06, 'epoch': 3.52}
# {'loss': 0.6292, 'grad_norm': 0.29780688881874084, 'learning_rate': 2.9312e-06, 'epoch': 3.536}
# {'loss': 0.6936, 'grad_norm': 0.37606871128082275, 'learning_rate': 2.8992000000000005e-06, 'epoch': 3.552}
# {'loss': 0.6688, 'grad_norm': 0.3404427468776703, 'learning_rate': 2.8672e-06, 'epoch': 3.568}
# {'loss': 0.6184, 'grad_norm': 0.32228872179985046, 'learning_rate': 2.8352e-06, 'epoch': 3.584}
# {'loss': 0.6458, 'grad_norm': 0.3151572644710541, 'learning_rate': 2.8032000000000005e-06, 'epoch': 3.6}
# {'loss': 0.5813, 'grad_norm': 0.2816193401813507, 'learning_rate': 2.7712e-06, 'epoch': 3.616}
# {'loss': 0.6896, 'grad_norm': 0.292702853679657, 'learning_rate': 2.7392000000000004e-06, 'epoch': 3.632}
# {'loss': 0.7222, 'grad_norm': 0.27935317158699036, 'learning_rate': 2.7072000000000005e-06, 'epoch': 3.648}
# {'loss': 0.7612, 'grad_norm': 0.3608092963695526, 'learning_rate': 2.6752e-06, 'epoch': 3.664}
# {'loss': 0.6932, 'grad_norm': 0.365541934967041, 'learning_rate': 2.6432000000000004e-06, 'epoch': 3.68}
# {'loss': 0.7713, 'grad_norm': 0.3512173891067505, 'learning_rate': 2.6112000000000005e-06, 'epoch': 3.6959999999999997}
# {'loss': 0.6743, 'grad_norm': 0.34893468022346497, 'learning_rate': 2.5792000000000002e-06, 'epoch': 3.7119999999999997}
# {'loss': 0.6421, 'grad_norm': 0.3068530559539795, 'learning_rate': 2.5472000000000004e-06, 'epoch': 3.7279999999999998}
# {'loss': 0.6481, 'grad_norm': 0.3125165104866028, 'learning_rate': 2.5152000000000005e-06, 'epoch': 3.7439999999999998}
# {'loss': 0.7211, 'grad_norm': 0.30533090233802795, 'learning_rate': 2.4832000000000002e-06, 'epoch': 3.76}
# {'loss': 0.7768, 'grad_norm': 0.24834688007831573, 'learning_rate': 2.4512000000000003e-06, 'epoch': 3.776}
# {'loss': 0.6225, 'grad_norm': 0.27118977904319763, 'learning_rate': 2.4192e-06, 'epoch': 3.792}
# {'loss': 0.6408, 'grad_norm': 0.400592178106308, 'learning_rate': 2.3872e-06, 'epoch': 3.808}
# {'loss': 0.75, 'grad_norm': 0.3158128261566162, 'learning_rate': 2.3552000000000003e-06, 'epoch': 3.824}
# {'loss': 0.6555, 'grad_norm': 0.395388126373291, 'learning_rate': 2.3232e-06, 'epoch': 3.84}
# {'loss': 0.623, 'grad_norm': 0.3501506745815277, 'learning_rate': 2.2912e-06, 'epoch': 3.856}
# {'loss': 0.7141, 'grad_norm': 0.30060747265815735, 'learning_rate': 2.2592000000000003e-06, 'epoch': 3.872}
# {'loss': 0.5223, 'grad_norm': 0.3024134337902069, 'learning_rate': 2.2272e-06, 'epoch': 3.888}
# {'loss': 0.7218, 'grad_norm': 0.32546359300613403, 'learning_rate': 2.1952e-06, 'epoch': 3.904}
# {'loss': 0.6755, 'grad_norm': 0.2533681094646454, 'learning_rate': 2.1632000000000003e-06, 'epoch': 3.92}
# {'loss': 0.6198, 'grad_norm': 0.31986743211746216, 'learning_rate': 2.1312e-06, 'epoch': 3.936}
# {'loss': 0.6094, 'grad_norm': 0.293121337890625, 'learning_rate': 2.0992e-06, 'epoch': 3.952}
# {'loss': 0.6842, 'grad_norm': 0.3450773358345032, 'learning_rate': 2.0672e-06, 'epoch': 3.968}
# {'loss': 0.7162, 'grad_norm': 0.3178938627243042, 'learning_rate': 2.0352000000000004e-06, 'epoch': 3.984}
# {'loss': 0.63, 'grad_norm': 0.2816779911518097, 'learning_rate': 2.0032e-06, 'epoch': 4.0}
# {'eval_loss': 0.6573784351348877, 'eval_runtime': 249.2785, 'eval_samples_per_second': 20.058, 'eval_steps_per_second': 2.507, 'epoch': 4.0}
# {'loss': 0.6039, 'grad_norm': 0.3063739538192749, 'learning_rate': 1.9712e-06, 'epoch': 4.016}
# {'loss': 0.6404, 'grad_norm': 0.3477717339992523, 'learning_rate': 1.9392000000000004e-06, 'epoch': 4.032}
# {'loss': 0.7045, 'grad_norm': 0.316999614238739, 'learning_rate': 1.9072000000000001e-06, 'epoch': 4.048}
# {'loss': 0.6619, 'grad_norm': 0.30331265926361084, 'learning_rate': 1.8752e-06, 'epoch': 4.064}
# {'loss': 0.661, 'grad_norm': 0.3184344470500946, 'learning_rate': 1.8432000000000002e-06, 'epoch': 4.08}
# {'loss': 0.7096, 'grad_norm': 0.32955729961395264, 'learning_rate': 1.8112000000000001e-06, 'epoch': 4.096}
# {'loss': 0.7294, 'grad_norm': 0.26179707050323486, 'learning_rate': 1.7792e-06, 'epoch': 4.112}
# {'loss': 0.6744, 'grad_norm': 0.35639044642448425, 'learning_rate': 1.7472e-06, 'epoch': 4.128}
# {'loss': 0.6694, 'grad_norm': 0.3055437505245209, 'learning_rate': 1.7152000000000001e-06, 'epoch': 4.144}
# {'loss': 0.716, 'grad_norm': 0.3688664436340332, 'learning_rate': 1.6832e-06, 'epoch': 4.16}
# {'loss': 0.6369, 'grad_norm': 0.36258938908576965, 'learning_rate': 1.6512e-06, 'epoch': 4.176}
# {'loss': 0.6887, 'grad_norm': 0.31420668959617615, 'learning_rate': 1.6192000000000003e-06, 'epoch': 4.192}
# {'loss': 0.7205, 'grad_norm': 0.3455009162425995, 'learning_rate': 1.5872e-06, 'epoch': 4.208}
# {'loss': 0.6281, 'grad_norm': 0.36896374821662903, 'learning_rate': 1.5552e-06, 'epoch': 4.224}
# {'loss': 0.6901, 'grad_norm': 0.3393552899360657, 'learning_rate': 1.5232000000000003e-06, 'epoch': 4.24}
# {'loss': 0.6684, 'grad_norm': 0.33802565932273865, 'learning_rate': 1.4912000000000002e-06, 'epoch': 4.256}
# {'loss': 0.6159, 'grad_norm': 0.28337159752845764, 'learning_rate': 1.4592000000000001e-06, 'epoch': 4.272}
# {'loss': 0.6683, 'grad_norm': 0.3333803117275238, 'learning_rate': 1.4272000000000003e-06, 'epoch': 4.288}
# {'loss': 0.7295, 'grad_norm': 0.31334787607192993, 'learning_rate': 1.3952000000000002e-06, 'epoch': 4.304}
# {'loss': 0.723, 'grad_norm': 0.3430716097354889, 'learning_rate': 1.3632000000000001e-06, 'epoch': 4.32}
# {'loss': 0.7479, 'grad_norm': 0.32884481549263, 'learning_rate': 1.3312e-06, 'epoch': 4.336}
# {'loss': 0.6888, 'grad_norm': 0.2780594527721405, 'learning_rate': 1.2992000000000002e-06, 'epoch': 4.352}
# {'loss': 0.7002, 'grad_norm': 0.30430641770362854, 'learning_rate': 1.2672000000000001e-06, 'epoch': 4.368}
# {'loss': 0.6316, 'grad_norm': 0.3134707510471344, 'learning_rate': 1.2352e-06, 'epoch': 4.384}
# {'loss': 0.7562, 'grad_norm': 0.4018550515174866, 'learning_rate': 1.2032e-06, 'epoch': 4.4}
# {'loss': 0.7538, 'grad_norm': 0.33185866475105286, 'learning_rate': 1.1712000000000001e-06, 'epoch': 4.416}
# {'loss': 0.6661, 'grad_norm': 0.32287490367889404, 'learning_rate': 1.1392e-06, 'epoch': 4.432}
# {'loss': 0.7403, 'grad_norm': 0.29852530360221863, 'learning_rate': 1.1072000000000002e-06, 'epoch': 4.448}
# {'loss': 0.6389, 'grad_norm': 0.287093847990036, 'learning_rate': 1.0752e-06, 'epoch': 4.464}
# {'loss': 0.667, 'grad_norm': 0.2776528000831604, 'learning_rate': 1.0432e-06, 'epoch': 4.48}
# {'loss': 0.6361, 'grad_norm': 0.3176531195640564, 'learning_rate': 1.0112000000000002e-06, 'epoch': 4.496}
# {'loss': 0.6972, 'grad_norm': 0.3406406342983246, 'learning_rate': 9.792e-07, 'epoch': 4.5120000000000005}
# {'loss': 0.6042, 'grad_norm': 0.2591259181499481, 'learning_rate': 9.472e-07, 'epoch': 4.5280000000000005}
# {'loss': 0.6267, 'grad_norm': 0.2962818443775177, 'learning_rate': 9.152000000000001e-07, 'epoch': 4.5440000000000005}
# {'loss': 0.8517, 'grad_norm': 0.33988142013549805, 'learning_rate': 8.832000000000001e-07, 'epoch': 4.5600000000000005}
# {'loss': 0.6105, 'grad_norm': 0.3342871367931366, 'learning_rate': 8.512000000000001e-07, 'epoch': 4.576}
# {'loss': 0.6831, 'grad_norm': 0.3131347894668579, 'learning_rate': 8.192000000000001e-07, 'epoch': 4.592}
# {'loss': 0.7169, 'grad_norm': 0.3402910828590393, 'learning_rate': 7.872000000000001e-07, 'epoch': 4.608}
# {'loss': 0.6466, 'grad_norm': 0.26401859521865845, 'learning_rate': 7.552000000000001e-07, 'epoch': 4.624}
# {'loss': 0.6113, 'grad_norm': 0.3003730773925781, 'learning_rate': 7.232e-07, 'epoch': 4.64}
# {'loss': 0.6813, 'grad_norm': 0.3206842541694641, 'learning_rate': 6.912e-07, 'epoch': 4.656}
# {'loss': 0.6513, 'grad_norm': 0.4034903943538666, 'learning_rate': 6.592000000000001e-07, 'epoch': 4.672}
# {'loss': 0.6302, 'grad_norm': 0.30915597081184387, 'learning_rate': 6.272e-07, 'epoch': 4.688}
# {'loss': 0.6882, 'grad_norm': 0.31434711813926697, 'learning_rate': 5.952e-07, 'epoch': 4.704}
# {'loss': 0.6489, 'grad_norm': 0.33551308512687683, 'learning_rate': 5.632000000000001e-07, 'epoch': 4.72}
# {'loss': 0.6942, 'grad_norm': 0.3078662157058716, 'learning_rate': 5.312000000000001e-07, 'epoch': 4.736}
# {'loss': 0.775, 'grad_norm': 0.40134328603744507, 'learning_rate': 4.992e-07, 'epoch': 4.752}
# {'loss': 0.7394, 'grad_norm': 0.4127098023891449, 'learning_rate': 4.672e-07, 'epoch': 4.768}
# {'loss': 0.7778, 'grad_norm': 0.26816409826278687, 'learning_rate': 4.352000000000001e-07, 'epoch': 4.784}
# {'loss': 0.6125, 'grad_norm': 0.30835631489753723, 'learning_rate': 4.0320000000000006e-07, 'epoch': 4.8}
# {'loss': 0.5826, 'grad_norm': 0.2785659730434418, 'learning_rate': 3.7120000000000004e-07, 'epoch': 4.816}
# {'loss': 0.57, 'grad_norm': 0.31091657280921936, 'learning_rate': 3.392e-07, 'epoch': 4.832}
# {'loss': 0.6085, 'grad_norm': 0.3088819086551666, 'learning_rate': 3.0720000000000005e-07, 'epoch': 4.848}
# {'loss': 0.6686, 'grad_norm': 0.4375271201133728, 'learning_rate': 2.7520000000000003e-07, 'epoch': 4.864}
# {'loss': 0.7823, 'grad_norm': 0.4197078049182892, 'learning_rate': 2.432e-07, 'epoch': 4.88}
# {'loss': 0.7355, 'grad_norm': 0.31091180443763733, 'learning_rate': 2.112e-07, 'epoch': 4.896}
# {'loss': 0.7007, 'grad_norm': 0.35331904888153076, 'learning_rate': 1.792e-07, 'epoch': 4.912}
# {'loss': 0.6591, 'grad_norm': 0.5056825876235962, 'learning_rate': 1.4720000000000002e-07, 'epoch': 4.928}
# {'loss': 0.716, 'grad_norm': 0.33430424332618713, 'learning_rate': 1.1520000000000001e-07, 'epoch': 4.944}
# {'loss': 0.6948, 'grad_norm': 0.309762567281723, 'learning_rate': 8.32e-08, 'epoch': 4.96}
# {'loss': 0.6844, 'grad_norm': 0.34511280059814453, 'learning_rate': 5.120000000000001e-08, 'epoch': 4.976}
# {'loss': 0.6924, 'grad_norm': 0.3242042660713196, 'learning_rate': 1.9200000000000003e-08, 'epoch': 4.992}
# {'eval_loss': 0.6571118235588074, 'eval_runtime': 249.0065, 'eval_samples_per_second': 20.08, 'eval_steps_per_second': 2.51, 'epoch': 5.0}
# {'train_runtime': 4041.2013, 'train_samples_per_second': 6.186, 'train_steps_per_second': 0.773, 'train_loss': 0.9050247608947753, 'epoch': 5.0}

# %%
# predict with model (measuring time)
t0 = time.perf_counter()

pred_txt = model_llama_lora.predict(
    x=x,
    text_token_limit=256,
    report_interval=100)

pred_num = cm.label3_txt_to_num(pred_txt)

t1 = time.perf_counter()
pred_time_seconds = t1 - t0
pred_time_per_sample = pred_time_seconds / len(pred_num)
# Out:
# Reviews processed: 100
# Reviews processed: 200
# Reviews processed: 300
# Reviews processed: 400
# Reviews processed: 500
# Reviews processed: 600
# Reviews processed: 700
# Reviews processed: 800
# Reviews processed: 900
# Reviews processed: 1000
# Reviews processed: 1100
# Reviews processed: 1200
# Reviews processed: 1300
# Reviews processed: 1400
# Reviews processed: 1500
# Reviews processed: 1600
# Reviews processed: 1700
# Reviews processed: 1800
# Reviews processed: 1900
# Reviews processed: 2000
# Reviews processed: 2100
# Reviews processed: 2200
# Reviews processed: 2300
# Reviews processed: 2400
# Reviews processed: 2500
# Reviews processed: 2600
# Reviews processed: 2700
# Reviews processed: 2800
# Reviews processed: 2900
# Reviews processed: 3000
# Reviews processed: 3100
# Reviews processed: 3200
# Reviews processed: 3300
# Reviews processed: 3400
# Reviews processed: 3500
# Reviews processed: 3600
# Reviews processed: 3700
# Reviews processed: 3800
# Reviews processed: 3900
# Reviews processed: 4000
# Reviews processed: 4100
# Reviews processed: 4200
# Reviews processed: 4300
# Reviews processed: 4400
# Reviews processed: 4500
# Reviews processed: 4600
# Reviews processed: 4700
# Reviews processed: 4800
# Reviews processed: 4900
# Reviews processed: 5000

# %%
# sanity check: accuracy
acc = sum(y == pred_num) / len(pred_num)
print(f"acc cntrl: {acc}")
# Out:
# acc cntrl: 0.8532

# %%
# create a run directory (analogous to KP)
hyperparams = {
    "learning_rate": training_config.learning_rate,
    "train_batch_size": training_config.per_device_train_batch_size,
    "epochs": training_config.num_train_epochs }

run_outdir = utils.make_run_dir(
    output_root="outputs",
    model_name=f"{model_name}_lora_finetuned",
    hyperparams=hyperparams)

print("run_outdir:", run_outdir)
# Out:
# run_outdir: outputs/meta-llama_Llama-3.2-3B-Instruct_lora_finetuned_lr1e-05_bs8_ep5_20251207_012359

# %%
# save model and trainig

# save model weights
model_llama_lora.trainer.save_model(run_outdir)

# save tokenizer
model_llama_lora.tokenizer.save_pretrained(run_outdir)

# save training log_history as csv
log_df = pd.DataFrame(model_llama_lora.log_history)
log_df.to_csv(os.path.join(run_outdir, "training_log_history.csv"), index=False)

# save train_result metrics as JSON
train_result = model_llama_lora.train_result
with open(os.path.join(run_outdir, "train_result.json"), "w") as f:
    # train_result is a TrainOutput; .metrics is usually what you care about
    json.dump(train_result.metrics, f, indent=2)

# %% [markdown]
# # Evaluate Results/ Experiment

# %%
# loss curves on training and validation data (incl. saving)
logs = pd.DataFrame(model_llama_lora.log_history)

train_loss = logs[["epoch", "loss"]].dropna()
eval_loss  = logs[["epoch", "eval_loss"]].dropna()

plt.figure(figsize=(10,6))
plt.plot(train_loss["epoch"], train_loss["loss"], '-o', markersize=6, label="train_loss")
plt.plot(eval_loss["epoch"], eval_loss["eval_loss"], '-o', markersize=6, label="eval_loss")

plt.xlabel("epoch")
plt.ylabel("loss")
plt.title("Training & Validation Loss per Epoch")
plt.legend()
plt.grid(True)

plt.savefig(os.path.join(run_outdir, "loss_curves_epoch.png"), bbox_inches="tight")
plt.show()

# %%
# classification metrics (incl. saving classification report as csv)
metrics = utils.compute_classification_metrics_from_arrays(y_true=y, y_pred=pred_num)
df_cfreport = pd.DataFrame(metrics["classification report"]).T
print(df_cfreport)
path = os.path.join(run_outdir, "classification_report.csv")
df_cfreport.to_csv(path)
# Out:
#               precision    recall  f1-score    support
# 0              0.881897  0.802643  0.840406  1135.0000
# 1              0.336735  0.720874  0.459042   412.0000
# 2              0.991248  0.885607  0.935454  3453.0000
# accuracy       0.853200  0.853200  0.853200     0.8532
# macro avg      0.736627  0.803041  0.744967  5000.0000
# weighted avg   0.912493  0.853200  0.874622  5000.0000

# %%
# confusion matrix (incl. saving)
cm = confusion_matrix(y_true=y, y_pred=pred_num)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
plt.figure(figsize=(6, 6))
disp.plot(values_format='d')
plt.title(f"Confusion Matrix (Llama model)")
path = os.path.join(run_outdir, "confusion_matrix.png")
plt.savefig(path, bbox_inches='tight')
plt.show()

# %%
# evaluate time
print("Training time in seconds:", train_time_seconds)
print("Training time per sample:", train_time_per_sample)
print("Prediction time in seconds:", pred_time_seconds)
print("Prediction time per sample:", pred_time_per_sample)
# Out:
# Training time in seconds: 4057.4402641880006
# Training time per sample: 0.8114880528376002
# Prediction time in seconds: 730.4299329350006
# Prediction time per sample: 0.14608598658700012

# %%
# saving results in team_comparison_results
results_comparison = {
    "n_samples": len(x),
    "train_seconds": train_time_seconds,
    "pred_time_seconds": pred_time_seconds,
    "pred_time_per_sample": pred_time_per_sample,
    "metrics": metrics}

utils.save_results_csv(
    results=results_comparison,
    csv_path=os.path.join("outputs", "team_comparison_results.csv"),
    model_name=f"{model_name}_zeroshot",
    extra_info={"run_outdir": run_outdir})
# Out:
# Appended results to outputs/team_comparison_results.csv

# %%
# saving all results in dictionary
results_all = results_comparison
results_all["train_time_seconds"] = train_time_seconds,
results_all["train_time_per_sample"] = train_time_per_sample,
results_all["model"] = f"{model_name}_zeroshot",
results_all["instruction"] = instruction
path = os.path.join(run_outdir, "results_all.json")
with open(path, "w") as f:
    json.dump(results_all, f, indent=2)
