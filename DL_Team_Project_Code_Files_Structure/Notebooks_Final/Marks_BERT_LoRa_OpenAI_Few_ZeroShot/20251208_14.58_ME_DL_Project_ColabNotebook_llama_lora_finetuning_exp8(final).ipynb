# %% [markdown]
# # Preliminaries and Imports

# %% [markdown]
# Notes:
# - In case of error "Using `bitsandbytes` 4-bit quantization requires the latest version of bitsandbytes: `pip install -U bitsandbytes": The update is already implemented in the notebook. "Restart the session" and "Run all" again because the update seems to require a restart

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# system and path set up
import os
import sys

# path
GOOGLE_DRIVE_PATH = os.path.join('/content', 'drive', 'My Drive', 'ColabNotebooks', 'DL','Deep Learning Project Full','DL Team Project', '20251126_22.47_DL_Team_Project_Code_Files_Structure')

# set working directory (for saving/ loading)
os.chdir(GOOGLE_DRIVE_PATH)

# set import path (for importing src/)
sys.path.insert(0, GOOGLE_DRIVE_PATH)

# verify
print("Current working directory:", os.getcwd())
print("Current import directory:", sys.path[0])
# Out:
# Current working directory: /content/drive/My Drive/ColabNotebooks/DL/Deep Learning Project Full/DL Team Project/20251126_22.47_DL_Team_Project_Code_Files_Structure
# Current import directory: /content/drive/My Drive/ColabNotebooks/DL/Deep Learning Project Full/DL Team Project/20251126_22.47_DL_Team_Project_Code_Files_Structure

# %%
# log into HF
# note: previously store your key as secret (key symbol on the left)
from google.colab import userdata
hf_token = userdata.get('HF_TOKEN')

from huggingface_hub import login
login(token=hf_token)

# Option: silence all HF logs
from transformers.utils.logging import set_verbosity_error
set_verbosity_error()

# %%
# install libraries (only once and then comment out)
# !pip install -q "transformers>=4.40.0" accelerate datasets peft bitsandbytes trl
# !pip install -q -U bitsandbytes transformers accelerate peft trl

# %%
# import standard libraries
import pandas as pd
import time
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import json
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, TrainingArguments
import torch
from peft import LoraConfig

# import utils
from src import utils

# import model
from src.model_llama_lora import CommonMethods, LlamaBaseModel, LlamaLoraModel

# create instance object of CommonMethods
cm = CommonMethods()

# %%
# set seed for reproduceibility (Note: does not work for OpenAI)
seed = 42

# %% [markdown]
# # Load and prepare data

# %%
# load pre-processed data
csv_path_train_data = f"{GOOGLE_DRIVE_PATH}/data/data_train.csv"
csv_path_val_data = f"{GOOGLE_DRIVE_PATH}/data/data_val.csv"
csv_path_test_data = f"{GOOGLE_DRIVE_PATH}/data/data_test.csv"

train_bal = pd.read_csv(csv_path_train_data)
val = pd.read_csv(csv_path_val_data)
test = pd.read_csv(csv_path_test_data)

# %%
# keep only needed columns (drop lang and label5)
train_bal = train_bal.drop(columns=["label5","lang"])
val = val.drop(columns=["label5","lang"])
test = test.drop(columns=["label5","lang"])

# %%
# downsample data
# Note: Fine-tuning on full data would take too long
train_bal = train_bal.sample(n=5000, random_state=seed)
val = val.sample(n=5000, random_state=seed)
test = test.sample(n=20000, random_state=seed)

# %% [markdown]
# # Run model/ Experiment

# %% [markdown]
# Specify model:
# - Choose model type
# - quant_config (= hyperparameters)
# - lora_config (= hyperparameters)
# - training_config (= hyperparameters)
# - Instruction (= hyperparameters)
#
# Specify data for evaluation:
# - val data: for tuning
# - test data: for final run

# %%
# choose model
model_name = "meta-llama/Llama-3.2-3B-Instruct" # "meta-llama/Meta-Llama-3-8B-Instruct"

# %%
# set quantification configuration
quant_config = BitsAndBytesConfig(
    load_in_4_bit=True,
    bnb_4bit_use_double_quant=False,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16)

# %%
peft_config = LoraConfig(
    r=8, # Default 8; size of low-rank update matrice; higher r --> larger trainable capacity                              # 1st prio hyperparameter
    lora_alpha=16, # Default 8;  scaling of loRA updates before adding to base model; higher alpha --> higher loRA effect   # 1st prio hyperparameter
    lora_dropout=0.05, # Default 0;  regularization withing LoRA
    bias="none", # Default None; base model bias not modified
    task_type="CAUSAL_LM", # Default "Causal_LM"; type is LLM
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj"]) # Default None; base model modules to which loRA is applied

# %%
# instruction
instruction = "Classify the following product review into one of: negative, neutral, positive."

# %%
# set x and y variables for evaluation
# Note: Does not affect train (uses always train data and val data) but only evaluation metrics
x = val["text"] # choose from: val["text"], test["text"]
y = val["label3"] # choose from: val["label3"], test["label3"]

# %%
# create instance of model
model_llama_lora = LlamaLoraModel(model_name, quant_config, peft_config, instruction)
# Out:
# model.safetensors.index.json:   0%|          | 0.00/20.9k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# trainable params: 4,587,520 || all params: 3,217,337,344 || trainable%: 0.1426
# tokenizer_config.json:   0%|          | 0.00/54.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]

# %%
# train model (measuring time)
t0 = time.perf_counter()

training_config = TrainingArguments(
    output_dir="outputs/llama3_lora_trainer",
    num_train_epochs=10, # default 3               # 1st prio hyperparameter
    per_device_train_batch_size=1, # default 8
    per_device_eval_batch_size=8, # default 8
    gradient_accumulation_steps=8,
    learning_rate=5e-5, # default 2e-4            # 1st prio hyperparameter
    logging_steps=10, # default 500
    eval_strategy="epoch", # default "no"
    save_strategy="epoch", # default "steps"
    load_best_model_at_end=True, # default False
    fp16=True, # default False
    report_to=[]) # defaulte None

model_llama_lora.train(
    x_train=train_bal["text"],
    y_train=cm.label3_num_to_txt(train_bal["label3"]),
    x_val=val["text"],
    y_val=cm.label3_num_to_txt(val["label3"]),
    training_config = training_config,
    text_token_limit=256)

t1 = time.perf_counter()
train_time_seconds = t1 - t0
train_time_per_sample = train_time_seconds / len(train_bal["label3"])
# Out:
# Map:   0%|          | 0/5000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5000 [00:00<?, ? examples/s]
# {'loss': 6.86, 'grad_norm': 15.737404823303223, 'learning_rate': 4.9928e-05, 'epoch': 0.016}
# {'loss': 2.9219, 'grad_norm': 2.842545509338379, 'learning_rate': 4.9848e-05, 'epoch': 0.032}
# {'loss': 1.0692, 'grad_norm': 0.5452031493186951, 'learning_rate': 4.9768e-05, 'epoch': 0.048}
# {'loss': 0.9982, 'grad_norm': 0.42461398243904114, 'learning_rate': 4.9688e-05, 'epoch': 0.064}
# {'loss': 0.7715, 'grad_norm': 0.4003520905971527, 'learning_rate': 4.9608000000000003e-05, 'epoch': 0.08}
# {'loss': 0.7705, 'grad_norm': 0.7146596908569336, 'learning_rate': 4.9528000000000004e-05, 'epoch': 0.096}
# {'loss': 0.6072, 'grad_norm': 0.26851680874824524, 'learning_rate': 4.9448e-05, 'epoch': 0.112}
# {'loss': 0.6516, 'grad_norm': 0.24380844831466675, 'learning_rate': 4.9368000000000006e-05, 'epoch': 0.128}
# {'loss': 0.6392, 'grad_norm': 0.25618496537208557, 'learning_rate': 4.9288e-05, 'epoch': 0.144}
# {'loss': 0.6301, 'grad_norm': 0.3758060336112976, 'learning_rate': 4.920800000000001e-05, 'epoch': 0.16}
# {'loss': 0.6415, 'grad_norm': 0.3504781424999237, 'learning_rate': 4.9128e-05, 'epoch': 0.176}
# {'loss': 0.5511, 'grad_norm': 0.3419753313064575, 'learning_rate': 4.0888000000000006e-05, 'epoch': 1.8239999999999998}
# {'loss': 0.6366, 'grad_norm': 0.3692615032196045, 'learning_rate': 4.0808e-05, 'epoch': 1.8399999999999999}
# {'loss': 0.6037, 'grad_norm': 0.3807281255722046, 'learning_rate': 4.0728e-05, 'epoch': 1.8559999999999999}
# {'loss': 0.632, 'grad_norm': 0.35632139444351196, 'learning_rate': 4.0648e-05, 'epoch': 1.8719999999999999}
# {'loss': 0.544, 'grad_norm': 0.29820919036865234, 'learning_rate': 4.0568e-05, 'epoch': 1.888}
# {'loss': 0.6176, 'grad_norm': 0.3674999177455902, 'learning_rate': 4.0488e-05, 'epoch': 1.904}
# {'loss': 0.5236, 'grad_norm': 0.37881138920783997, 'learning_rate': 4.0408000000000003e-05, 'epoch': 1.92}
# {'loss': 0.5369, 'grad_norm': 0.4091024100780487, 'learning_rate': 4.0328000000000004e-05, 'epoch': 1.936}
# {'loss': 0.7058, 'grad_norm': 0.4896053671836853, 'learning_rate': 4.0248000000000005e-05, 'epoch': 1.952}
# {'loss': 0.5141, 'grad_norm': 0.2840960919857025, 'learning_rate': 4.0168e-05, 'epoch': 1.968}
# {'loss': 0.6173, 'grad_norm': 0.39900583028793335, 'learning_rate': 4.0088000000000006e-05, 'epoch': 1.984}
# {'loss': 0.6418, 'grad_norm': 0.4618455171585083, 'learning_rate': 4.0008e-05, 'epoch': 2.0}
# {'eval_loss': 0.5854822397232056, 'eval_runtime': 250.0668, 'eval_samples_per_second': 19.995, 'eval_steps_per_second': 2.499, 'epoch': 2.0}
# {'loss': 0.635, 'grad_norm': 0.3650568425655365, 'learning_rate': 3.9928e-05, 'epoch': 2.016}
# {'loss': 0.588, 'grad_norm': 0.3755410611629486, 'learning_rate': 3.9848e-05, 'epoch': 2.032}
# {'loss': 0.6203, 'grad_norm': 0.32545799016952515, 'learning_rate': 3.9768e-05, 'epoch': 2.048}
# {'loss': 0.6317, 'grad_norm': 0.4151894748210907, 'learning_rate': 3.9688000000000004e-05, 'epoch': 2.064}
# {'loss': 0.646, 'grad_norm': 0.32742398977279663, 'learning_rate': 3.9608e-05, 'epoch': 2.08}
# {'loss': 0.6113, 'grad_norm': 0.4123004376888275, 'learning_rate': 3.9528000000000005e-05, 'epoch': 2.096}
# {'loss': 0.6684, 'grad_norm': 0.3632335960865021, 'learning_rate': 3.9448e-05, 'epoch': 2.112}
# {'loss': 0.5425, 'grad_norm': 0.3539675772190094, 'learning_rate': 3.9368e-05, 'epoch': 2.128}
# {'loss': 0.5302, 'grad_norm': 0.3462221622467041, 'learning_rate': 3.9288e-05, 'epoch': 2.144}
# {'loss': 0.6162, 'grad_norm': 0.40817946195602417, 'learning_rate': 3.9208e-05, 'epoch': 2.16}
# {'loss': 0.5041, 'grad_norm': 0.42277073860168457, 'learning_rate': 3.9128e-05, 'epoch': 2.176}
# {'loss': 0.5791, 'grad_norm': 0.42306506633758545, 'learning_rate': 3.9048e-05, 'epoch': 2.192}
# {'loss': 0.6021, 'grad_norm': 0.3413132131099701, 'learning_rate': 3.8968000000000004e-05, 'epoch': 2.208}
# {'loss': 0.4668, 'grad_norm': 0.3897750675678253, 'learning_rate': 3.6888e-05, 'epoch': 2.624}
# {'loss': 0.5525, 'grad_norm': 0.37072256207466125, 'learning_rate': 3.6808000000000004e-05, 'epoch': 2.64}
# {'loss': 0.511, 'grad_norm': 0.43736594915390015, 'learning_rate': 3.6728e-05, 'epoch': 2.656}
# {'loss': 0.6553, 'grad_norm': 0.4960760474205017, 'learning_rate': 3.6648e-05, 'epoch': 2.672}
# {'loss': 0.5654, 'grad_norm': 0.40233904123306274, 'learning_rate': 3.6568e-05, 'epoch': 2.6879999999999997}
# {'loss': 0.556, 'grad_norm': 0.33259057998657227, 'learning_rate': 3.6488e-05, 'epoch': 2.7039999999999997}
# {'loss': 0.5284, 'grad_norm': 0.37433406710624695, 'learning_rate': 3.6408e-05, 'epoch': 2.7199999999999998}
# {'loss': 0.4922, 'grad_norm': 0.408225417137146, 'learning_rate': 3.6328e-05, 'epoch': 2.7359999999999998}
# {'loss': 0.6237, 'grad_norm': 0.36709558963775635, 'learning_rate': 3.6248e-05, 'epoch': 2.752}
# {'loss': 0.5969, 'grad_norm': 0.498872309923172, 'learning_rate': 3.6168e-05, 'epoch': 2.768}
# {'loss': 0.5157, 'grad_norm': 0.3367219865322113, 'learning_rate': 3.6088e-05, 'epoch': 2.784}
# {'loss': 0.5651, 'grad_norm': 0.4888646900653839, 'learning_rate': 3.6008000000000005e-05, 'epoch': 2.8}
# {'loss': 0.5783, 'grad_norm': 0.5588573217391968, 'learning_rate': 3.5928e-05, 'epoch': 2.816}
# {'loss': 0.5045, 'grad_norm': 0.33640414476394653, 'learning_rate': 3.5848000000000006e-05, 'epoch': 2.832}
# {'loss': 0.5744, 'grad_norm': 0.6214923858642578, 'learning_rate': 3.5768e-05, 'epoch': 2.848}
# {'loss': 0.6578, 'grad_norm': 0.5637479424476624, 'learning_rate': 3.5688e-05, 'epoch': 2.864}
# {'loss': 0.4979, 'grad_norm': 0.31120923161506653, 'learning_rate': 3.5608e-05, 'epoch': 2.88}
# {'loss': 0.6754, 'grad_norm': 0.30593380331993103, 'learning_rate': 3.5528e-05, 'epoch': 2.896}
# {'loss': 0.7101, 'grad_norm': 0.4355470538139343, 'learning_rate': 3.5448000000000003e-05, 'epoch': 2.912}
# {'loss': 0.6115, 'grad_norm': 0.49609076976776123, 'learning_rate': 3.5368000000000004e-05, 'epoch': 2.928}
# {'loss': 0.587, 'grad_norm': 0.5278406739234924, 'learning_rate': 3.5288000000000005e-05, 'epoch': 2.944}
# {'loss': 0.6123, 'grad_norm': 0.3752427399158478, 'learning_rate': 3.5208e-05, 'epoch': 2.96}
# {'loss': 0.6386, 'grad_norm': 0.4913792908191681, 'learning_rate': 3.5128e-05, 'epoch': 2.976}
# {'loss': 0.5424, 'grad_norm': 0.40447303652763367, 'learning_rate': 3.5048e-05, 'epoch': 2.992}
# {'eval_loss': 0.5831810832023621, 'eval_runtime': 250.1289, 'eval_samples_per_second': 19.99, 'eval_steps_per_second': 2.499, 'epoch': 3.0}
# {'loss': 0.6492, 'grad_norm': 0.32910656929016113, 'learning_rate': 3.4968e-05, 'epoch': 3.008}
# {'loss': 0.5816, 'grad_norm': 0.4488678574562073, 'learning_rate': 3.4888e-05, 'epoch': 3.024}
# {'loss': 0.6183, 'grad_norm': 0.5405856966972351, 'learning_rate': 3.4808e-05, 'epoch': 3.04}
# {'loss': 0.5328, 'grad_norm': 0.3870396018028259, 'learning_rate': 3.4728e-05, 'epoch': 3.056}
# {'loss': 0.6519, 'grad_norm': 0.40878236293792725, 'learning_rate': 3.4648000000000004e-05, 'epoch': 3.072}
# {'loss': 0.6374, 'grad_norm': 0.38375598192214966, 'learning_rate': 3.4568e-05, 'epoch': 3.088}
# {'loss': 0.5498, 'grad_norm': 0.39293113350868225, 'learning_rate': 3.4488000000000006e-05, 'epoch': 3.104}
# {'loss': 0.6222, 'grad_norm': 0.47631335258483887, 'learning_rate': 3.4408e-05, 'epoch': 3.12}
# {'loss': 0.5076, 'grad_norm': 0.4851366877555847, 'learning_rate': 3.4328e-05, 'epoch': 3.136}
# {'loss': 0.5419, 'grad_norm': 0.3576410710811615, 'learning_rate': 3.4248e-05, 'epoch': 3.152}
# {'loss': 0.5645, 'grad_norm': 0.4505915641784668, 'learning_rate': 3.4168e-05, 'epoch': 3.168}
# {'loss': 0.6465, 'grad_norm': 0.41259923577308655, 'learning_rate': 3.4088e-05, 'epoch': 3.184}
# {'loss': 0.5993, 'grad_norm': 0.5428000092506409, 'learning_rate': 3.4008000000000004e-05, 'epoch': 3.2}
# {'loss': 0.6028, 'grad_norm': 0.5050920248031616, 'learning_rate': 3.3928000000000004e-05, 'epoch': 3.216}
# {'loss': 0.6384, 'grad_norm': 0.4165284335613251, 'learning_rate': 3.3848000000000005e-05, 'epoch': 3.232}
# {'loss': 0.6942, 'grad_norm': 0.5404072999954224, 'learning_rate': 3.3768e-05, 'epoch': 3.248}
# {'loss': 0.6428, 'grad_norm': 0.5911503434181213, 'learning_rate': 3.3688e-05, 'epoch': 3.2640000000000002}
# {'loss': 0.5915, 'grad_norm': 0.6190457344055176, 'learning_rate': 3.3608e-05, 'epoch': 3.2800000000000002}
# {'loss': 0.6252, 'grad_norm': 0.5337508916854858, 'learning_rate': 3.3528e-05, 'epoch': 3.296}
# {'loss': 0.6852, 'grad_norm': 0.5309059023857117, 'learning_rate': 3.3448e-05, 'epoch': 3.312}
# {'loss': 0.5543, 'grad_norm': 0.33607518672943115, 'learning_rate': 3.3367999999999996e-05, 'epoch': 3.328}
# {'loss': 0.5272, 'grad_norm': 0.5543857216835022, 'learning_rate': 3.3288000000000004e-05, 'epoch': 3.344}
# {'loss': 0.693, 'grad_norm': 0.5229466557502747, 'learning_rate': 3.3208e-05, 'epoch': 3.36}
# {'loss': 0.5709, 'grad_norm': 0.4858395755290985, 'learning_rate': 3.3128000000000005e-05, 'epoch': 3.376}
# {'loss': 0.5266, 'grad_norm': 0.3843475580215454, 'learning_rate': 3.3048e-05, 'epoch': 3.392}
# {'loss': 0.6341, 'grad_norm': 0.4449688196182251, 'learning_rate': 3.2968e-05, 'epoch': 3.408}
# {'loss': 0.5502, 'grad_norm': 0.4455445110797882, 'learning_rate': 3.2888e-05, 'epoch': 3.424}
# {'loss': 0.6899, 'grad_norm': 0.5357557535171509, 'learning_rate': 3.2808e-05, 'epoch': 3.44}
# {'loss': 0.6382, 'grad_norm': 0.6678001284599304, 'learning_rate': 3.2728e-05, 'epoch': 3.456}
# {'loss': 0.5766, 'grad_norm': 0.4709216058254242, 'learning_rate': 3.2648e-05, 'epoch': 3.472}
# {'loss': 0.5693, 'grad_norm': 0.6653026938438416, 'learning_rate': 3.2568000000000004e-05, 'epoch': 3.488}
# {'loss': 0.5444, 'grad_norm': 0.34104737639427185, 'learning_rate': 3.2488000000000005e-05, 'epoch': 3.504}
# {'loss': 0.498, 'grad_norm': 0.37236088514328003, 'learning_rate': 3.2408e-05, 'epoch': 3.52}
# {'loss': 0.5398, 'grad_norm': 0.4204108417034149, 'learning_rate': 3.2328e-05, 'epoch': 3.536}
# {'loss': 0.5999, 'grad_norm': 0.47105100750923157, 'learning_rate': 3.2248e-05, 'epoch': 3.552}
# {'loss': 0.5768, 'grad_norm': 0.5600220561027527, 'learning_rate': 3.2168e-05, 'epoch': 3.568}
# {'loss': 0.5285, 'grad_norm': 0.366511732339859, 'learning_rate': 3.2088e-05, 'epoch': 3.584}
# {'loss': 0.5589, 'grad_norm': 0.48357096314430237, 'learning_rate': 3.2007999999999996e-05, 'epoch': 3.6}
# {'loss': 0.498, 'grad_norm': 0.378255158662796, 'learning_rate': 3.1928e-05, 'epoch': 3.616}
# {'loss': 0.5956, 'grad_norm': 0.46749061346054077, 'learning_rate': 3.1848e-05, 'epoch': 3.632}
# {'loss': 0.622, 'grad_norm': 0.38697272539138794, 'learning_rate': 3.1768000000000005e-05, 'epoch': 3.648}
# {'loss': 0.656, 'grad_norm': 0.6243830919265747, 'learning_rate': 3.1688e-05, 'epoch': 3.664}
# {'loss': 0.5981, 'grad_norm': 0.4761483073234558, 'learning_rate': 3.1608000000000006e-05, 'epoch': 3.68}
# {'loss': 0.6687, 'grad_norm': 0.5528529286384583, 'learning_rate': 3.1528e-05, 'epoch': 3.6959999999999997}
# {'loss': 0.5823, 'grad_norm': 0.4280432462692261, 'learning_rate': 3.1448e-05, 'epoch': 3.7119999999999997}
# {'loss': 0.5472, 'grad_norm': 0.4877234399318695, 'learning_rate': 3.1368e-05, 'epoch': 3.7279999999999998}
# {'loss': 0.5592, 'grad_norm': 0.4966004490852356, 'learning_rate': 3.1288e-05, 'epoch': 3.7439999999999998}
# {'loss': 0.6251, 'grad_norm': 0.4459927976131439, 'learning_rate': 3.1208000000000003e-05, 'epoch': 3.76}
# {'loss': 0.6782, 'grad_norm': 0.4128517806529999, 'learning_rate': 3.1128000000000004e-05, 'epoch': 3.776}
# {'loss': 0.5373, 'grad_norm': 0.3913060128688812, 'learning_rate': 3.1048e-05, 'epoch': 3.792}
# {'loss': 0.5524, 'grad_norm': 0.5309343934059143, 'learning_rate': 3.0968000000000006e-05, 'epoch': 3.808}
# {'loss': 0.6495, 'grad_norm': 0.3964200019836426, 'learning_rate': 3.0888e-05, 'epoch': 3.824}
# {'loss': 0.6517, 'grad_norm': 0.520115315914154, 'learning_rate': 2.0728e-05, 'epoch': 5.856}
# {'loss': 0.4744, 'grad_norm': 0.6079220175743103, 'learning_rate': 2.0648e-05, 'epoch': 5.872}
# {'loss': 0.6555, 'grad_norm': 0.7067061066627502, 'learning_rate': 2.0568e-05, 'epoch': 5.888}
# {'loss': 0.6279, 'grad_norm': 0.6338148713111877, 'learning_rate': 2.0488e-05, 'epoch': 5.904}
# {'loss': 0.5868, 'grad_norm': 0.7270810604095459, 'learning_rate': 2.0408000000000002e-05, 'epoch': 5.92}
# {'loss': 0.5807, 'grad_norm': 0.6055915951728821, 'learning_rate': 2.0328e-05, 'epoch': 5.936}
# {'loss': 0.5856, 'grad_norm': 0.5454917550086975, 'learning_rate': 2.0248e-05, 'epoch': 5.952}
# {'loss': 0.5889, 'grad_norm': 0.7512632012367249, 'learning_rate': 2.0168e-05, 'epoch': 5.968}
# {'loss': 0.5911, 'grad_norm': 0.7406507134437561, 'learning_rate': 2.0088e-05, 'epoch': 5.984}
# {'loss': 0.5879, 'grad_norm': 0.6709603071212769, 'learning_rate': 2.0008000000000002e-05, 'epoch': 6.0}
# {'eval_loss': 0.585326611995697, 'eval_runtime': 250.0431, 'eval_samples_per_second': 19.997, 'eval_steps_per_second': 2.5, 'epoch': 6.0}
# {'loss': 0.5646, 'grad_norm': 0.5076364874839783, 'learning_rate': 1.9928000000000003e-05, 'epoch': 6.016}
# {'loss': 0.4596, 'grad_norm': 0.6062214374542236, 'learning_rate': 1.9848e-05, 'epoch': 6.032}
# {'loss': 0.5, 'grad_norm': 0.6802386045455933, 'learning_rate': 1.9768e-05, 'epoch': 6.048}
# {'loss': 0.5865, 'grad_norm': 0.5459662079811096, 'learning_rate': 1.9688000000000002e-05, 'epoch': 6.064}
# {'loss': 0.5323, 'grad_norm': 0.7016941905021667, 'learning_rate': 1.9608000000000003e-05, 'epoch': 6.08}
# {'loss': 0.5891, 'grad_norm': 0.763863742351532, 'learning_rate': 1.9528000000000003e-05, 'epoch': 6.096}
# {'loss': 0.5306, 'grad_norm': 0.7805910110473633, 'learning_rate': 1.9448e-05, 'epoch': 6.112}
# {'loss': 0.6261, 'grad_norm': 0.7240073084831238, 'learning_rate': 1.9368e-05, 'epoch': 6.128}
# {'loss': 0.632, 'grad_norm': 0.6548426747322083, 'learning_rate': 1.9288e-05, 'epoch': 6.144}
# {'loss': 0.5081, 'grad_norm': 0.4325219392776489, 'learning_rate': 1.9208e-05, 'epoch': 6.16}
# {'loss': 0.5911, 'grad_norm': 0.5571923851966858, 'learning_rate': 1.9128e-05, 'epoch': 6.176}
# {'loss': 0.6124, 'grad_norm': 0.6592058539390564, 'learning_rate': 1.9048e-05, 'epoch': 6.192}
# {'loss': 0.5945, 'grad_norm': 0.649423360824585, 'learning_rate': 1.8968e-05, 'epoch': 6.208}
# {'loss': 0.5296, 'grad_norm': 0.5512552857398987, 'learning_rate': 1.8888e-05, 'epoch': 6.224}
# {'loss': 0.5441, 'grad_norm': 0.6580283045768738, 'learning_rate': 1.8808e-05, 'epoch': 6.24}
# {'loss': 0.5272, 'grad_norm': 0.6105251312255859, 'learning_rate': 1.8728e-05, 'epoch': 6.256}
# {'loss': 0.574, 'grad_norm': 0.5953088998794556, 'learning_rate': 1.8648000000000002e-05, 'epoch': 6.272}
# {'loss': 0.5413, 'grad_norm': 0.7383724451065063, 'learning_rate': 1.8568000000000002e-05, 'epoch': 6.288}
# {'loss': 0.4608, 'grad_norm': 0.55012446641922, 'learning_rate': 1.8488e-05, 'epoch': 6.304}
# {'loss': 0.5752, 'grad_norm': 0.6394742131233215, 'learning_rate': 1.8408e-05, 'epoch': 6.32}
# {'loss': 0.5732, 'grad_norm': 0.5783566236495972, 'learning_rate': 1.8328e-05, 'epoch': 6.336}
# {'loss': 0.5631, 'grad_norm': 0.5561321377754211, 'learning_rate': 1.8248000000000002e-05, 'epoch': 6.352}
# {'loss': 0.5561, 'grad_norm': 0.7329123020172119, 'learning_rate': 1.8168000000000003e-05, 'epoch': 6.368}
# {'loss': 0.5628, 'grad_norm': 0.8023030161857605, 'learning_rate': 1.8088000000000004e-05, 'epoch': 6.384}
# {'loss': 0.5257, 'grad_norm': 0.6406149864196777, 'learning_rate': 1.8008e-05, 'epoch': 6.4}
# {'loss': 0.5274, 'grad_norm': 0.5882906317710876, 'learning_rate': 1.7928000000000002e-05, 'epoch': 6.416}
# {'loss': 0.5962, 'grad_norm': 0.5897676944732666, 'learning_rate': 1.7848e-05, 'epoch': 6.432}
# {'loss': 0.5542, 'grad_norm': 0.7542491555213928, 'learning_rate': 1.7768e-05, 'epoch': 6.448}
# {'loss': 0.5198, 'grad_norm': 0.6672834753990173, 'learning_rate': 1.7688e-05, 'epoch': 6.464}
# {'loss': 0.5635, 'grad_norm': 0.7546259164810181, 'learning_rate': 1.7607999999999998e-05, 'epoch': 6.48}
# {'loss': 0.5979, 'grad_norm': 0.6181226372718811, 'learning_rate': 1.7528e-05, 'epoch': 6.496}
# {'loss': 0.5888, 'grad_norm': 0.568160891532898, 'learning_rate': 1.7448e-05, 'epoch': 6.5120000000000005}
# {'loss': 0.5838, 'grad_norm': 0.7321298122406006, 'learning_rate': 1.7368e-05, 'epoch': 6.5280000000000005}
# {'loss': 0.6429, 'grad_norm': 0.6582692861557007, 'learning_rate': 1.7288e-05, 'epoch': 6.5440000000000005}
# {'loss': 0.5633, 'grad_norm': 0.5849172472953796, 'learning_rate': 1.7208000000000002e-05, 'epoch': 6.5600000000000005}
# {'loss': 0.4798, 'grad_norm': 0.4746491312980652, 'learning_rate': 1.7128e-05, 'epoch': 6.576}
# {'loss': 0.5722, 'grad_norm': 0.6953712105751038, 'learning_rate': 1.7048e-05, 'epoch': 6.592}
# {'loss': 0.5547, 'grad_norm': 0.6675707697868347, 'learning_rate': 1.6968e-05, 'epoch': 6.608}
# {'loss': 0.6, 'grad_norm': 0.7722304463386536, 'learning_rate': 1.6888e-05, 'epoch': 6.624}
# {'loss': 0.5699, 'grad_norm': 0.7935171127319336, 'learning_rate': 1.6808000000000002e-05, 'epoch': 6.64}
# {'loss': 0.5865, 'grad_norm': 0.7341814637184143, 'learning_rate': 1.6728000000000003e-05, 'epoch': 6.656}
# {'loss': 0.5838, 'grad_norm': 0.7408921718597412, 'learning_rate': 1.4728e-05, 'epoch': 7.056}
# {'loss': 0.5651, 'grad_norm': 0.6039857268333435, 'learning_rate': 1.4648000000000001e-05, 'epoch': 7.072}
# {'loss': 0.5318, 'grad_norm': 0.6116089820861816, 'learning_rate': 1.4568000000000002e-05, 'epoch': 7.088}
# {'loss': 0.5592, 'grad_norm': 0.6737004518508911, 'learning_rate': 1.4488000000000001e-05, 'epoch': 7.104}
# {'loss': 0.5557, 'grad_norm': 0.6332294344902039, 'learning_rate': 1.4408000000000002e-05, 'epoch': 7.12}
# {'loss': 0.5116, 'grad_norm': 0.6492121815681458, 'learning_rate': 1.4327999999999999e-05, 'epoch': 7.136}
# {'loss': 0.4945, 'grad_norm': 0.7165299654006958, 'learning_rate': 1.4248e-05, 'epoch': 7.152}
# {'loss': 0.6203, 'grad_norm': 0.7127444744110107, 'learning_rate': 1.4168e-05, 'epoch': 7.168}
# {'loss': 0.4652, 'grad_norm': 0.6664612293243408, 'learning_rate': 1.4088000000000001e-05, 'epoch': 7.184}
# {'loss': 0.5552, 'grad_norm': 0.5157617330551147, 'learning_rate': 1.4008000000000002e-05, 'epoch': 7.2}
# {'loss': 0.5301, 'grad_norm': 0.8567983508110046, 'learning_rate': 1.3928e-05, 'epoch': 7.216}
# {'loss': 0.5337, 'grad_norm': 0.6015255451202393, 'learning_rate': 1.3848e-05, 'epoch': 7.232}
# {'loss': 0.6319, 'grad_norm': 0.8562005758285522, 'learning_rate': 1.3768000000000001e-05, 'epoch': 7.248}
# {'loss': 0.6047, 'grad_norm': 0.8359009027481079, 'learning_rate': 1.3688e-05, 'epoch': 7.264}
# {'loss': 0.5272, 'grad_norm': 0.6862558722496033, 'learning_rate': 1.3608e-05, 'epoch': 7.28}
# {'loss': 0.5383, 'grad_norm': 0.7709558010101318, 'learning_rate': 1.3528000000000002e-05, 'epoch': 7.296}
# {'loss': 0.5225, 'grad_norm': 0.6664705276489258, 'learning_rate': 1.3447999999999999e-05, 'epoch': 7.312}
# {'loss': 0.5599, 'grad_norm': 0.5474440455436707, 'learning_rate': 1.3368e-05, 'epoch': 7.328}
# {'loss': 0.6012, 'grad_norm': 0.880897581577301, 'learning_rate': 1.3288e-05, 'epoch': 7.344}
# {'loss': 0.5498, 'grad_norm': 0.711861789226532, 'learning_rate': 1.3208000000000001e-05, 'epoch': 7.36}
# {'loss': 0.4652, 'grad_norm': 0.5973975658416748, 'learning_rate': 1.3128000000000002e-05, 'epoch': 7.376}
# {'loss': 0.5529, 'grad_norm': 0.5272967219352722, 'learning_rate': 1.3048000000000001e-05, 'epoch': 7.392}
# {'loss': 0.7538, 'grad_norm': 0.9928835034370422, 'learning_rate': 1.2968e-05, 'epoch': 7.408}
# {'loss': 0.6517, 'grad_norm': 0.9073143601417542, 'learning_rate': 1.2888e-05, 'epoch': 7.424}
# {'loss': 0.603, 'grad_norm': 0.6949570775032043, 'learning_rate': 1.2808e-05, 'epoch': 7.44}
# {'loss': 0.6223, 'grad_norm': 0.6401268839836121, 'learning_rate': 1.2728e-05, 'epoch': 7.456}
# {'loss': 0.5087, 'grad_norm': 0.7099550366401672, 'learning_rate': 1.2648000000000002e-05, 'epoch': 7.4719999999999995}
# {'loss': 0.5514, 'grad_norm': 0.7000396251678467, 'learning_rate': 1.2567999999999999e-05, 'epoch': 7.4879999999999995}
# {'loss': 0.529, 'grad_norm': 0.572024405002594, 'learning_rate': 1.2488000000000001e-05, 'epoch': 7.504}
# {'loss': 0.6094, 'grad_norm': 0.7339284420013428, 'learning_rate': 1.2408e-05, 'epoch': 7.52}
# {'loss': 0.6282, 'grad_norm': 0.5820149779319763, 'learning_rate': 1.2328000000000001e-05, 'epoch': 7.536}
# {'loss': 0.5772, 'grad_norm': 0.8715915083885193, 'learning_rate': 1.2248e-05, 'epoch': 7.552}
# {'loss': 0.5623, 'grad_norm': 0.809249997138977, 'learning_rate': 1.2168000000000001e-05, 'epoch': 7.568}
# {'loss': 0.4866, 'grad_norm': 0.6728459596633911, 'learning_rate': 1.2088e-05, 'epoch': 7.584}
# {'loss': 0.5608, 'grad_norm': 0.7599304914474487, 'learning_rate': 1.2008000000000001e-05, 'epoch': 7.6}
# {'loss': 0.54, 'grad_norm': 0.8395556211471558, 'learning_rate': 1.1928e-05, 'epoch': 7.616}
# {'loss': 0.5349, 'grad_norm': 0.6891101002693176, 'learning_rate': 1.1848e-05, 'epoch': 7.632}
# {'loss': 0.5101, 'grad_norm': 0.692615807056427, 'learning_rate': 1.1768000000000002e-05, 'epoch': 7.648}
# {'loss': 0.4914, 'grad_norm': 0.6400339007377625, 'learning_rate': 1.1688e-05, 'epoch': 7.664}
# {'loss': 0.6841, 'grad_norm': 0.662362813949585, 'learning_rate': 1.1608000000000001e-05, 'epoch': 7.68}
# {'loss': 0.5485, 'grad_norm': 0.7040774822235107, 'learning_rate': 1.1528e-05, 'epoch': 7.696}
# {'loss': 0.5281, 'grad_norm': 0.5846793055534363, 'learning_rate': 1.1448000000000001e-05, 'epoch': 7.712}
# {'loss': 0.5976, 'grad_norm': 0.8189308643341064, 'learning_rate': 1.1368e-05, 'epoch': 7.728}
# {'loss': 0.5407, 'grad_norm': 0.6470640897750854, 'learning_rate': 1.1288e-05, 'epoch': 7.744}
# {'loss': 0.6291, 'grad_norm': 0.9318469762802124, 'learning_rate': 1.1208e-05, 'epoch': 7.76}
# {'loss': 0.641, 'grad_norm': 0.6466763019561768, 'learning_rate': 1.1128000000000001e-05, 'epoch': 7.776}
# {'loss': 0.5761, 'grad_norm': 1.1150057315826416, 'learning_rate': 1.1048e-05, 'epoch': 7.792}
# {'loss': 0.5472, 'grad_norm': 0.7025788426399231, 'learning_rate': 1.0968e-05, 'epoch': 7.808}
# {'loss': 0.5038, 'grad_norm': 0.8908010721206665, 'learning_rate': 1.0888000000000001e-05, 'epoch': 7.824}
# {'loss': 0.4812, 'grad_norm': 0.7676671743392944, 'learning_rate': 1.0808e-05, 'epoch': 7.84}
# {'loss': 0.5127, 'grad_norm': 0.5467104315757751, 'learning_rate': 1.0728000000000001e-05, 'epoch': 7.856}
# {'loss': 0.583, 'grad_norm': 0.5807782411575317, 'learning_rate': 1.0648e-05, 'epoch': 7.872}
# {'loss': 0.5321, 'grad_norm': 0.7242486476898193, 'learning_rate': 4.488000000000001e-06, 'epoch': 9.104}
# {'loss': 0.5027, 'grad_norm': 0.8159633874893188, 'learning_rate': 4.408e-06, 'epoch': 9.12}
# {'loss': 0.5997, 'grad_norm': 1.203604817390442, 'learning_rate': 4.328e-06, 'epoch': 9.136}
# {'loss': 0.5682, 'grad_norm': 0.84099280834198, 'learning_rate': 4.248e-06, 'epoch': 9.152}
# {'loss': 0.5697, 'grad_norm': 1.0578147172927856, 'learning_rate': 4.168000000000001e-06, 'epoch': 9.168}
# {'loss': 0.4621, 'grad_norm': 0.7412179112434387, 'learning_rate': 4.0880000000000005e-06, 'epoch': 9.184}
# {'loss': 0.6687, 'grad_norm': 1.0818067789077759, 'learning_rate': 4.0079999999999996e-06, 'epoch': 9.2}
# {'loss': 0.5299, 'grad_norm': 0.9052251577377319, 'learning_rate': 3.928e-06, 'epoch': 9.216}
# {'loss': 0.6322, 'grad_norm': 0.7813709378242493, 'learning_rate': 3.848e-06, 'epoch': 9.232}
# {'loss': 0.5458, 'grad_norm': 0.9381434321403503, 'learning_rate': 3.768e-06, 'epoch': 9.248}
# {'loss': 0.5263, 'grad_norm': 0.6874878406524658, 'learning_rate': 3.6880000000000005e-06, 'epoch': 9.264}
# {'loss': 0.5985, 'grad_norm': 0.6132341623306274, 'learning_rate': 3.6080000000000004e-06, 'epoch': 9.28}
# {'loss': 0.579, 'grad_norm': 0.650005042552948, 'learning_rate': 3.528e-06, 'epoch': 9.296}
# {'loss': 0.5856, 'grad_norm': 0.6553981900215149, 'learning_rate': 3.448e-06, 'epoch': 9.312}
# {'loss': 0.562, 'grad_norm': 0.7597559094429016, 'learning_rate': 3.368e-06, 'epoch': 9.328}
# {'loss': 0.5989, 'grad_norm': 0.8598397970199585, 'learning_rate': 3.288e-06, 'epoch': 9.344}
# {'loss': 0.6361, 'grad_norm': 1.0126487016677856, 'learning_rate': 3.208e-06, 'epoch': 9.36}
# {'loss': 0.5122, 'grad_norm': 0.672403872013092, 'learning_rate': 3.1280000000000004e-06, 'epoch': 9.376}
# {'loss': 0.4696, 'grad_norm': 0.7931907773017883, 'learning_rate': 3.0480000000000003e-06, 'epoch': 9.392}
# {'loss': 0.5386, 'grad_norm': 0.6310129165649414, 'learning_rate': 2.9680000000000002e-06, 'epoch': 9.408}
# {'loss': 0.6306, 'grad_norm': 0.6856998801231384, 'learning_rate': 2.888e-06, 'epoch': 9.424}
# {'loss': 0.5078, 'grad_norm': 0.6703038811683655, 'learning_rate': 2.808e-06, 'epoch': 9.44}
# {'loss': 0.5088, 'grad_norm': 0.6549839377403259, 'learning_rate': 2.728e-06, 'epoch': 9.456}
# {'loss': 0.5172, 'grad_norm': 0.6196891665458679, 'learning_rate': 2.6480000000000003e-06, 'epoch': 9.472}
# {'loss': 0.5304, 'grad_norm': 0.803059458732605, 'learning_rate': 2.5680000000000002e-06, 'epoch': 9.488}
# {'loss': 0.596, 'grad_norm': 0.830391526222229, 'learning_rate': 2.488e-06, 'epoch': 9.504}
# {'loss': 0.5378, 'grad_norm': 0.5056923031806946, 'learning_rate': 2.408e-06, 'epoch': 9.52}
# {'loss': 0.5685, 'grad_norm': 0.8697674870491028, 'learning_rate': 2.328e-06, 'epoch': 9.536}
# {'loss': 0.5002, 'grad_norm': 0.6294008493423462, 'learning_rate': 2.248e-06, 'epoch': 9.552}
# {'loss': 0.6061, 'grad_norm': 0.7725768089294434, 'learning_rate': 2.1680000000000002e-06, 'epoch': 9.568}
# {'loss': 0.4907, 'grad_norm': 0.682888925075531, 'learning_rate': 2.088e-06, 'epoch': 9.584}
# {'loss': 0.506, 'grad_norm': 0.8620173931121826, 'learning_rate': 2.008e-06, 'epoch': 9.6}
# {'loss': 0.443, 'grad_norm': 0.6805291771888733, 'learning_rate': 1.928e-06, 'epoch': 9.616}
# {'loss': 0.6006, 'grad_norm': 0.8445215821266174, 'learning_rate': 1.8480000000000001e-06, 'epoch': 9.632}
# {'loss': 0.5844, 'grad_norm': 1.0360634326934814, 'learning_rate': 1.7680000000000003e-06, 'epoch': 9.648}
# {'loss': 0.4778, 'grad_norm': 1.0317564010620117, 'learning_rate': 1.688e-06, 'epoch': 9.664}
# {'loss': 0.5589, 'grad_norm': 0.8507294654846191, 'learning_rate': 1.608e-06, 'epoch': 9.68}
# {'loss': 0.5077, 'grad_norm': 0.8003769516944885, 'learning_rate': 1.528e-06, 'epoch': 9.696}
# {'loss': 0.5675, 'grad_norm': 0.667714536190033, 'learning_rate': 1.4480000000000002e-06, 'epoch': 9.712}
# {'loss': 0.6258, 'grad_norm': 0.966521143913269, 'learning_rate': 1.368e-06, 'epoch': 9.728}
# {'loss': 0.5112, 'grad_norm': 0.8146204948425293, 'learning_rate': 1.2880000000000002e-06, 'epoch': 9.744}
# {'loss': 0.6431, 'grad_norm': 0.7765752077102661, 'learning_rate': 1.2080000000000001e-06, 'epoch': 9.76}
# {'loss': 0.5637, 'grad_norm': 0.7956160306930542, 'learning_rate': 1.128e-06, 'epoch': 9.776}
# {'loss': 0.5772, 'grad_norm': 0.7355462908744812, 'learning_rate': 1.048e-06, 'epoch': 9.792}
# {'loss': 0.5981, 'grad_norm': 0.7823789715766907, 'learning_rate': 9.679999999999999e-07, 'epoch': 9.808}
# {'loss': 0.536, 'grad_norm': 0.9007849097251892, 'learning_rate': 8.880000000000001e-07, 'epoch': 9.824}
# {'loss': 0.5548, 'grad_norm': 0.7988250255584717, 'learning_rate': 8.08e-07, 'epoch': 9.84}
# {'loss': 0.5403, 'grad_norm': 0.7722131609916687, 'learning_rate': 7.280000000000001e-07, 'epoch': 9.856}
# {'loss': 0.5696, 'grad_norm': 0.564060389995575, 'learning_rate': 6.48e-07, 'epoch': 9.872}
# {'loss': 0.5147, 'grad_norm': 0.645397424697876, 'learning_rate': 5.68e-07, 'epoch': 9.888}
# {'loss': 0.5329, 'grad_norm': 0.8595824837684631, 'learning_rate': 4.88e-07, 'epoch': 9.904}
# {'loss': 0.5127, 'grad_norm': 0.9114124178886414, 'learning_rate': 4.0800000000000005e-07, 'epoch': 9.92}
# {'loss': 0.525, 'grad_norm': 0.6845599412918091, 'learning_rate': 3.28e-07, 'epoch': 9.936}
# {'loss': 0.5861, 'grad_norm': 0.7355534434318542, 'learning_rate': 2.48e-07, 'epoch': 9.952}
# {'loss': 0.523, 'grad_norm': 0.7469391226768494, 'learning_rate': 1.6800000000000002e-07, 'epoch': 9.968}
# {'loss': 0.5008, 'grad_norm': 0.8942964673042297, 'learning_rate': 8.800000000000001e-08, 'epoch': 9.984}
# {'loss': 0.5795, 'grad_norm': 0.8529040217399597, 'learning_rate': 8e-09, 'epoch': 10.0}
# {'eval_loss': 0.5926081538200378, 'eval_runtime': 250.0322, 'eval_samples_per_second': 19.997, 'eval_steps_per_second': 2.5, 'epoch': 10.0}
# {'train_runtime': 15264.6287, 'train_samples_per_second': 3.276, 'train_steps_per_second': 0.409, 'train_loss': 0.6000672383117676, 'epoch': 10.0}

# %%
# predict with model (measuring time)
t0 = time.perf_counter()

pred_txt = model_llama_lora.predict(
    x=x,
    text_token_limit=256,
    report_interval=100)

pred_num = cm.label3_txt_to_num(pred_txt)

t1 = time.perf_counter()
pred_time_seconds = t1 - t0
pred_time_per_sample = pred_time_seconds / len(pred_num)
# Out:
# Reviews processed: 100
# Reviews processed: 200
# Reviews processed: 300
# Reviews processed: 400
# Reviews processed: 500
# Reviews processed: 600
# Reviews processed: 700
# Reviews processed: 800
# Reviews processed: 900
# Reviews processed: 1000
# Reviews processed: 1100
# Reviews processed: 1200
# Reviews processed: 1300
# Reviews processed: 1400
# Reviews processed: 1500
# Reviews processed: 1600
# Reviews processed: 1700
# Reviews processed: 1800
# Reviews processed: 1900
# Reviews processed: 2000
# Reviews processed: 2100
# Reviews processed: 2200
# Reviews processed: 2300
# Reviews processed: 2400
# Reviews processed: 2500
# Reviews processed: 2600
# Reviews processed: 2700
# Reviews processed: 2800
# Reviews processed: 2900
# Reviews processed: 3000
# Reviews processed: 3100
# Reviews processed: 3200
# Reviews processed: 3300
# Reviews processed: 3400
# Reviews processed: 3500
# Reviews processed: 3600
# Reviews processed: 3700
# Reviews processed: 3800
# Reviews processed: 3900
# Reviews processed: 4000
# Reviews processed: 4100
# Reviews processed: 4200
# Reviews processed: 4300
# Reviews processed: 4400
# Reviews processed: 4500
# Reviews processed: 4600
# Reviews processed: 4700
# Reviews processed: 4800
# Reviews processed: 4900
# Reviews processed: 5000

# %%
# sanity check: accuracy
acc = sum(y == pred_num) / len(pred_num)
print(f"acc cntrl: {acc}")
# Out:
# acc cntrl: 0.8808

# %%
# create a run directory (analogous to KP)
hyperparams = {
    "learning_rate": training_config.learning_rate,
    "train_batch_size": training_config.per_device_train_batch_size,
    "epochs": training_config.num_train_epochs }

run_outdir = utils.make_run_dir(
    output_root="outputs",
    model_name=f"{model_name}_lora_finetuned",
    hyperparams=hyperparams)

print("run_outdir:", run_outdir)
# Out:
# run_outdir: outputs/meta-llama_Llama-3.2-3B-Instruct_lora_finetuned_lr5e-05_bs1_ep10_20251208_175333

# %%
# save model and trainig

# save model weights
model_llama_lora.trainer.save_model(run_outdir)

# save tokenizer
model_llama_lora.tokenizer.save_pretrained(run_outdir)

# save training log_history as csv
log_df = pd.DataFrame(model_llama_lora.log_history)
log_df.to_csv(os.path.join(run_outdir, "training_log_history.csv"), index=False)

# save train_result metrics as JSON
train_result = model_llama_lora.train_result
with open(os.path.join(run_outdir, "train_result.json"), "w") as f:
    # train_result is a TrainOutput; .metrics is usually what you care about
    json.dump(train_result.metrics, f, indent=2)

# %% [markdown]
# # Evaluate Results/ Experiment

# %%
# loss curves on training and validation data (incl. saving)
logs = pd.DataFrame(model_llama_lora.log_history)

train_loss = logs[["epoch", "loss"]].dropna()
eval_loss  = logs[["epoch", "eval_loss"]].dropna()

plt.figure(figsize=(10,6))
plt.plot(train_loss["epoch"], train_loss["loss"], '-o', markersize=6, label="train_loss")
plt.plot(eval_loss["epoch"], eval_loss["eval_loss"], '-o', markersize=6, label="eval_loss")

plt.xlabel("epoch")
plt.ylabel("loss")
plt.title("Training & Validation Loss per Epoch")
plt.legend()
plt.grid(True)

plt.savefig(os.path.join(run_outdir, "loss_curves_epoch.png"), bbox_inches="tight")
plt.show()

# %%
# classification metrics (incl. saving classification report as csv)
metrics = utils.compute_classification_metrics_from_arrays(y_true=y, y_pred=pred_num)
df_cfreport = pd.DataFrame(metrics["classification report"]).T
print(df_cfreport)
path = os.path.join(run_outdir, "classification_report.csv")
df_cfreport.to_csv(path)
# Out:
#               precision    recall  f1-score    support
# 0              0.861603  0.899559  0.880172  1135.0000
# 1              0.389571  0.616505  0.477444   412.0000
# 2              0.989251  0.906169  0.945889  3453.0000
# accuracy       0.880800  0.880800  0.880800     0.8808
# macro avg      0.746808  0.807411  0.767835  5000.0000
# weighted avg   0.910861  0.880800  0.892371  5000.0000

# %%
# confusion matrix (incl. saving)
cm = confusion_matrix(y_true=y, y_pred=pred_num)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
plt.figure(figsize=(6, 6))
disp.plot(values_format='d')
plt.title(f"Confusion Matrix (Llama model)")
path = os.path.join(run_outdir, "confusion_matrix.png")
plt.savefig(path, bbox_inches='tight')
plt.show()

# %%
# evaluate time
print("Training time in seconds:", train_time_seconds)
print("Training time per sample:", train_time_per_sample)
print("Prediction time in seconds:", pred_time_seconds)
print("Prediction time per sample:", pred_time_per_sample)
# Out:
# Training time in seconds: 15280.647076918
# Training time per sample: 3.0561294153836
# Prediction time in seconds: 869.3061366540005
# Prediction time per sample: 0.1738612273308001

# %%
# saving results in team_comparison_results
results_comparison = {
    "n_samples": len(x),
    "train_seconds": train_time_seconds,
    "pred_time_seconds": pred_time_seconds,
    "pred_time_per_sample": pred_time_per_sample,
    "metrics": metrics}

utils.save_results_csv(
    results=results_comparison,
    csv_path=os.path.join("outputs", "team_comparison_results.csv"),
    model_name=f"{model_name}_zeroshot",
    extra_info={"run_outdir": run_outdir})
# Out:
# Appended results to outputs/team_comparison_results.csv

# %%
# saving all results in dictionary
results_all = results_comparison
results_all["train_time_seconds"] = train_time_seconds,
results_all["train_time_per_sample"] = train_time_per_sample,
results_all["model"] = f"{model_name}_zeroshot",
results_all["instruction"] = instruction
path = os.path.join(run_outdir, "results_all.json")
with open(path, "w") as f:
    json.dump(results_all, f, indent=2)
